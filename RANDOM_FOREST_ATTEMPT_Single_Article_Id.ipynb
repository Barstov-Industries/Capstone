# %%
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
from dotenv import dotenv_values

from sqlalchemy import create_engine, types
from sqlalchemy import text # to be able to pass string

# %%
# Load environment variables
config = dotenv_values()

# Define variables for the login
pg_user = config['POSTGRES_USER']
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']

# Set up the PostgreSQL connection URL
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# Create the database engine
engine = create_engine(url, echo=False)
my_schema = 'capstone_barstov_industries'

# Load data directly into a DataFrame
with engine.connect() as conn:
    conn.execute(text(f'SET search_path TO {my_schema};'))
    seasonal_data = pd.read_sql("SELECT * FROM seasonality_analysis;", conn)
    item_params_final = pd.read_sql("SELECT * FROM items_params_final", conn)

# Check the DataFrame structure

# %%
total_sales_article_id = seasonal_data.groupby(['article_id', 'product_type_name'])['total_sales'].sum().reset_index()
total_sales_id = total_sales_article_id.sort_values(by='total_sales', ascending=False)
top_30_percent = int(len(total_sales_id) * 0.3)
total_sales_id_sorted = total_sales_article_id.sort_values(by='total_sales', ascending=False)

# %%
total_sales_id.head(top_30_percent)
# Out:
#        article_id product_type_name  total_sales
# 53811   706016001          Trousers  1374.568748
# 53812   706016002          Trousers   994.142671
# 15970   568601006            Blazer   809.587383
# 3086    448509014          Trousers   649.887626
# 58405   720125001   Leggings/Tights   612.479067
# ...           ...               ...          ...
# 59367   723488002        Sunglasses     5.230847
# 82642   810169020          Trousers     5.230390
# 82819   810845001             Dress     5.229119
# 74240   776746005           T-shirt     5.228424
# 89964   841898002          Trousers     5.228407
#
# [31353 rows x 3 columns]

# %%
# Ensure `sale_date` is in datetime format
seasonal_data['sale_date'] = pd.to_datetime(seasonal_data['sale_date'])

# List of top 30% selling article IDs
top_30_article_ids = total_sales_id.head(top_30_percent)['article_id'].values  # Assuming this list was calculated as shown in your code

# Step 1: Filter `seasonal_data` to include only top 30% article IDs
top_selling_data = seasonal_data[seasonal_data['article_id'].isin(top_30_article_ids)]

# %%
# RANDOM FOREST 7 DAYS 5% ITEMS, all 5% are in the supreme Mighty Best Params Set

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # Suppress non-critical warnings

# Ensure `sale_date` is in datetime format and filter for dates up to the end of February 2020
seasonal_data['sale_date'] = pd.to_datetime(seasonal_data['sale_date'])
seasonal_data = seasonal_data[seasonal_data['sale_date'] <= '2020-02-29']

# List of top 5% selling article IDs
top_5_percent = int(len(total_sales_id_sorted) * 0.05)
top_sample_article_ids = total_sales_id_sorted.head(top_5_percent)['article_id'].values

# Step 1: Filter `top_sample_article_ids` to include only those present in `item_params_final`
filtered_sample_ids = [article_id for article_id in top_sample_article_ids if article_id in item_params_final['article_id'].values]

# Step 2: Filter `seasonal_data` to include only items in the filtered sample
sampled_data = seasonal_data[seasonal_data['article_id'].isin(filtered_sample_ids)]

# Initialize dictionaries to store predictions and validation metrics
predictions_7_days = {}
validation_results = []

# Set default parameters for items without specific tuning information (if applicable)
default_params = {
    'max_depth': 10,
    'min_samples_split': 2,
    'n_estimators': 100
}

# Loop through each article in the filtered sampled set and apply Random Forest with validation
for article_id in filtered_sample_ids:
    # Filter data for the current article_id
    article_data = sampled_data[sampled_data['article_id'] == article_id]
    
    # Sort data by `sale_date`, set it as index
    article_data = article_data.set_index('sale_date').sort_index()
    article_data['total_sales'] = article_data['total_sales'].fillna(0)
    
    # Extract the time series for training
    ts_data = article_data['total_sales']
    
    # Check for sufficient data points
    if len(ts_data) < 60:  # Ensure at least 60 days of data for model stability
        continue
    
    # Fetch parameters for the current article_id from `item_params_final`
    params = item_params_final[item_params_final['article_id'] == article_id].iloc[0]

    # Use specific parameters if they exist, otherwise default to common ones
    if len(params) > 0:  # Check if params is not empty
        max_depth = int(params['max_depth'])
        min_samples_split = int(params['min_samples_split'])
        n_estimators = int(params['n_estimators'])

    else:
        max_depth = default_params['max_depth']
        min_samples_split = default_params['min_samples_split']
        n_estimators = default_params['n_estimators']
    
    # Define the RandomForest model with the selected parameters
    rf_model = RandomForestRegressor(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        n_estimators=n_estimators,
        random_state=42
    )
    
    # Split the data for validation: last 8 weeks (56 days)
    train_data = ts_data[:-56]  # All data except the last 8 weeks
    validation_data = ts_data[-56:]  # Last 8 weeks
    
    # Further split the last 8 weeks into 4-week training and 4-week validation sets
    rf_train = validation_data[:-28].values.reshape(-1, 1)  # First 4 weeks of the last 8 weeks
    rf_validation = validation_data[-28:].values  # Last 4 weeks of the last 8 weeks
    validation_dates = validation_data[-28:].index  # Dates for the validation period
    
    # Prepare target data for training
    y_train = train_data.values.reshape(-1, 1)
    
    # Fit the model on training data
    rf_model.fit(np.arange(len(y_train)).reshape(-1, 1), y_train.ravel())
    
    # Predict the next 7 days for forecasting using the trained model
    future_days = np.arange(len(y_train), len(y_train) + 7).reshape(-1, 1)
    forecast_7_days = rf_model.predict(future_days)
    predictions_7_days[article_id] = forecast_7_days
    
    # Validate the model on the 4-week validation period
    validation_days = np.arange(len(y_train), len(y_train) + 28).reshape(-1, 1)
    rf_validation_pred = rf_model.predict(validation_days)
    
    # Calculate RMSE and MAE on validation set
    rmse = np.sqrt(mean_squared_error(rf_validation, rf_validation_pred))
    mae = mean_absolute_error(rf_validation, rf_validation_pred)
    
    # Store each validation point with actual and predicted values, along with date
    for date, actual, predicted in zip(validation_dates, rf_validation, rf_validation_pred):
        validation_results.append({
            'article_id': article_id,
            'date': date,
            'total_sales': actual,
            'total_sales_predicted': predicted,
            'rmse': rmse,
            'mae': mae
        })

    print(f"Random Forest validation for article_id {article_id}: RMSE={rmse}, MAE={mae}")

# Convert predictions and validation results to DataFrames
forecast_df = pd.DataFrame(predictions_7_days).T  # Transpose so each article_id is a row
forecast_df.columns = [f"day_{i+1}" for i in range(7)]  # Rename columns for each forecasted day

validation_df = pd.DataFrame(validation_results)

# Save the results to CSV
forecast_df.to_csv("covid_5_rf_7_day_forecasts.csv", index=True)
validation_df.to_csv("covid_5_rf_7_day_validation_results_with_dates.csv", index=False)

print("Random Forest predictions and validation tables with time information created successfully!")
# Out:
# Random Forest validation for article_id 706016002: RMSE=0.549808418080242, MAE=0.3862977507619038
# Random Forest validation for article_id 568601006: RMSE=0.38776462276093465, MAE=0.32003002935911057
# Random Forest validation for article_id 448509014: RMSE=1.028374212113053, MAE=0.8776318890539858
# Random Forest validation for article_id 720125001: RMSE=1.1723946052733083, MAE=1.0341467297999989
# Random Forest validation for article_id 399223001: RMSE=0.36394992445390006, MAE=0.31856117152246605
# Random Forest validation for article_id 706016003: RMSE=1.246453165835904, MAE=1.1560983521278203
# Random Forest validation for article_id 562245046: RMSE=0.31784391253613603, MAE=0.27608948279999945
# Random Forest validation for article_id 751471001: RMSE=1.0201915122973442, MAE=0.9483195091285718
# Random Forest validation for article_id 661794001: RMSE=1.5301947365688624, MAE=1.5091359147857162
# Random Forest validation for article_id 706016015: RMSE=0.2582770120799426, MAE=0.2025072741428571
# Random Forest validation for article_id 562245001: RMSE=0.4216610564096799, MAE=0.40036453377857073
# Random Forest validation for article_id 554450001: RMSE=0.17983064149085012, MAE=0.15565170547845925
# Random Forest validation for article_id 399201002: RMSE=0.8922515717681178, MAE=0.8237308391501211
# Random Forest validation for article_id 687704001: RMSE=0.3707257823703122, MAE=0.28218054571428575
# Random Forest validation for article_id 399136009: RMSE=0.054981669722809996, MAE=0.04529074478928575
# Random Forest validation for article_id 741356002: RMSE=0.1619173220952705, MAE=0.1417064291357051
# Random Forest validation for article_id 673677002: RMSE=1.0530206972940568, MAE=1.022663104285714
# Random Forest validation for article_id 590928001: RMSE=0.9890199172237886, MAE=0.9610614329228572
# Random Forest validation for article_id 372860001: RMSE=0.23556987643331118, MAE=0.16777909842001618
# Random Forest validation for article_id 706016006: RMSE=0.4396174979971173, MAE=0.41539071704571784
# Random Forest validation for article_id 568597006: RMSE=0.11660657708370482, MAE=0.09195732807857157
# Random Forest validation for article_id 730683001: RMSE=0.45358290547601193, MAE=0.3921290270000009
# Random Forest validation for article_id 448509001: RMSE=0.34557990148526835, MAE=0.28761003303372673
# Random Forest validation for article_id 562245018: RMSE=0.13861735342505513, MAE=0.1235060693785718
# Random Forest validation for article_id 568601007: RMSE=0.36001228420553827, MAE=0.29500069840801313
# Random Forest validation for article_id 464297007: RMSE=0.4877383412422612, MAE=0.45645731472986534
# Random Forest validation for article_id 399201022: RMSE=0.10149657627419476, MAE=0.06735203455794288
# Random Forest validation for article_id 661794002: RMSE=0.31074524203299014, MAE=0.26804060026160753
# Random Forest validation for article_id 351484002: RMSE=0.198527136284462, MAE=0.17550047842857078
# Random Forest validation for article_id 573716012: RMSE=0.17356330443205414, MAE=0.1682290513168236
# Random Forest validation for article_id 714790020: RMSE=0.2544690638617172, MAE=0.20512636848571456
# Random Forest validation for article_id 753737001: RMSE=0.46018650505105485, MAE=0.32209462601041977
# Random Forest validation for article_id 695632002: RMSE=0.1923144820598533, MAE=0.15781720256232457
# Random Forest validation for article_id 399201005: RMSE=0.05486910884805074, MAE=0.040640520430059515
# Random Forest validation for article_id 685814001: RMSE=0.26853494283120427, MAE=0.23339198384406337
# Random Forest validation for article_id 799365002: RMSE=0.4571015061428434, MAE=0.403217230789611
# Random Forest validation for article_id 484398001: RMSE=0.16076932876742456, MAE=0.14694515567857153
# Random Forest validation for article_id 732842001: RMSE=0.2749316155173941, MAE=0.2178236988820297
# Random Forest validation for article_id 732842002: RMSE=0.15240136048757558, MAE=0.12788922392857144
# Random Forest validation for article_id 714790003: RMSE=0.4230507998114608, MAE=0.3689037543267237
# Random Forest validation for article_id 695632001: RMSE=0.17911256105544146, MAE=0.14527542499999999
# Random Forest validation for article_id 534181002: RMSE=0.739791630731637, MAE=0.6943339865256458
# Random Forest validation for article_id 684209004: RMSE=0.2067766808914657, MAE=0.14375059653571426
# Random Forest validation for article_id 578476001: RMSE=0.23182430033511484, MAE=0.19676851074935517
# Random Forest validation for article_id 658030011: RMSE=0.17599051536539284, MAE=0.14186109945571437
# Random Forest validation for article_id 399061008: RMSE=0.17180160934244912, MAE=0.12145834799750004
# Random Forest validation for article_id 507909001: RMSE=0.11308768237301715, MAE=0.08738126026571377
# Random Forest validation for article_id 640021005: RMSE=0.12886493830755144, MAE=0.1163231336506423
# Random Forest validation for article_id 399201042: RMSE=0.4962929552822149, MAE=0.4006868271192873
# Random Forest validation for article_id 783346001: RMSE=0.4075049455962655, MAE=0.3674912940999149
# Random Forest validation for article_id 399256001: RMSE=0.16022863572377552, MAE=0.12465352685677512
# Random Forest validation for article_id 573085028: RMSE=0.6878047713247272, MAE=0.6457346474706835
# Random Forest validation for article_id 399136004: RMSE=0.0950155272886189, MAE=0.07606615002141673
# Random Forest validation for article_id 749699002: RMSE=0.16853610144299552, MAE=0.1549305647847497
# Random Forest validation for article_id 572998001: RMSE=0.9334309581299717, MAE=0.8927237515649555
# Random Forest validation for article_id 714790008: RMSE=0.2602669615144003, MAE=0.19260394351273447
# Random Forest validation for article_id 399223029: RMSE=0.37032627916468336, MAE=0.3611003730778403
# Random Forest validation for article_id 372860002: RMSE=0.1186697643601674, MAE=0.09145057743253161
# Random Forest validation for article_id 640021011: RMSE=0.1039957511100209, MAE=0.08297422675142856
# Random Forest validation for article_id 790006001: RMSE=0.4897040809414873, MAE=0.45748142682143067
# Random Forest validation for article_id 579302001: RMSE=0.1738896341633653, MAE=0.14200302714285715
# Random Forest validation for article_id 658030001: RMSE=0.2809249749485651, MAE=0.25653978027220165
# Random Forest validation for article_id 708705001: RMSE=0.20035334781585742, MAE=0.16465309656842844
# Random Forest validation for article_id 699080001: RMSE=0.20775453438330774, MAE=0.17369170303516998
# Random Forest validation for article_id 731160005: RMSE=0.3133869876991996, MAE=0.2743280204028905
# Random Forest validation for article_id 749699001: RMSE=0.10121022638198639, MAE=0.0743386068964285
# Random Forest validation for article_id 687704002: RMSE=0.38415120324178126, MAE=0.35186609367720745
# Random Forest validation for article_id 534181011: RMSE=0.23768667616256767, MAE=0.21315975502142842
# Random Forest validation for article_id 685814003: RMSE=0.3098770988461046, MAE=0.1992978232142857
# Random Forest validation for article_id 731160004: RMSE=0.11286749141722292, MAE=0.09794014399751753
# Random Forest validation for article_id 534181005: RMSE=0.07397312515748275, MAE=0.039323610592857126
# Random Forest validation for article_id 636455003: RMSE=0.0788375221920798, MAE=0.07046861858748986
# Random Forest validation for article_id 740519002: RMSE=0.24736419585535094, MAE=0.22042278445311939
# Random Forest validation for article_id 666006004: RMSE=0.934130910647532, MAE=0.9331921383185707
# Random Forest validation for article_id 562245050: RMSE=0.11213177268189142, MAE=0.08835677928000016
# Random Forest validation for article_id 554450027: RMSE=0.2559932330010665, MAE=0.24015303400458168
# Random Forest validation for article_id 539723005: RMSE=0.018901039485987748, MAE=0.015678873823214333
# Random Forest validation for article_id 781613006: RMSE=0.20601178060900702, MAE=0.19799879989285715
# Random Forest validation for article_id 312878001: RMSE=0.1284274729111875, MAE=0.10736098642142933
# Random Forest validation for article_id 724906006: RMSE=0.3993752258932535, MAE=0.347097822600623
# Random Forest validation for article_id 600886001: RMSE=0.48829200798948047, MAE=0.4658502131017143
# Random Forest validation for article_id 723469001: RMSE=0.19247222380338722, MAE=0.17011746230065564
# Random Forest validation for article_id 666006006: RMSE=0.24503410350636334, MAE=0.24316791875997817
# Random Forest validation for article_id 554450004: RMSE=0.196488735427866, MAE=0.17967609132315612
# Random Forest validation for article_id 688537004: RMSE=0.1904381363082422, MAE=0.16847603752080823
# Random Forest validation for article_id 658030020: RMSE=0.22598369714164532, MAE=0.18719257231714184
# Random Forest validation for article_id 673396002: RMSE=0.07485108424681174, MAE=0.06026750100000013
# Random Forest validation for article_id 579541001: RMSE=0.07727850250729194, MAE=0.06284883534644561
# Random Forest validation for article_id 618800001: RMSE=0.5014536073564605, MAE=0.49749264037571467
# Random Forest validation for article_id 568597007: RMSE=0.2341946484287837, MAE=0.18821238774913399
# Random Forest validation for article_id 684209013: RMSE=0.27702916438981245, MAE=0.2738081132857146
# Random Forest validation for article_id 399223033: RMSE=0.5157837522021039, MAE=0.4977529500222218
# Random Forest validation for article_id 573085004: RMSE=0.052967471479572356, MAE=0.041368479191861256
# Random Forest validation for article_id 448509018: RMSE=0.565240890729914, MAE=0.5052350769096903
# Random Forest validation for article_id 399136061: RMSE=0.7389205425853502, MAE=0.7246062351485671
# Random Forest validation for article_id 554479001: RMSE=0.11061067712227167, MAE=0.0894483204074714
# Random Forest validation for article_id 399136011: RMSE=0.11030217617118401, MAE=0.10173964216736335
# Random Forest validation for article_id 539723001: RMSE=0.05263270595051456, MAE=0.052008311489092275
# Random Forest validation for article_id 655784001: RMSE=0.14050364719639244, MAE=0.12174517856788837
# Random Forest validation for article_id 743616009: RMSE=0.4980555932517582, MAE=0.4606293974588011
# Random Forest validation for article_id 712587003: RMSE=0.023083756844420995, MAE=0.021075951571428612
# Random Forest validation for article_id 805000001: RMSE=0.2903870004046156, MAE=0.2426634976714265
# Random Forest validation for article_id 769748002: RMSE=0.6413879370266973, MAE=0.5271051774571506
# Random Forest validation for article_id 772774001: RMSE=2.3308716580131352, MAE=2.319428060544768
# Random Forest validation for article_id 507910001: RMSE=0.02142322054029471, MAE=0.01908373847579221
# Random Forest validation for article_id 720125007: RMSE=0.4634111995381792, MAE=0.42581619287404776
# Random Forest validation for article_id 554450036: RMSE=0.09787522811596305, MAE=0.08594149324819048
# Random Forest validation for article_id 756318001: RMSE=0.2813400329738131, MAE=0.22258720487394137
# Random Forest validation for article_id 762846001: RMSE=0.5667499922125393, MAE=0.5360598740149711
# Random Forest validation for article_id 573937001: RMSE=0.09625490449124675, MAE=0.08351170061071436
# Random Forest validation for article_id 399201020: RMSE=0.06076286199713902, MAE=0.05569240458889964
# Random Forest validation for article_id 487722001: RMSE=0.11407516624436488, MAE=0.09139761581080771
# Random Forest validation for article_id 719655001: RMSE=0.20112194011051251, MAE=0.18012743281655555
# Random Forest validation for article_id 608776002: RMSE=0.29916508094944577, MAE=0.26852570021058747
# Random Forest validation for article_id 736530007: RMSE=0.23664869363358873, MAE=0.18293368162280088
# Random Forest validation for article_id 599580017: RMSE=0.18972918599172006, MAE=0.16447071211057143
# Random Forest validation for article_id 827635001: RMSE=0.301450848650959, MAE=0.2448623850051554
# Random Forest validation for article_id 752814003: RMSE=0.6940069724078872, MAE=0.6500802826798309
# Random Forest validation for article_id 188183001: RMSE=0.24681066257669904, MAE=0.2448865861502126
# Random Forest validation for article_id 610776002: RMSE=0.13869293646935296, MAE=0.12841245127351297
# Random Forest validation for article_id 762846008: RMSE=0.6417725575830989, MAE=0.5796515067460868
# Random Forest validation for article_id 772829002: RMSE=1.1832219677981723, MAE=1.17035025014286
# Random Forest validation for article_id 716672001: RMSE=0.0974885182108107, MAE=0.09578794993206449
# Random Forest validation for article_id 573085043: RMSE=0.4626194828660476, MAE=0.4095474320685719
# Random Forest validation for article_id 179950001: RMSE=0.10883451236008597, MAE=0.08540608552657779
# Random Forest validation for article_id 680262001: RMSE=0.02704104976185145, MAE=0.01649091340464286
# Random Forest validation for article_id 658030006: RMSE=0.09938713753867942, MAE=0.07875938427490932
# Random Forest validation for article_id 554479005: RMSE=0.026402743638147267, MAE=0.01971755319168424
# Random Forest validation for article_id 723529001: RMSE=0.19657924130201337, MAE=0.17729731589285716
# Random Forest validation for article_id 715343003: RMSE=0.14571706549222163, MAE=0.11582022392857146
# Random Forest validation for article_id 399061028: RMSE=0.37024326689424336, MAE=0.32171105140111916
# Random Forest validation for article_id 715624001: RMSE=0.5262284983856618, MAE=0.49747334514116176
# Random Forest validation for article_id 399201024: RMSE=0.1094151295821654, MAE=0.10696908006172152
# Random Forest validation for article_id 598859001: RMSE=0.1966422665901424, MAE=0.19261211996692781
# Random Forest validation for article_id 668537001: RMSE=0.07865951017998922, MAE=0.07543035337142898
# Random Forest validation for article_id 678942001: RMSE=0.3143606267179448, MAE=0.2852549113185712
# Random Forest validation for article_id 656763001: RMSE=0.03868606654220415, MAE=0.028079102097133688
# Random Forest validation for article_id 621381001: RMSE=0.10422221505610682, MAE=0.0927852649568818
# Random Forest validation for article_id 636323001: RMSE=0.1334222181340785, MAE=0.11419211900285728
# Random Forest validation for article_id 621381012: RMSE=0.11040604484582617, MAE=0.09103862815215728
# Random Forest validation for article_id 658298001: RMSE=0.5633236713400998, MAE=0.555585082842858
# Random Forest validation for article_id 639192002: RMSE=1.1748525409231014, MAE=1.174123773558353
# Random Forest validation for article_id 624257001: RMSE=0.22194931285552305, MAE=0.17777859700214343
# Random Forest validation for article_id 484205004: RMSE=0.0765690308930962, MAE=0.07298905500475904
# Random Forest validation for article_id 728156006: RMSE=0.257345650242736, MAE=0.2047937473891696
# Random Forest validation for article_id 764155001: RMSE=0.09548426588104382, MAE=0.06490382432142858
# Random Forest validation for article_id 714790017: RMSE=0.20489453219718892, MAE=0.16343854670044622
# Random Forest validation for article_id 559633001: RMSE=0.023953427867040633, MAE=0.019569998878499337
# Random Forest validation for article_id 730683041: RMSE=0.9916409459543454, MAE=0.9197150437142865
# Random Forest validation for article_id 758084002: RMSE=0.07976118249183338, MAE=0.07276388921342938
# Random Forest validation for article_id 687704012: RMSE=0.95050645475247, MAE=0.9424816517006464
# Random Forest validation for article_id 690936003: RMSE=0.07430768690044366, MAE=0.06929757708356284
# Random Forest validation for article_id 502224001: RMSE=0.11766761395880919, MAE=0.11293149451170635
# Random Forest validation for article_id 722169001: RMSE=0.18575717737581143, MAE=0.16964290233857277
# Random Forest validation for article_id 639448001: RMSE=0.3712057620289554, MAE=0.3602385316146755
# Random Forest validation for article_id 399087014: RMSE=0.18886112966483545, MAE=0.17658009843249484
# Random Forest validation for article_id 578487002: RMSE=0.07107198170949253, MAE=0.06239346239642849
# Random Forest validation for article_id 568808001: RMSE=0.0902002941247838, MAE=0.07892258488600648
# Random Forest validation for article_id 690936006: RMSE=0.4701374760561928, MAE=0.46975238562399463
# Random Forest validation for article_id 278811006: RMSE=0.10962839394468094, MAE=0.08758033909285753
# Random Forest validation for article_id 708138002: RMSE=0.31982465690207296, MAE=0.256504114751818
# Random Forest validation for article_id 699081001: RMSE=0.10413506138769348, MAE=0.07560003978262506
# Random Forest validation for article_id 815851001: RMSE=0.6399858618543537, MAE=0.6165418959589958
# Random Forest validation for article_id 688537011: RMSE=0.03278863990167592, MAE=0.024209408515714254
# Random Forest validation for article_id 547780001: RMSE=0.5365258879249228, MAE=0.5154888292277129
# Random Forest validation for article_id 741040001: RMSE=0.2116133840619777, MAE=0.18030856434285722
# Random Forest validation for article_id 160442007: RMSE=0.05202620180799714, MAE=0.04515280607285711
# Random Forest validation for article_id 697031002: RMSE=0.11781159136595751, MAE=0.09255936472859323
# Random Forest validation for article_id 684209001: RMSE=0.09718884412419364, MAE=0.09480168266757073
# Random Forest validation for article_id 690936002: RMSE=0.04493601364287722, MAE=0.04126884100518368
# Random Forest validation for article_id 658298007: RMSE=0.10201411411336077, MAE=0.08676400793297613
# Random Forest validation for article_id 399136027: RMSE=0.09242543507646012, MAE=0.08462604702698359
# Random Forest validation for article_id 305931001: RMSE=0.13689347681023853, MAE=0.11769563357411618
# Random Forest validation for article_id 790006003: RMSE=1.7857008235471028, MAE=1.7806052883996035
# Random Forest validation for article_id 706016019: RMSE=0.1553159300495176, MAE=0.12729558045000014
# Random Forest validation for article_id 795440001: RMSE=0.1622387857946826, MAE=0.12312615389642843
# Random Forest validation for article_id 401044004: RMSE=0.06964789171358128, MAE=0.06436737873391858
# Random Forest validation for article_id 399256005: RMSE=0.16256454307890147, MAE=0.14593322760501912
# Random Forest validation for article_id 796210001: RMSE=0.17287571943405577, MAE=0.14575143142857153
# Random Forest validation for article_id 660599002: RMSE=0.061434947520744534, MAE=0.0556510488910717
# Random Forest validation for article_id 537116001: RMSE=0.24146363634014265, MAE=0.18897069253886192
# Random Forest validation for article_id 680263003: RMSE=0.1057913505900148, MAE=0.10476365688928554
# Random Forest validation for article_id 536139006: RMSE=0.09191428672086623, MAE=0.07847410149774912
# Random Forest validation for article_id 534181008: RMSE=0.20843506847774265, MAE=0.18874199884285708
# Random Forest validation for article_id 729928001: RMSE=0.08796613115757014, MAE=0.07555091013400006
# Random Forest validation for article_id 253448003: RMSE=0.06754101725173359, MAE=0.05398163522285713
# Random Forest validation for article_id 762846006: RMSE=0.5751313312636052, MAE=0.5293825943901984
# Random Forest validation for article_id 652924004: RMSE=0.22051001052374505, MAE=0.18704845600971226
# Random Forest validation for article_id 636505001: RMSE=0.661740411617205, MAE=0.6279084619519443
# Random Forest validation for article_id 688105002: RMSE=0.11155975995761555, MAE=0.09602104744357196
# Random Forest validation for article_id 781613002: RMSE=0.0861598638144733, MAE=0.06079764403637756
# Random Forest validation for article_id 757303012: RMSE=0.301165154927035, MAE=0.2676295464300595
# Random Forest validation for article_id 729860002: RMSE=0.14853107402253857, MAE=0.12076294207857134
# Random Forest validation for article_id 677999001: RMSE=0.07004029596668929, MAE=0.04989508013372751
# Random Forest validation for article_id 578478001: RMSE=0.1312939325705967, MAE=0.09859789800902112
# Random Forest validation for article_id 399201025: RMSE=0.20885647646686492, MAE=0.1532097116289728
# Random Forest validation for article_id 719530003: RMSE=0.16111374421894237, MAE=0.14138969789285685
# Random Forest validation for article_id 706016004: RMSE=0.12312098812760962, MAE=0.10627356672221082
# Random Forest validation for article_id 636455005: RMSE=5.374857430350603, MAE=5.3745831767786685
# Random Forest validation for article_id 612481002: RMSE=0.05687183990673666, MAE=0.04248905434884213
# Random Forest validation for article_id 568601023: RMSE=0.25198202077286497, MAE=0.19940172801788192
# Random Forest validation for article_id 755362001: RMSE=0.2676803534636303, MAE=0.24904373755714235
# Random Forest validation for article_id 554598001: RMSE=0.12398098923685187, MAE=0.10933561205567145
# Random Forest validation for article_id 759814009: RMSE=0.2874161898353762, MAE=0.24967814809642816
# Random Forest validation for article_id 773989001: RMSE=0.2712476171023452, MAE=0.2702687895778848
# Random Forest validation for article_id 748355003: RMSE=0.1264461368132879, MAE=0.1059232868771425
# Random Forest validation for article_id 714927002: RMSE=0.276216011378651, MAE=0.24800086453428247
# Random Forest validation for article_id 610776001: RMSE=0.04355776206085823, MAE=0.03475646735004648
# Random Forest validation for article_id 690936001: RMSE=0.35683451434987756, MAE=0.35644921722768447
# Random Forest validation for article_id 600886011: RMSE=0.07922552964822425, MAE=0.06837075607652611
# Random Forest validation for article_id 791587001: RMSE=0.42139672411667356, MAE=0.37528245522828846
# Random Forest validation for article_id 562245062: RMSE=0.21654594301104507, MAE=0.20974094827886353
# Random Forest validation for article_id 680265002: RMSE=0.11188934882624721, MAE=0.1076637645918571
# Random Forest validation for article_id 535035001: RMSE=0.346153720436456, MAE=0.3259641392540515
# Random Forest validation for article_id 760084003: RMSE=0.13045430757983947, MAE=0.10514007323777982
# Random Forest validation for article_id 695545001: RMSE=0.05800745157223306, MAE=0.05543209739914242
# Random Forest validation for article_id 803757001: RMSE=0.1530377957100327, MAE=0.12187685682857079
# Random Forest validation for article_id 611415001: RMSE=0.12383231123862709, MAE=0.1075048095145389
# Random Forest validation for article_id 698276001: RMSE=1.2402692962229886, MAE=1.2340085898932547
# Random Forest validation for article_id 158340001: RMSE=0.14680456590155372, MAE=0.11748083377142858
# Random Forest validation for article_id 758034001: RMSE=0.3453120493227051, MAE=0.32319242674775517
# Random Forest validation for article_id 612935009: RMSE=0.2839617338876908, MAE=0.28314960175006065
# Random Forest validation for article_id 762063001: RMSE=0.10742917228495612, MAE=0.08732030622265825
# Random Forest validation for article_id 534181003: RMSE=0.31663309684659424, MAE=0.3070095542345071
# Random Forest validation for article_id 690936013: RMSE=0.11860302088985998, MAE=0.11788852508577334
# Random Forest validation for article_id 664133001: RMSE=0.13035909603555335, MAE=0.10733606648098307
# Random Forest validation for article_id 640021012: RMSE=0.16863229442923378, MAE=0.1528608620543956
# Random Forest validation for article_id 603584018: RMSE=0.043284228627047255, MAE=0.029295066547078207
# Random Forest validation for article_id 715624010: RMSE=0.2026098669799328, MAE=0.1679154942148588
# Random Forest validation for article_id 160442010: RMSE=0.1253666537025537, MAE=0.11257405291834295
# Random Forest validation for article_id 615141002: RMSE=0.04524551905436457, MAE=0.034417536245714274
# Random Forest validation for article_id 540768002: RMSE=0.06161577635496842, MAE=0.055845145665032854
# Random Forest validation for article_id 684340001: RMSE=0.03346650305537339, MAE=0.024341870368544634
# Random Forest validation for article_id 537688014: RMSE=0.017699487469298808, MAE=0.015484542339714396
# Random Forest validation for article_id 658030016: RMSE=0.1488115370845773, MAE=0.12163843867857152
# Random Forest validation for article_id 740498001: RMSE=0.4647156962946623, MAE=0.45840486848999523
# Random Forest validation for article_id 568601030: RMSE=0.5856128770926432, MAE=0.4245769128513629
# Random Forest validation for article_id 700144001: RMSE=0.2632530769756671, MAE=0.26039773896428664
# Random Forest validation for article_id 589599031: RMSE=0.05177915281181182, MAE=0.03230461351026854
# Random Forest validation for article_id 516903005: RMSE=0.11676997304898708, MAE=0.10473215150392824
# Random Forest validation for article_id 742561001: RMSE=0.5542712712782276, MAE=0.5487775878888511
# Random Forest validation for article_id 554450019: RMSE=0.04697010668355477, MAE=0.032377448488799164
# Random Forest validation for article_id 664074001: RMSE=0.08854722982187671, MAE=0.07603407682142846
# Random Forest validation for article_id 623115001: RMSE=0.38051625617854357, MAE=0.37410343093571485
# Random Forest validation for article_id 790006002: RMSE=0.1885242260266128, MAE=0.12323777289285598
# Random Forest validation for article_id 529953007: RMSE=0.18150068303498418, MAE=0.17230234233108313
# Random Forest validation for article_id 662418001: RMSE=0.10677212585458498, MAE=0.09556663785149389
# Random Forest validation for article_id 702790004: RMSE=0.13665005372286168, MAE=0.13607695789916666
# Random Forest validation for article_id 698776002: RMSE=0.050788569467178434, MAE=0.04551157616999961
# Random Forest validation for article_id 794575001: RMSE=0.15675266728978782, MAE=0.13849460306461933
# Random Forest validation for article_id 506098007: RMSE=0.18127754901883283, MAE=0.1527929375143631
# Random Forest validation for article_id 399201023: RMSE=0.09876779187812809, MAE=0.08961484469714291
# Random Forest validation for article_id 809961002: RMSE=0.6399639159791773, MAE=0.6114547290457174
# Random Forest validation for article_id 714803001: RMSE=0.35118019299205655, MAE=0.3507770819142852
# Random Forest validation for article_id 682550001: RMSE=0.10946983652779384, MAE=0.09429320754621613
# Random Forest validation for article_id 399136033: RMSE=0.05240992734631603, MAE=0.049675246865921015
# Random Forest validation for article_id 728156001: RMSE=0.18644253557330623, MAE=0.17105559819844
# Random Forest validation for article_id 507909003: RMSE=0.08634139709008355, MAE=0.06856979617552501
# Random Forest validation for article_id 699075001: RMSE=0.10110303765021476, MAE=0.10056004473947625
# Random Forest validation for article_id 574109011: RMSE=0.04707941832115566, MAE=0.02973849875
# Random Forest validation for article_id 714824001: RMSE=0.051072555263935906, MAE=0.039294712648503094
# Random Forest validation for article_id 779324004: RMSE=0.18510379993753678, MAE=0.170993117557143
# Random Forest validation for article_id 733267001: RMSE=0.07309491209499197, MAE=0.07082978461142808
# Random Forest validation for article_id 711440001: RMSE=0.10747719331592032, MAE=0.082423288506425
# Random Forest validation for article_id 751471016: RMSE=0.09397945599637693, MAE=0.08905401925040232
# Random Forest validation for article_id 730683019: RMSE=1.0584164249114998, MAE=1.045096247195239
# Random Forest validation for article_id 705786001: RMSE=0.08594332354785618, MAE=0.07187754109714316
# Random Forest validation for article_id 650122001: RMSE=0.1860905123269531, MAE=0.1752801318867822
# Random Forest validation for article_id 652730004: RMSE=0.17657867178152672, MAE=0.1599122932205365
# Random Forest validation for article_id 399087030: RMSE=0.06792345185601371, MAE=0.05432256539589111
# Random Forest validation for article_id 797710001: RMSE=0.2033554872051486, MAE=0.20082677402792387
# Random Forest validation for article_id 179123001: RMSE=0.16590384082146944, MAE=0.16315402037571397
# Random Forest validation for article_id 697054014: RMSE=0.15448669157154335, MAE=0.13705477256072432
# Random Forest validation for article_id 759871002: RMSE=0.061373642167410314, MAE=0.049349978852350304
# Random Forest validation for article_id 689109001: RMSE=0.03125392437375764, MAE=0.030858906273165565
# Random Forest validation for article_id 758064001: RMSE=0.04501934114900187, MAE=0.026803511217857134
# Random Forest validation for article_id 539723003: RMSE=0.014299289719841991, MAE=0.010568895547857117
# Random Forest validation for article_id 658030017: RMSE=0.13687010593828003, MAE=0.10315577243532593
# Random Forest validation for article_id 820873001: RMSE=0.1392111332945797, MAE=0.11397186434142857
# Random Forest validation for article_id 745475001: RMSE=0.16852840312290787, MAE=0.1676531177012302
# Random Forest validation for article_id 663679001: RMSE=0.05490428038020563, MAE=0.05276259056150007
# Random Forest validation for article_id 709138001: RMSE=0.32104309309490237, MAE=0.32016118094851365
# Random Forest validation for article_id 711053003: RMSE=0.08027829886653769, MAE=0.07140843207949409
# Random Forest validation for article_id 698387001: RMSE=0.23233641488045903, MAE=0.18207134603224315
# Random Forest validation for article_id 673677004: RMSE=0.16435355456827763, MAE=0.14759122232674396
# Random Forest validation for article_id 524061003: RMSE=0.04390645817119965, MAE=0.024997403715228343
# Random Forest validation for article_id 714828002: RMSE=0.07817615350787584, MAE=0.07541058357857147
# Random Forest validation for article_id 697091007: RMSE=0.04981607071328038, MAE=0.04289129903346432
# Random Forest validation for article_id 562245093: RMSE=0.08661397815430685, MAE=0.06962505651050287
# Random Forest validation for article_id 688873002: RMSE=0.02056972890024962, MAE=0.012419734239285718
# Random Forest validation for article_id 744786001: RMSE=0.024599023420529737, MAE=0.01960361328004621
# Random Forest validation for article_id 573716053: RMSE=0.031467980834742254, MAE=0.029657416834840272
# Random Forest validation for article_id 569562005: RMSE=0.43128469049333573, MAE=0.22190585872571425
# Random Forest validation for article_id 706016007: RMSE=0.7520143504497707, MAE=0.5963552864285714
# Random Forest validation for article_id 714807003: RMSE=0.1415730734548005, MAE=0.11569272395977429
# Random Forest validation for article_id 824185001: RMSE=0.36990817678170174, MAE=0.3502043450000002
# Random Forest validation for article_id 752814004: RMSE=0.08865944942384492, MAE=0.07948528094428543
# Random Forest validation for article_id 783384008: RMSE=0.22559916522228515, MAE=0.1841813001014286
# Random Forest validation for article_id 787946002: RMSE=0.0966850533817845, MAE=0.0826566528088524
# Random Forest validation for article_id 399087010: RMSE=0.10424239351006309, MAE=0.09086111625082553
# Random Forest validation for article_id 400285006: RMSE=0.1727326419121275, MAE=0.15749350855401914
# Random Forest validation for article_id 721268001: RMSE=0.09121874864084985, MAE=0.06753232603571423
# Random Forest validation for article_id 658030005: RMSE=0.027261293067984377, MAE=0.01905414358857171
# Random Forest validation for article_id 720504001: RMSE=0.10132918289194635, MAE=0.08392550357381025
# Random Forest validation for article_id 637283006: RMSE=0.1270415265168648, MAE=0.12547352281560084
# Random Forest validation for article_id 634426008: RMSE=0.06483867077758136, MAE=0.05343186681621833
# Random Forest validation for article_id 704756001: RMSE=0.0729592584105506, MAE=0.057901689889285866
# Random Forest validation for article_id 685813001: RMSE=0.10598960519160942, MAE=0.08344067049999968
# Random Forest validation for article_id 111586001: RMSE=0.1901788220280692, MAE=0.16865856793704986
# Random Forest validation for article_id 547058001: RMSE=0.41172339749365106, MAE=0.4107068709549996
# Random Forest validation for article_id 456163060: RMSE=0.5631663350929856, MAE=0.5130684210714261
# Random Forest validation for article_id 788846004: RMSE=0.34040745454299737, MAE=0.31247003737142937
# Random Forest validation for article_id 599580020: RMSE=0.02237006682426195, MAE=0.012409582889000017
# Random Forest validation for article_id 749615001: RMSE=0.08041190452501425, MAE=0.06013881371142858
# Random Forest validation for article_id 743616001: RMSE=0.1799032451992491, MAE=0.16211286987857138
# Random Forest validation for article_id 539723006: RMSE=0.027961979328713697, MAE=0.011855289754285717
# Random Forest validation for article_id 111593001: RMSE=0.08412692768668668, MAE=0.06852610455034698
# Random Forest validation for article_id 524825011: RMSE=0.024182306271561652, MAE=0.020473516308928692
# Random Forest validation for article_id 399223035: RMSE=0.16061338723760393, MAE=0.1559366902356711
# Random Forest validation for article_id 611415005: RMSE=0.2755120864401033, MAE=0.2537771553445079
# Random Forest validation for article_id 684824003: RMSE=0.4408599416993488, MAE=0.43942504583642983
# Random Forest validation for article_id 768912001: RMSE=0.14030467810156214, MAE=0.11891621784999355
# Random Forest validation for article_id 622955001: RMSE=0.34811094879198284, MAE=0.3438876926999993
# Random Forest validation for article_id 599502001: RMSE=0.07727176894554194, MAE=0.07194261328970215
# Random Forest validation for article_id 743594003: RMSE=0.07970933735247886, MAE=0.06034351324857147
# Random Forest validation for article_id 253448001: RMSE=0.14044191507682652, MAE=0.11177482295366023
# Random Forest validation for article_id 775825001: RMSE=1.3654561417600835, MAE=1.3605322428057103
# Random Forest validation for article_id 712587004: RMSE=0.025666710718248182, MAE=0.019661579881108
# Random Forest validation for article_id 745475002: RMSE=0.3716586317600492, MAE=0.3704881773107195
# Random Forest validation for article_id 571706001: RMSE=0.054370326442757445, MAE=0.04282673508192176
# Random Forest validation for article_id 590928011: RMSE=0.014719168272037822, MAE=0.010910259512111121
# Random Forest validation for article_id 748269003: RMSE=0.11340075184074547, MAE=0.10386718724398795
# Random Forest validation for article_id 697031001: RMSE=0.03781302935443761, MAE=0.033996876313095274
# Random Forest validation for article_id 772832001: RMSE=0.28848865978661153, MAE=0.24955268063409977
# Random Forest validation for article_id 557994003: RMSE=0.050397502167025716, MAE=0.03345823259714286
# Random Forest validation for article_id 455832001: RMSE=0.06196192664830607, MAE=0.05298372527853584
# Random Forest validation for article_id 771829005: RMSE=0.12444378188157042, MAE=0.10960435475000001
# Random Forest validation for article_id 639151001: RMSE=0.0941802106475504, MAE=0.08909043017321391
# Random Forest validation for article_id 812207002: RMSE=0.5785597096871659, MAE=0.5510401551976188
# Random Forest validation for article_id 675068002: RMSE=0.0715630436950991, MAE=0.06169010692857164
# Random Forest validation for article_id 730863005: RMSE=0.20281485960218554, MAE=0.13016063468840403
# Random Forest validation for article_id 399223034: RMSE=0.6257664556728665, MAE=0.6182011947006278
# Random Forest validation for article_id 399201026: RMSE=0.052885743923702065, MAE=0.048431716628956116
# Random Forest validation for article_id 429313006: RMSE=0.09557850643611032, MAE=0.07861699294637635
# Random Forest validation for article_id 736870001: RMSE=0.1151737450367416, MAE=0.09518386844214284
# Random Forest validation for article_id 624486001: RMSE=0.06265069976115543, MAE=0.049878869287689795
# Random Forest validation for article_id 685814033: RMSE=0.2588545680907131, MAE=0.21381701125476532
# Random Forest validation for article_id 537346026: RMSE=0.0984320603967101, MAE=0.09742865115149532
# Random Forest validation for article_id 688105003: RMSE=0.08758006466073437, MAE=0.0748245690190392
# Random Forest validation for article_id 664319021: RMSE=0.025185785234654597, MAE=0.023674114938571595
# Random Forest validation for article_id 803468002: RMSE=0.16693963708621493, MAE=0.13715377776716514
# Random Forest validation for article_id 589599047: RMSE=0.02385378703892767, MAE=0.019559171602131876
# Random Forest validation for article_id 781613001: RMSE=0.18800920237062899, MAE=0.1850434517999998
# Random Forest validation for article_id 719957006: RMSE=0.19673111238051547, MAE=0.1699027640442845
# Random Forest validation for article_id 692632001: RMSE=0.2625277522829222, MAE=0.2590496896214289
# Random Forest validation for article_id 469137001: RMSE=0.35230664248705973, MAE=0.3517382260769926
# Random Forest validation for article_id 806388002: RMSE=0.04951009887171426, MAE=0.03847042982742853
# Random Forest validation for article_id 708311001: RMSE=0.1719797081923918, MAE=0.12061974364383074
# Random Forest validation for article_id 680264001: RMSE=0.05094048683449175, MAE=0.045206251831736446
# Random Forest validation for article_id 562245004: RMSE=0.0781318230871282, MAE=0.07505325462949008
# Random Forest validation for article_id 698276004: RMSE=0.2885811018088364, MAE=0.24711760048855222
# Random Forest validation for article_id 812167002: RMSE=0.4412389070910713, MAE=0.438309294242857
# Random Forest validation for article_id 762846007: RMSE=0.3160075761127564, MAE=0.21823823748371413
# Random Forest validation for article_id 772829001: RMSE=1.8083709870874982, MAE=1.7813189621889725
# Random Forest validation for article_id 811777001: RMSE=0.3553336123727357, MAE=0.29987613927143036
# Random Forest validation for article_id 698718002: RMSE=0.06741602227801934, MAE=0.04219619718906038
# Random Forest validation for article_id 771829002: RMSE=0.6754639894475338, MAE=0.6684914193999995
# Random Forest validation for article_id 399087021: RMSE=0.07182791878313757, MAE=0.05460393743513673
# Random Forest validation for article_id 572998002: RMSE=0.0684094836928915, MAE=0.06322911942857161
# Random Forest validation for article_id 806388001: RMSE=0.1113171103595329, MAE=0.08520566379142865
# Random Forest validation for article_id 573716050: RMSE=0.06815223246879144, MAE=0.06471422562348868
# Random Forest validation for article_id 537688010: RMSE=1.7429769319853325, MAE=1.7419708516382018
# Random Forest validation for article_id 673799001: RMSE=0.01963110558066502, MAE=0.01720392338928569
# Random Forest validation for article_id 756322001: RMSE=0.06423951514870356, MAE=0.05390035903177561
# Random Forest validation for article_id 716672003: RMSE=0.1171896789387338, MAE=0.1166949200653187
# Random Forest validation for article_id 687704039: RMSE=0.2503490463808427, MAE=0.20250665250000002
# Random Forest validation for article_id 827637001: RMSE=1.8659521067543707, MAE=1.843873912143814
# Random Forest validation for article_id 723469002: RMSE=0.10909771750392999, MAE=0.08746070094428614
# Random Forest validation for article_id 563519008: RMSE=0.19640430064579906, MAE=0.19490205192844678
# Random Forest validation for article_id 662948003: RMSE=0.393611454854352, MAE=0.39325012372175616
# Random Forest validation for article_id 660599016: RMSE=0.1643606168405712, MAE=0.15622087935430137
# Random Forest validation for article_id 591334003: RMSE=0.03046305422915247, MAE=0.023905337549119027
# Random Forest validation for article_id 688432001: RMSE=0.0257968103921785, MAE=0.020121806331785723
# Random Forest validation for article_id 700701001: RMSE=0.08360097899923241, MAE=0.05944020940824425
# Random Forest validation for article_id 736489003: RMSE=0.06167541868153387, MAE=0.0504424194703222
# Random Forest validation for article_id 640542002: RMSE=0.06823782972898262, MAE=0.056008970549193626
# Random Forest validation for article_id 660599001: RMSE=0.04968862004989189, MAE=0.037003631892857144
# Random Forest validation for article_id 519583008: RMSE=0.09198167224302588, MAE=0.08427165238480941
# Random Forest validation for article_id 552716001: RMSE=0.13795907151353382, MAE=0.11680872779394569
# Random Forest validation for article_id 780297001: RMSE=0.05402906046348166, MAE=0.05226641081643623
# Random Forest validation for article_id 750330002: RMSE=0.05209107247785838, MAE=0.03871268950765023
# Random Forest validation for article_id 692930001: RMSE=0.048866260034842686, MAE=0.0460321096384027
# Random Forest validation for article_id 534164001: RMSE=0.12449462460883978, MAE=0.11042135071474558
# Random Forest validation for article_id 687704028: RMSE=0.8126119376456652, MAE=0.8025729494278225
# Random Forest validation for article_id 688873001: RMSE=0.028870607716130803, MAE=0.027688738863928593
# Random Forest validation for article_id 572797001: RMSE=0.07166610169526137, MAE=0.0529362488051112
# Random Forest validation for article_id 590928022: RMSE=0.25475457628643206, MAE=0.2049911620228571
# Random Forest validation for article_id 811198002: RMSE=0.08505701523931267, MAE=0.07951417611250004
# Random Forest validation for article_id 751664001: RMSE=0.3620219909287082, MAE=0.34358883172100013
# Random Forest validation for article_id 656719005: RMSE=0.02189601609955842, MAE=0.015638611922571682
# Random Forest validation for article_id 547780003: RMSE=0.11680456992346185, MAE=0.10143855941250832
# Random Forest validation for article_id 801512004: RMSE=0.3668212956010351, MAE=0.33415593545204997
# Random Forest validation for article_id 796210010: RMSE=0.3178175972118223, MAE=0.2751451883385087
# Random Forest validation for article_id 670655001: RMSE=0.3072559474385396, MAE=0.3061882213788191
# Random Forest validation for article_id 564786001: RMSE=0.06043464312055184, MAE=0.04695406749928568
# Random Forest validation for article_id 772822001: RMSE=1.0297401457933426, MAE=1.0260013702999962
# Random Forest validation for article_id 738943005: RMSE=0.2408489769180196, MAE=0.23874720132857144
# Random Forest validation for article_id 754238001: RMSE=0.20824298200032676, MAE=0.1801309938295997
# Random Forest validation for article_id 156231001: RMSE=0.1057980237161881, MAE=0.087948581182143
# Random Forest validation for article_id 301656026: RMSE=0.12192215906063136, MAE=0.10313459396837198
# Random Forest validation for article_id 624257003: RMSE=0.17561971334494866, MAE=0.15735392723836727
# Random Forest validation for article_id 559634009: RMSE=0.17319271557471422, MAE=0.17276886166484534
# Random Forest validation for article_id 821031002: RMSE=0.6601420449410531, MAE=0.6533662025285703
# Random Forest validation for article_id 751941002: RMSE=0.020953829621201906, MAE=0.01988242121571429
# Random Forest validation for article_id 704668001: RMSE=0.3850970753207021, MAE=0.38335495195861097
# Random Forest validation for article_id 573085033: RMSE=0.37530768603519943, MAE=0.3720176238685749
# Random Forest validation for article_id 689109003: RMSE=0.013348455970574232, MAE=0.008352710615857144
# Random Forest validation for article_id 837941001: RMSE=0.24829839371597565, MAE=0.20673182971527157
# Random Forest validation for article_id 735583001: RMSE=0.029430877132193105, MAE=0.019551420411257847
# Random Forest validation for article_id 470789001: RMSE=0.044818432738319175, MAE=0.03812163515770928
# Random Forest validation for article_id 534357002: RMSE=0.041074596631826804, MAE=0.03189309747142859
# Random Forest validation for article_id 684341001: RMSE=0.017641869752850006, MAE=0.012227239509427815
# Random Forest validation for article_id 688558001: RMSE=0.04303427458706374, MAE=0.03437624204628558
# Random Forest validation for article_id 622958003: RMSE=0.0888312074570685, MAE=0.07158859461979454
# Random Forest validation for article_id 750422018: RMSE=0.20380651646762593, MAE=0.15140419928185642
# Random Forest validation for article_id 755362003: RMSE=1.7887484730676515, MAE=1.785550149317667
# Random Forest validation for article_id 787148001: RMSE=0.3913569041899739, MAE=0.3337414879789726
# Random Forest validation for article_id 744180001: RMSE=0.06990363676034028, MAE=0.0654324056607144
# Random Forest validation for article_id 559633008: RMSE=0.22830520360287646, MAE=0.19538038485563233
# Random Forest validation for article_id 801309002: RMSE=0.26584791909263394, MAE=0.2560369411599974
# Random Forest validation for article_id 678686001: RMSE=0.0765684156213618, MAE=0.07376156709605687
# Random Forest validation for article_id 717727002: RMSE=0.2096371627786728, MAE=0.20898396473571407
# Random Forest validation for article_id 559616013: RMSE=0.2856537930938689, MAE=0.28557509607500026
# Random Forest validation for article_id 661794006: RMSE=0.1165225007024243, MAE=0.10339183085714287
# Random Forest validation for article_id 799742003: RMSE=1.0418688264293912, MAE=1.0370230418047657
# Random Forest validation for article_id 727029001: RMSE=0.03819448512311567, MAE=0.02992731372339285
# Random Forest validation for article_id 719530004: RMSE=0.36159838660552607, MAE=0.28615640217051735
# Random Forest validation for article_id 707269003: RMSE=0.2742683666143068, MAE=0.26489513620714294
# Random Forest validation for article_id 786752001: RMSE=0.3371727112803879, MAE=0.3247198756185031
# Random Forest validation for article_id 656719015: RMSE=0.049525649072339896, MAE=0.043123462757142884
# Random Forest validation for article_id 714807004: RMSE=0.13822460573279918, MAE=0.11720405285644843
# Random Forest validation for article_id 787049001: RMSE=1.011169247567586, MAE=1.007708737235716
# Random Forest validation for article_id 554450005: RMSE=0.04518364827409838, MAE=0.03496913198364695
# Random Forest validation for article_id 739144004: RMSE=0.027878486221395618, MAE=0.016693123500571463
# Random Forest validation for article_id 534181010: RMSE=4.588388231217467, MAE=4.5864220906482105
# Random Forest validation for article_id 779842001: RMSE=0.21679999936091135, MAE=0.19564367300357116
# Random Forest validation for article_id 697091002: RMSE=0.03014169940115309, MAE=0.025533291785714285
# Random Forest validation for article_id 649437002: RMSE=0.03655504194115538, MAE=0.019918776907071407
# Random Forest validation for article_id 756633001: RMSE=0.042336171488613926, MAE=0.029667941881428576
# Random Forest validation for article_id 668537002: RMSE=0.5874932083019789, MAE=0.586661770906419
# Random Forest validation for article_id 673901001: RMSE=0.06998188213677822, MAE=0.0690907138142858
# Random Forest validation for article_id 785018003: RMSE=0.2156384131337298, MAE=0.18724339752857166
# Random Forest validation for article_id 708705004: RMSE=0.4613325262836104, MAE=0.449543913244043
# Random Forest validation for article_id 700701002: RMSE=0.08467126694539205, MAE=0.06962671714281211
# Random Forest validation for article_id 537346013: RMSE=0.25793171073151233, MAE=0.2567441272253732
# Random Forest validation for article_id 827635002: RMSE=0.20095522906467303, MAE=0.16522530542735384
# Random Forest validation for article_id 738943003: RMSE=0.12136863285225688, MAE=0.11712061634999979
# Random Forest validation for article_id 671852003: RMSE=0.040159728100914276, MAE=0.03129024672519183
# Random Forest validation for article_id 720125004: RMSE=0.09882031007399754, MAE=0.09576040391828654
# Random Forest validation for article_id 607154001: RMSE=0.023832724344990938, MAE=0.018684026539704773
# Random Forest validation for article_id 684340002: RMSE=0.03649540492033077, MAE=0.025389823745809507
# Random Forest validation for article_id 621381016: RMSE=0.1558364906138021, MAE=0.14194750568622258
# Random Forest validation for article_id 189616006: RMSE=0.17340426872619147, MAE=0.16732869450432403
# Random Forest validation for article_id 680262010: RMSE=0.043722462507273026, MAE=0.043025206212724744
# Random Forest validation for article_id 457892003: RMSE=0.1532166442511633, MAE=0.14264308747979834
# Random Forest validation for article_id 562245064: RMSE=0.01765246445418663, MAE=0.013194915
# Random Forest validation for article_id 662948012: RMSE=0.053587783151210405, MAE=0.048938651287143274
# Random Forest validation for article_id 748355002: RMSE=1.6604708576326024, MAE=1.657348705853433
# Random Forest validation for article_id 806388003: RMSE=0.05245412394622692, MAE=0.037290331625483675
# Random Forest validation for article_id 684080001: RMSE=0.960697565447734, MAE=0.9600547370107128
# Random Forest validation for article_id 731644001: RMSE=0.32154421948822587, MAE=0.32104454941733057
# Random Forest validation for article_id 448515001: RMSE=0.1167245731813035, MAE=0.09304492876926591
# Random Forest validation for article_id 732842004: RMSE=0.06059878853979001, MAE=0.045386575340194746
# Random Forest validation for article_id 733123004: RMSE=0.2717532044558111, MAE=0.2710662922014266
# Random Forest validation for article_id 700851001: RMSE=0.153102913821523, MAE=0.152253926851404
# Random Forest validation for article_id 702790003: RMSE=0.07553012918637764, MAE=0.07473798950508341
# Random Forest validation for article_id 678965001: RMSE=0.08079896735550011, MAE=0.07755008229890002
# Random Forest validation for article_id 758049001: RMSE=0.042105840914318, MAE=0.03769054621999989
# ...
# Random Forest validation for article_id 793856005: RMSE=0.386933161761102, MAE=0.38272132453571445
# Random Forest validation for article_id 669682006: RMSE=0.09484790664879394, MAE=0.09254222004464355
# Random Forest validation for article_id 816933001: RMSE=0.20772128728248634, MAE=0.17569039173775505
# Random Forest validation for article_id 524529010: RMSE=0.7307705785114539, MAE=0.7304943283917578
# Random Forest validation for article_id 789301001: RMSE=0.2615106841402065, MAE=0.26024602008809533
# Random Forest validation for article_id 755738001: RMSE=0.06379702260552265, MAE=0.060984777192106106
# Random Forest validation for article_id 718086003: RMSE=0.07317293830909509, MAE=0.05025241273272403
# Random Forest validation for article_id 665481013: RMSE=0.307371269740575, MAE=0.25373016315795927
# Random Forest validation for article_id 684824001: RMSE=0.02572497701969277, MAE=0.017723951222142997
# Random Forest validation for article_id 712924008: RMSE=0.009830292762426173, MAE=0.008271424327285755
# Random Forest validation for article_id 698387003: RMSE=0.08975584564362438, MAE=0.08439153215214108
# Random Forest validation for article_id 701046001: RMSE=0.02674520679876539, MAE=0.023234888703021893
# Random Forest validation for article_id 598859009: RMSE=0.1429406920739992, MAE=0.13704807195535687
# Random Forest validation for article_id 637566007: RMSE=0.03967114114536563, MAE=0.029718620285714266
# Random Forest validation for article_id 669715001: RMSE=0.34098854804621187, MAE=0.339893179426192
# Random Forest validation for article_id 790791002: RMSE=0.0436354839541949, MAE=0.03164543643214261
# Random Forest validation for article_id 722437003: RMSE=0.02313987764630605, MAE=0.02232099478964277
# Random Forest validation for article_id 788324008: RMSE=0.23946282052371456, MAE=0.23883830551883362
# Random Forest validation for article_id 775996015: RMSE=0.12267300314585902, MAE=0.1207258878899995
# Random Forest validation for article_id 824999001: RMSE=0.18880755520900333, MAE=0.15843163924553388
# Random Forest validation for article_id 706016028: RMSE=0.09981998121047969, MAE=0.0941828756996906
# Random Forest validation for article_id 761406001: RMSE=0.3662324403303079, MAE=0.36489157453285825
# Random Forest validation for article_id 794779001: RMSE=0.17707972930026478, MAE=0.17207258100219894
# Random Forest validation for article_id 705974001: RMSE=0.06927918895396372, MAE=0.06378454858571468
# Random Forest validation for article_id 772149001: RMSE=0.01993489056484994, MAE=0.01825636993227242
# Random Forest validation for article_id 676539001: RMSE=0.035689460309607256, MAE=0.02270798452447758
# Random Forest validation for article_id 685150002: RMSE=0.08051122877831957, MAE=0.07866579984387803
# Random Forest validation for article_id 787147002: RMSE=1.2733876944378113, MAE=1.270768530353105
# Random Forest validation for article_id 763037001: RMSE=0.04481677695511827, MAE=0.035321530094540456
# Random Forest validation for article_id 556260001: RMSE=0.06504605837524294, MAE=0.04611104273592518
# Random Forest validation for article_id 606395006: RMSE=0.060370994105316364, MAE=0.051825953384455836
# Random Forest validation for article_id 456163048: RMSE=0.6987346639204703, MAE=0.698408946807142
# Random Forest validation for article_id 783444001: RMSE=0.17663411866412257, MAE=0.17573056739571302
# Random Forest validation for article_id 395127011: RMSE=0.03283605647024501, MAE=0.026278322503595214
# Random Forest validation for article_id 639258002: RMSE=0.044926624977730416, MAE=0.02925529222857152
# Random Forest validation for article_id 687704027: RMSE=0.19991688635432556, MAE=0.1543331856785431
# Random Forest validation for article_id 706016011: RMSE=0.03541077141114871, MAE=0.027555926545398585
# Random Forest validation for article_id 676990001: RMSE=0.17416866212116497, MAE=0.17289377249904733
# Random Forest validation for article_id 784926001: RMSE=0.060692907468191816, MAE=0.052698147291428646
# Random Forest validation for article_id 670752002: RMSE=0.09584078864853142, MAE=0.09128331633093467
# Random Forest validation for article_id 794395001: RMSE=0.23867532967782912, MAE=0.2378811376285718
# Random Forest validation for article_id 781608001: RMSE=0.3280402937739208, MAE=0.32029481878428623
# Random Forest validation for article_id 770857003: RMSE=0.25787307434677736, MAE=0.2523541744071424
# Random Forest validation for article_id 756132001: RMSE=0.038058550815911245, MAE=0.0357818446381564
# Random Forest validation for article_id 744893006: RMSE=0.2946950333586421, MAE=0.29281947058999924
# Random Forest validation for article_id 501820003: RMSE=0.004734407400548467, MAE=0.0036400785944205663
# Random Forest validation for article_id 787696004: RMSE=0.14121079623993602, MAE=0.13809293146590082
# Random Forest validation for article_id 562245025: RMSE=0.030861048328958415, MAE=0.02468657856912885
# Random Forest validation for article_id 759814010: RMSE=0.13969965917959654, MAE=0.10709044698285726
# Random Forest validation for article_id 714825002: RMSE=0.12510039629747854, MAE=0.1243133039347062
# Random Forest validation for article_id 616708006: RMSE=0.05673858569981766, MAE=0.02891849179469246
# Random Forest validation for article_id 844059001: RMSE=0.12426875285227153, MAE=0.11229806203000006
# Random Forest validation for article_id 696209004: RMSE=0.013771118792032688, MAE=0.011559156913857166
# Random Forest validation for article_id 675070002: RMSE=0.011123465580391142, MAE=0.009817844891000014
# Random Forest validation for article_id 776237003: RMSE=0.020509649226268904, MAE=0.016893262443928577
# Random Forest validation for article_id 791571003: RMSE=0.5407638339921707, MAE=0.5330578529921663
# Random Forest validation for article_id 694182004: RMSE=0.08390073833882647, MAE=0.0764481046799628
# Random Forest validation for article_id 577648001: RMSE=0.06281099789416428, MAE=0.06260361829285771
# Random Forest validation for article_id 797065001: RMSE=0.23508265745879248, MAE=0.22621006525599482
# Random Forest validation for article_id 708379004: RMSE=0.3074737751946113, MAE=0.3071538949700657
# Random Forest validation for article_id 734435002: RMSE=0.1823364070540991, MAE=0.18081686855739165
# Random Forest validation for article_id 569984001: RMSE=0.02985958842648422, MAE=0.023454893102381327
# Random Forest validation for article_id 807329002: RMSE=0.1465912665150883, MAE=0.1354966014945128
# Random Forest validation for article_id 732511002: RMSE=0.10992791411782855, MAE=0.10277921040544832
# Random Forest validation for article_id 637667002: RMSE=0.16782723421771154, MAE=0.16656988835290437
# Random Forest validation for article_id 748566004: RMSE=0.03050805371623649, MAE=0.016704799832857165
# Random Forest validation for article_id 661435002: RMSE=0.318066732818421, MAE=0.316683396521428
# Random Forest validation for article_id 733101002: RMSE=0.26172899079422657, MAE=0.26069177887283057
# Random Forest validation for article_id 637566006: RMSE=0.26202134566638474, MAE=0.26164404813571457
# Random Forest validation for article_id 695545008: RMSE=0.9838784813881656, MAE=0.9338562689642849
# Random Forest validation for article_id 706371001: RMSE=0.056079399304011374, MAE=0.05296049682612249
# Random Forest validation for article_id 837325001: RMSE=1.5355301182736434, MAE=1.5341254311940478
# Random Forest validation for article_id 781608002: RMSE=0.2979657262224903, MAE=0.2809052786777909
# Random Forest validation for article_id 697054002: RMSE=0.02515341318792199, MAE=0.02392825254887754
# Random Forest validation for article_id 668004001: RMSE=2.054118327589272, MAE=2.049109628534723
# Random Forest validation for article_id 767869001: RMSE=0.07832501935390478, MAE=0.07119470288571297
# Random Forest validation for article_id 762286001: RMSE=0.19678514288063895, MAE=0.1931305138170438
# Random Forest validation for article_id 768419001: RMSE=0.5843675852783373, MAE=0.5834607024694065
# Random Forest validation for article_id 744072002: RMSE=0.08456455599716942, MAE=0.05967163871971414
# Random Forest validation for article_id 737852001: RMSE=0.3216856999888254, MAE=0.3215109602214286
# Random Forest validation for article_id 687948001: RMSE=0.11358282446060479, MAE=0.09723797121446634
# Random Forest validation for article_id 695632007: RMSE=0.07422669735683571, MAE=0.07101599826535694
# Random Forest validation for article_id 844915003: RMSE=0.27665259338122955, MAE=0.25040291848571405
# Random Forest validation for article_id 794575003: RMSE=0.07629978159556855, MAE=0.047716761816764916
# Random Forest validation for article_id 571092001: RMSE=0.017183912267498304, MAE=0.013259325109020554
# Random Forest validation for article_id 662888005: RMSE=1.173245441731503, MAE=1.1724770608372135
# Random Forest validation for article_id 775996012: RMSE=0.03942967785624989, MAE=0.03403247499250002
# Random Forest validation for article_id 809961001: RMSE=0.14339313482839647, MAE=0.12368674641856994
# Random Forest validation for article_id 637549005: RMSE=0.31075159747787745, MAE=0.3073888973928564
# Random Forest validation for article_id 778534001: RMSE=0.3921268889812951, MAE=0.39153419725523786
# Random Forest validation for article_id 733027005: RMSE=0.017168692175710976, MAE=0.015703534320510748
# Random Forest validation for article_id 399223068: RMSE=0.2424972362683424, MAE=0.22312685768571477
# Random Forest validation for article_id 351933051: RMSE=0.043459256591282316, MAE=0.034031452243494915
# Random Forest validation for article_id 399223059: RMSE=0.07224007295741086, MAE=0.06707611806753337
# Random Forest validation for article_id 717816001: RMSE=0.07105221948749416, MAE=0.055526803082857144
# Random Forest validation for article_id 669605003: RMSE=0.022402170411776, MAE=0.02165253796011653
# Random Forest validation for article_id 717664001: RMSE=0.046093655324825275, MAE=0.044283011880634895
# Random Forest validation for article_id 618287006: RMSE=0.24194268572041247, MAE=0.22841174104006035
# Random Forest validation for article_id 714750001: RMSE=0.04655501176810516, MAE=0.045432282415377
# Random Forest validation for article_id 624486005: RMSE=0.012227475888438076, MAE=0.009167804570630387
# Random Forest validation for article_id 767438002: RMSE=0.03485068234254955, MAE=0.034033713225865674
# Random Forest validation for article_id 788107006: RMSE=0.45298131629566063, MAE=0.37766127077510714
# Random Forest validation for article_id 636323005: RMSE=0.01782369388543071, MAE=0.015750079881244182
# Random Forest validation for article_id 637283007: RMSE=0.15840969296463314, MAE=0.15161505365142852
# Random Forest validation for article_id 495685003: RMSE=0.4222650173169485, MAE=0.41987487043571026
# Random Forest validation for article_id 718582002: RMSE=0.20373697327591922, MAE=0.1886944849657148
# Random Forest validation for article_id 750398005: RMSE=0.03357503526766413, MAE=0.030162876267999957
# Random Forest validation for article_id 744862004: RMSE=0.030316806352049266, MAE=0.029169342665143278
# Random Forest validation for article_id 760449001: RMSE=0.35939688038507434, MAE=0.31496229612857096
# Random Forest validation for article_id 695318002: RMSE=0.1319215215858052, MAE=0.13141253919164173
# Random Forest validation for article_id 540768012: RMSE=0.019100974121413764, MAE=0.013794067248898301
# Random Forest validation for article_id 696733001: RMSE=0.06196756795505592, MAE=0.05797328102198292
# Random Forest validation for article_id 689005002: RMSE=0.04281177125989325, MAE=0.0260229760176743
# Random Forest validation for article_id 661806003: RMSE=0.06449465477173545, MAE=0.059699924864384184
# Random Forest validation for article_id 666382014: RMSE=0.5184281864032031, MAE=0.5173693661524118
# Random Forest validation for article_id 820563001: RMSE=0.419385351803811, MAE=0.4187185520931568
# Random Forest validation for article_id 569929001: RMSE=0.84302607221633, MAE=0.8421565018354727
# Random Forest validation for article_id 700515002: RMSE=0.225966447736875, MAE=0.2223336860249836
# Random Forest validation for article_id 831218001: RMSE=0.3409165895982212, MAE=0.335477355455957
# Random Forest validation for article_id 650122004: RMSE=0.05110533483335933, MAE=0.04615816587581629
# Random Forest validation for article_id 399201031: RMSE=0.16365124863906405, MAE=0.15715905320278376
# Random Forest validation for article_id 599580049: RMSE=0.13856875307394595, MAE=0.11554140781930748
# Random Forest validation for article_id 788651001: RMSE=0.18970762823802895, MAE=0.1872463115531746
# Random Forest validation for article_id 662868002: RMSE=0.1470715325537391, MAE=0.14317745010999997
# Random Forest validation for article_id 724905008: RMSE=0.11226393389712767, MAE=0.0797321816142857
# Random Forest validation for article_id 704630003: RMSE=0.04671694213857396, MAE=0.04354975470319268
# Random Forest validation for article_id 784143001: RMSE=0.09575625718962533, MAE=0.07537685270870731
# Random Forest validation for article_id 694127001: RMSE=0.21035444691063562, MAE=0.20983448570507274
# Random Forest validation for article_id 712711001: RMSE=0.06057616002481537, MAE=0.05740372821158255
# Random Forest validation for article_id 779889001: RMSE=0.11164107012087633, MAE=0.10892239850171358
# Random Forest validation for article_id 610776028: RMSE=0.03716185085421266, MAE=0.028836912797857005
# Random Forest validation for article_id 693479002: RMSE=0.0339550781947024, MAE=0.031467801953999876
# Random Forest validation for article_id 436083001: RMSE=0.10301808884922248, MAE=0.10180936189464307
# Random Forest validation for article_id 707699001: RMSE=0.03242095697488977, MAE=0.030283695296504244
# Random Forest validation for article_id 456163009: RMSE=0.03969132222099566, MAE=0.03438652896037414
# Random Forest validation for article_id 660599003: RMSE=0.14199413367334396, MAE=0.1350527210785712
# Random Forest validation for article_id 704126003: RMSE=0.016985900200845477, MAE=0.015487215730285428
# Random Forest validation for article_id 758642001: RMSE=0.4200050580388308, MAE=0.4194471853000003
# Random Forest validation for article_id 794793001: RMSE=0.1750471291062155, MAE=0.17123342960505905
# Random Forest validation for article_id 697060014: RMSE=0.015768483514663593, MAE=0.013383414382142857
# Random Forest validation for article_id 754323004: RMSE=0.35858413166450454, MAE=0.35723038324285705
# Random Forest validation for article_id 619884007: RMSE=0.02187255458957681, MAE=0.019979007444285702
# Random Forest validation for article_id 746888001: RMSE=0.16925519938852263, MAE=0.16731913857275074
# Random Forest validation for article_id 741478003: RMSE=0.15329977802938125, MAE=0.15224108220714258
# Random Forest validation for article_id 779656002: RMSE=0.6308459450405118, MAE=0.6303171731033982
# Random Forest validation for article_id 685848008: RMSE=0.14597185560466017, MAE=0.14570946108871932
# Random Forest validation for article_id 828991001: RMSE=0.08607510567508264, MAE=0.06376796491428573
# Random Forest validation for article_id 689572001: RMSE=0.047826164559255716, MAE=0.03668945402789552
# Random Forest validation for article_id 684686001: RMSE=0.0633404254175703, MAE=0.05941847911988204
# Random Forest validation for article_id 772927001: RMSE=0.16347180674778608, MAE=0.1622249816085713
# Random Forest validation for article_id 768440001: RMSE=0.015614398711759537, MAE=0.011377243455273644
# Random Forest validation for article_id 796239001: RMSE=0.09137061546381851, MAE=0.08706353352142858
# Random Forest validation for article_id 710708005: RMSE=0.03634112439372069, MAE=0.03302205710714308
# Random Forest validation for article_id 312878010: RMSE=0.13970286554780606, MAE=0.1260132626758644
# Random Forest validation for article_id 682520002: RMSE=0.15889006585357796, MAE=0.15810473550000048
# Random Forest validation for article_id 554450035: RMSE=0.04096966386898115, MAE=0.03529444774580946
# Random Forest validation for article_id 660712014: RMSE=0.016711384874353218, MAE=0.016134688304585778
# Random Forest predictions and validation tables with time information created successfully!

# %%
# RANDOM FOREST WITH 30 DAYS AND 30% ITEMS

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # Suppress non-critical warnings

# Ensure `sale_date` is in datetime format and filter for dates up to the end of February 2020
seasonal_data['sale_date'] = pd.to_datetime(seasonal_data['sale_date'])
seasonal_data = seasonal_data[seasonal_data['sale_date'] <= '2020-02-29']

# List of top 30% selling article IDs
top_30_percent = int(len(total_sales_id_sorted) * 0.3)
top_sample_article_ids = total_sales_id_sorted.head(top_30_percent)['article_id'].values

# Step 1: Filter `top_sample_article_ids` to include only those present in `item_params_final`
filtered_sample_ids = [article_id for article_id in top_sample_article_ids if article_id in item_params_final['article_id'].values]

# Step 2: Filter `seasonal_data` to include only items in the filtered sample
sampled_data = seasonal_data[seasonal_data['article_id'].isin(filtered_sample_ids)]

# Initialize dictionaries to store predictions and validation metrics
predictions_30_days = {}
validation_results = []

# Set default parameters for items without specific tuning information (if applicable)
default_params = {
    'max_depth': 10,
    'min_samples_split': 2,
    'n_estimators': 100
}

# Loop through each article in the filtered sampled set and apply Random Forest with validation
for article_id in filtered_sample_ids:
    # Filter data for the current article_id
    article_data = sampled_data[sampled_data['article_id'] == article_id]
    
    # Sort data by `sale_date`, set it as index
    article_data = article_data.set_index('sale_date').sort_index()
    article_data['total_sales'] = article_data['total_sales'].fillna(0)
    
    # Extract the time series for training
    ts_data = article_data['total_sales']
    
    # Check for sufficient data points
    if len(ts_data) < 60:  # Ensure at least 60 days of data for model stability
        continue
    
    # Fetch parameters for the current article_id from `item_params_final`
    params = item_params_final[item_params_final['article_id'] == article_id]

    # Use specific parameters if they exist, otherwise default to common ones
    if len(params) > 0:
        max_depth = int(params['max_depth'].values[0])
        min_samples_split = int(params['min_samples_split'].values[0])
        n_estimators = int(params['n_estimators'].values[0])
    else:
        max_depth = default_params['max_depth']
        min_samples_split = default_params['min_samples_split']
        n_estimators = default_params['n_estimators']
    
    # Define the RandomForest model with the selected parameters
    rf_model = RandomForestRegressor(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        n_estimators=n_estimators,
        random_state=42
    )
    
    # Split the data for validation: last 8 weeks (56 days)
    train_data = ts_data[:-56]  # All data except the last 8 weeks
    validation_data = ts_data[-56:]  # Last 8 weeks
    
    # Further split the last 8 weeks into 4-week training and 4-week validation sets
    rf_train = validation_data[:-28].values.reshape(-1, 1)  # First 4 weeks of the last 8 weeks
    rf_validation = validation_data[-28:].values  # Last 4 weeks of the last 8 weeks
    validation_dates = validation_data[-28:].index  # Dates for the validation period
    
    # Prepare target data for training
    y_train = train_data.values.reshape(-1, 1)
    
    # Fit the model on training data
    rf_model.fit(np.arange(len(y_train)).reshape(-1, 1), y_train.ravel())
    
    # Predict the next 30 days for forecasting using the trained model
    future_days = np.arange(len(y_train), len(y_train) + 30).reshape(-1, 1)
    forecast_30_days = rf_model.predict(future_days)
    predictions_30_days[article_id] = forecast_30_days
    
    # Validate the model on the 4-week validation period
    validation_days = np.arange(len(y_train), len(y_train) + 28).reshape(-1, 1)
    rf_validation_pred = rf_model.predict(validation_days)
    
    # Calculate RMSE and MAE on validation set
    rmse = np.sqrt(mean_squared_error(rf_validation, rf_validation_pred))
    mae = mean_absolute_error(rf_validation, rf_validation_pred)
    
    # Store each validation point with actual and predicted values, along with date
    for date, actual, predicted in zip(validation_dates, rf_validation, rf_validation_pred):
        validation_results.append({
            'article_id': article_id,
            'date': date,
            'total_sales': actual,
            'total_sales_predicted': predicted,
            'rmse': rmse,
            'mae': mae
        })

    print(f"Random Forest validation for article_id {article_id}: RMSE={rmse}, MAE={mae}")

# Convert predictions and validation results to DataFrames
forecast_df = pd.DataFrame(predictions_30_days).T  # Transpose so each article_id is a row
forecast_df.columns = [f"day_{i+1}" for i in range(30)]  # Rename columns for each forecasted day

validation_df = pd.DataFrame(validation_results)

# Save the results to CSV
forecast_df.to_csv("covid_30_rf_30_day_forecasts.csv", index=True)
validation_df.to_csv("covid_30_rf_30day_validation_results_with_dates.csv", index=False)

print("Random Forest predictions and validation tables with time information created successfully!")
# Out:
# Random Forest validation for article_id 706016002: RMSE=0.549808418080242, MAE=0.3862977507619038
# Random Forest validation for article_id 568601006: RMSE=0.38776462276093465, MAE=0.32003002935911057
# Random Forest validation for article_id 448509014: RMSE=1.028374212113053, MAE=0.8776318890539858
# Random Forest validation for article_id 720125001: RMSE=1.1723946052733083, MAE=1.0341467297999989
# Random Forest validation for article_id 399223001: RMSE=0.36394992445390006, MAE=0.31856117152246605
# Random Forest validation for article_id 706016003: RMSE=1.246453165835904, MAE=1.1560983521278203
# Random Forest validation for article_id 562245046: RMSE=0.31784391253613603, MAE=0.27608948279999945
# Random Forest validation for article_id 751471001: RMSE=1.0201915122973442, MAE=0.9483195091285718
# Random Forest validation for article_id 661794001: RMSE=1.5301947365688624, MAE=1.5091359147857162
# Random Forest validation for article_id 706016015: RMSE=0.2582770120799426, MAE=0.2025072741428571
# Random Forest validation for article_id 562245001: RMSE=0.4216610564096799, MAE=0.40036453377857073
# Random Forest validation for article_id 554450001: RMSE=0.17983064149085012, MAE=0.15565170547845925
# Random Forest validation for article_id 399201002: RMSE=0.8922515717681178, MAE=0.8237308391501211
# Random Forest validation for article_id 687704001: RMSE=0.3707257823703122, MAE=0.28218054571428575
# Random Forest validation for article_id 399136009: RMSE=0.054981669722809996, MAE=0.04529074478928575
# Random Forest validation for article_id 741356002: RMSE=0.1619173220952705, MAE=0.1417064291357051
# Random Forest validation for article_id 673677002: RMSE=1.0530206972940568, MAE=1.022663104285714
# Random Forest validation for article_id 590928001: RMSE=0.9890199172237886, MAE=0.9610614329228572
# Random Forest validation for article_id 372860001: RMSE=0.23556987643331118, MAE=0.16777909842001618
# Random Forest validation for article_id 706016006: RMSE=0.4396174979971173, MAE=0.41539071704571784
# Random Forest validation for article_id 568597006: RMSE=0.11660657708370482, MAE=0.09195732807857157
# Random Forest validation for article_id 730683001: RMSE=0.45358290547601193, MAE=0.3921290270000009
# Random Forest validation for article_id 448509001: RMSE=0.34557990148526835, MAE=0.28761003303372673
# Random Forest validation for article_id 562245018: RMSE=0.13861735342505513, MAE=0.1235060693785718
# Random Forest validation for article_id 568601007: RMSE=0.36001228420553827, MAE=0.29500069840801313
# Random Forest validation for article_id 464297007: RMSE=0.4877383412422612, MAE=0.45645731472986534
# Random Forest validation for article_id 399201022: RMSE=0.10149657627419476, MAE=0.06735203455794288
# Random Forest validation for article_id 661794002: RMSE=0.31074524203299014, MAE=0.26804060026160753
# Random Forest validation for article_id 351484002: RMSE=0.198527136284462, MAE=0.17550047842857078
# Random Forest validation for article_id 573716012: RMSE=0.17356330443205414, MAE=0.1682290513168236
# Random Forest validation for article_id 714790020: RMSE=0.2544690638617172, MAE=0.20512636848571456
# Random Forest validation for article_id 753737001: RMSE=0.46018650505105485, MAE=0.32209462601041977
# Random Forest validation for article_id 695632002: RMSE=0.1923144820598533, MAE=0.15781720256232457
# Random Forest validation for article_id 399201005: RMSE=0.05486910884805074, MAE=0.040640520430059515
# Random Forest validation for article_id 685814001: RMSE=0.26853494283120427, MAE=0.23339198384406337
# Random Forest validation for article_id 799365002: RMSE=0.4571015061428434, MAE=0.403217230789611
# Random Forest validation for article_id 484398001: RMSE=0.16076932876742456, MAE=0.14694515567857153
# Random Forest validation for article_id 732842001: RMSE=0.2749316155173941, MAE=0.2178236988820297
# Random Forest validation for article_id 732842002: RMSE=0.15240136048757558, MAE=0.12788922392857144
# Random Forest validation for article_id 714790003: RMSE=0.4230507998114608, MAE=0.3689037543267237
# Random Forest validation for article_id 695632001: RMSE=0.17911256105544146, MAE=0.14527542499999999
# Random Forest validation for article_id 534181002: RMSE=0.739791630731637, MAE=0.6943339865256458
# Random Forest validation for article_id 684209004: RMSE=0.2067766808914657, MAE=0.14375059653571426
# Random Forest validation for article_id 578476001: RMSE=0.23182430033511484, MAE=0.19676851074935517
# Random Forest validation for article_id 658030011: RMSE=0.17599051536539284, MAE=0.14186109945571437
# Random Forest validation for article_id 399061008: RMSE=0.17180160934244912, MAE=0.12145834799750004
# Random Forest validation for article_id 507909001: RMSE=0.11308768237301715, MAE=0.08738126026571377
# Random Forest validation for article_id 640021005: RMSE=0.12886493830755144, MAE=0.1163231336506423
# Random Forest validation for article_id 399201042: RMSE=0.4962929552822149, MAE=0.4006868271192873
# Random Forest validation for article_id 783346001: RMSE=0.4075049455962655, MAE=0.3674912940999149
# Random Forest validation for article_id 399256001: RMSE=0.16022863572377552, MAE=0.12465352685677512
# Random Forest validation for article_id 573085028: RMSE=0.6878047713247272, MAE=0.6457346474706835
# Random Forest validation for article_id 399136004: RMSE=0.0950155272886189, MAE=0.07606615002141673
# Random Forest validation for article_id 749699002: RMSE=0.16853610144299552, MAE=0.1549305647847497
# Random Forest validation for article_id 572998001: RMSE=0.9334309581299717, MAE=0.8927237515649555
# Random Forest validation for article_id 714790008: RMSE=0.2602669615144003, MAE=0.19260394351273447
# Random Forest validation for article_id 399223029: RMSE=0.37032627916468336, MAE=0.3611003730778403
# Random Forest validation for article_id 372860002: RMSE=0.1186697643601674, MAE=0.09145057743253161
# Random Forest validation for article_id 640021011: RMSE=0.1039957511100209, MAE=0.08297422675142856
# Random Forest validation for article_id 790006001: RMSE=0.4897040809414873, MAE=0.45748142682143067
# Random Forest validation for article_id 579302001: RMSE=0.1738896341633653, MAE=0.14200302714285715
# Random Forest validation for article_id 658030001: RMSE=0.2809249749485651, MAE=0.25653978027220165
# Random Forest validation for article_id 708705001: RMSE=0.20035334781585742, MAE=0.16465309656842844
# Random Forest validation for article_id 699080001: RMSE=0.20775453438330774, MAE=0.17369170303516998
# Random Forest validation for article_id 731160005: RMSE=0.3133869876991996, MAE=0.2743280204028905
# Random Forest validation for article_id 749699001: RMSE=0.10121022638198639, MAE=0.0743386068964285
# Random Forest validation for article_id 687704002: RMSE=0.38415120324178126, MAE=0.35186609367720745
# Random Forest validation for article_id 534181011: RMSE=0.23768667616256767, MAE=0.21315975502142842
# Random Forest validation for article_id 685814003: RMSE=0.3098770988461046, MAE=0.1992978232142857
# Random Forest validation for article_id 731160004: RMSE=0.11286749141722292, MAE=0.09794014399751753
# Random Forest validation for article_id 534181005: RMSE=0.07397312515748275, MAE=0.039323610592857126
# Random Forest validation for article_id 636455003: RMSE=0.0788375221920798, MAE=0.07046861858748986
# Random Forest validation for article_id 740519002: RMSE=0.24736419585535094, MAE=0.22042278445311939
# Random Forest validation for article_id 666006004: RMSE=0.934130910647532, MAE=0.9331921383185707
# Random Forest validation for article_id 562245050: RMSE=0.11213177268189142, MAE=0.08835677928000016
# Random Forest validation for article_id 554450027: RMSE=0.2559932330010665, MAE=0.24015303400458168
# Random Forest validation for article_id 539723005: RMSE=0.018901039485987748, MAE=0.015678873823214333
# Random Forest validation for article_id 781613006: RMSE=0.20601178060900702, MAE=0.19799879989285715
# Random Forest validation for article_id 312878001: RMSE=0.1284274729111875, MAE=0.10736098642142933
# Random Forest validation for article_id 724906006: RMSE=0.3993752258932535, MAE=0.347097822600623
# Random Forest validation for article_id 600886001: RMSE=0.48829200798948047, MAE=0.4658502131017143
# Random Forest validation for article_id 723469001: RMSE=0.19247222380338722, MAE=0.17011746230065564
# Random Forest validation for article_id 666006006: RMSE=0.24503410350636334, MAE=0.24316791875997817
# Random Forest validation for article_id 554450004: RMSE=0.196488735427866, MAE=0.17967609132315612
# Random Forest validation for article_id 688537004: RMSE=0.1904381363082422, MAE=0.16847603752080823
# Random Forest validation for article_id 658030020: RMSE=0.22598369714164532, MAE=0.18719257231714184
# Random Forest validation for article_id 673396002: RMSE=0.07485108424681174, MAE=0.06026750100000013
# Random Forest validation for article_id 579541001: RMSE=0.07727850250729194, MAE=0.06284883534644561
# Random Forest validation for article_id 618800001: RMSE=0.5014536073564605, MAE=0.49749264037571467
# Random Forest validation for article_id 568597007: RMSE=0.2341946484287837, MAE=0.18821238774913399
# Random Forest validation for article_id 684209013: RMSE=0.27702916438981245, MAE=0.2738081132857146
# Random Forest validation for article_id 399223033: RMSE=0.5157837522021039, MAE=0.4977529500222218
# Random Forest validation for article_id 573085004: RMSE=0.052967471479572356, MAE=0.041368479191861256
# Random Forest validation for article_id 448509018: RMSE=0.565240890729914, MAE=0.5052350769096903
# Random Forest validation for article_id 399136061: RMSE=0.7389205425853502, MAE=0.7246062351485671
# Random Forest validation for article_id 554479001: RMSE=0.11061067712227167, MAE=0.0894483204074714
# Random Forest validation for article_id 399136011: RMSE=0.11030217617118401, MAE=0.10173964216736335
# Random Forest validation for article_id 539723001: RMSE=0.05263270595051456, MAE=0.052008311489092275
# Random Forest validation for article_id 655784001: RMSE=0.14050364719639244, MAE=0.12174517856788837
# Random Forest validation for article_id 743616009: RMSE=0.4980555932517582, MAE=0.4606293974588011
# Random Forest validation for article_id 712587003: RMSE=0.023083756844420995, MAE=0.021075951571428612
# Random Forest validation for article_id 805000001: RMSE=0.2903870004046156, MAE=0.2426634976714265
# Random Forest validation for article_id 769748002: RMSE=0.6413879370266973, MAE=0.5271051774571506
# Random Forest validation for article_id 772774001: RMSE=2.3308716580131352, MAE=2.319428060544768
# Random Forest validation for article_id 507910001: RMSE=0.02142322054029471, MAE=0.01908373847579221
# Random Forest validation for article_id 720125007: RMSE=0.4634111995381792, MAE=0.42581619287404776
# Random Forest validation for article_id 554450036: RMSE=0.09787522811596305, MAE=0.08594149324819048
# Random Forest validation for article_id 756318001: RMSE=0.2813400329738131, MAE=0.22258720487394137
# Random Forest validation for article_id 762846001: RMSE=0.5667499922125393, MAE=0.5360598740149711
# Random Forest validation for article_id 573937001: RMSE=0.09625490449124675, MAE=0.08351170061071436
# Random Forest validation for article_id 399201020: RMSE=0.06076286199713902, MAE=0.05569240458889964
# Random Forest validation for article_id 487722001: RMSE=0.11407516624436488, MAE=0.09139761581080771
# Random Forest validation for article_id 719655001: RMSE=0.20112194011051251, MAE=0.18012743281655555
# Random Forest validation for article_id 608776002: RMSE=0.29916508094944577, MAE=0.26852570021058747
# Random Forest validation for article_id 736530007: RMSE=0.23664869363358873, MAE=0.18293368162280088
# Random Forest validation for article_id 599580017: RMSE=0.18972918599172006, MAE=0.16447071211057143
# Random Forest validation for article_id 827635001: RMSE=0.301450848650959, MAE=0.2448623850051554
# Random Forest validation for article_id 752814003: RMSE=0.6940069724078872, MAE=0.6500802826798309
# Random Forest validation for article_id 188183001: RMSE=0.24681066257669904, MAE=0.2448865861502126
# Random Forest validation for article_id 610776002: RMSE=0.13869293646935296, MAE=0.12841245127351297
# Random Forest validation for article_id 762846008: RMSE=0.6417725575830989, MAE=0.5796515067460868
# Random Forest validation for article_id 772829002: RMSE=1.1832219677981723, MAE=1.17035025014286
# Random Forest validation for article_id 716672001: RMSE=0.0974885182108107, MAE=0.09578794993206449
# Random Forest validation for article_id 573085043: RMSE=0.4626194828660476, MAE=0.4095474320685719
# Random Forest validation for article_id 179950001: RMSE=0.10883451236008597, MAE=0.08540608552657779
# Random Forest validation for article_id 680262001: RMSE=0.02704104976185145, MAE=0.01649091340464286
# Random Forest validation for article_id 658030006: RMSE=0.09938713753867942, MAE=0.07875938427490932
# Random Forest validation for article_id 554479005: RMSE=0.026402743638147267, MAE=0.01971755319168424
# Random Forest validation for article_id 723529001: RMSE=0.19657924130201337, MAE=0.17729731589285716
# Random Forest validation for article_id 715343003: RMSE=0.14571706549222163, MAE=0.11582022392857146
# Random Forest validation for article_id 399061028: RMSE=0.37024326689424336, MAE=0.32171105140111916
# Random Forest validation for article_id 715624001: RMSE=0.5262284983856618, MAE=0.49747334514116176
# Random Forest validation for article_id 399201024: RMSE=0.1094151295821654, MAE=0.10696908006172152
# Random Forest validation for article_id 598859001: RMSE=0.1966422665901424, MAE=0.19261211996692781
# Random Forest validation for article_id 668537001: RMSE=0.07865951017998922, MAE=0.07543035337142898
# Random Forest validation for article_id 678942001: RMSE=0.3143606267179448, MAE=0.2852549113185712
# Random Forest validation for article_id 656763001: RMSE=0.03868606654220415, MAE=0.028079102097133688
# Random Forest validation for article_id 621381001: RMSE=0.10422221505610682, MAE=0.0927852649568818
# Random Forest validation for article_id 636323001: RMSE=0.1334222181340785, MAE=0.11419211900285728
# Random Forest validation for article_id 621381012: RMSE=0.11040604484582617, MAE=0.09103862815215728
# Random Forest validation for article_id 658298001: RMSE=0.5633236713400998, MAE=0.555585082842858
# Random Forest validation for article_id 639192002: RMSE=1.1748525409231014, MAE=1.174123773558353
# Random Forest validation for article_id 624257001: RMSE=0.22194931285552305, MAE=0.17777859700214343
# Random Forest validation for article_id 484205004: RMSE=0.0765690308930962, MAE=0.07298905500475904
# Random Forest validation for article_id 728156006: RMSE=0.257345650242736, MAE=0.2047937473891696
# Random Forest validation for article_id 764155001: RMSE=0.09548426588104382, MAE=0.06490382432142858
# Random Forest validation for article_id 714790017: RMSE=0.20489453219718892, MAE=0.16343854670044622
# Random Forest validation for article_id 559633001: RMSE=0.023953427867040633, MAE=0.019569998878499337
# Random Forest validation for article_id 730683041: RMSE=0.9916409459543454, MAE=0.9197150437142865
# Random Forest validation for article_id 758084002: RMSE=0.07976118249183338, MAE=0.07276388921342938
# Random Forest validation for article_id 687704012: RMSE=0.95050645475247, MAE=0.9424816517006464
# Random Forest validation for article_id 690936003: RMSE=0.07430768690044366, MAE=0.06929757708356284
# Random Forest validation for article_id 502224001: RMSE=0.11766761395880919, MAE=0.11293149451170635
# Random Forest validation for article_id 722169001: RMSE=0.18575717737581143, MAE=0.16964290233857277
# Random Forest validation for article_id 639448001: RMSE=0.3712057620289554, MAE=0.3602385316146755
# Random Forest validation for article_id 399087014: RMSE=0.18886112966483545, MAE=0.17658009843249484
# Random Forest validation for article_id 578487002: RMSE=0.07107198170949253, MAE=0.06239346239642849
# Random Forest validation for article_id 568808001: RMSE=0.0902002941247838, MAE=0.07892258488600648
# Random Forest validation for article_id 690936006: RMSE=0.4701374760561928, MAE=0.46975238562399463
# Random Forest validation for article_id 278811006: RMSE=0.10962839394468094, MAE=0.08758033909285753
# Random Forest validation for article_id 708138002: RMSE=0.31982465690207296, MAE=0.256504114751818
# Random Forest validation for article_id 699081001: RMSE=0.10413506138769348, MAE=0.07560003978262506
# Random Forest validation for article_id 815851001: RMSE=0.6399858618543537, MAE=0.6165418959589958
# Random Forest validation for article_id 688537011: RMSE=0.03278863990167592, MAE=0.024209408515714254
# Random Forest validation for article_id 547780001: RMSE=0.5365258879249228, MAE=0.5154888292277129
# Random Forest validation for article_id 741040001: RMSE=0.2116133840619777, MAE=0.18030856434285722
# Random Forest validation for article_id 160442007: RMSE=0.05202620180799714, MAE=0.04515280607285711
# Random Forest validation for article_id 697031002: RMSE=0.11781159136595751, MAE=0.09255936472859323
# Random Forest validation for article_id 684209001: RMSE=0.09718884412419364, MAE=0.09480168266757073
# Random Forest validation for article_id 690936002: RMSE=0.04493601364287722, MAE=0.04126884100518368
# Random Forest validation for article_id 658298007: RMSE=0.10201411411336077, MAE=0.08676400793297613
# Random Forest validation for article_id 399136027: RMSE=0.09242543507646012, MAE=0.08462604702698359
# Random Forest validation for article_id 305931001: RMSE=0.13689347681023853, MAE=0.11769563357411618
# Random Forest validation for article_id 790006003: RMSE=1.7857008235471028, MAE=1.7806052883996035
# Random Forest validation for article_id 706016019: RMSE=0.1553159300495176, MAE=0.12729558045000014
# Random Forest validation for article_id 795440001: RMSE=0.1622387857946826, MAE=0.12312615389642843
# Random Forest validation for article_id 401044004: RMSE=0.06964789171358128, MAE=0.06436737873391858
# Random Forest validation for article_id 399256005: RMSE=0.16256454307890147, MAE=0.14593322760501912
# Random Forest validation for article_id 796210001: RMSE=0.17287571943405577, MAE=0.14575143142857153
# Random Forest validation for article_id 660599002: RMSE=0.061434947520744534, MAE=0.0556510488910717
# Random Forest validation for article_id 537116001: RMSE=0.24146363634014265, MAE=0.18897069253886192
# Random Forest validation for article_id 680263003: RMSE=0.1057913505900148, MAE=0.10476365688928554
# Random Forest validation for article_id 536139006: RMSE=0.09191428672086623, MAE=0.07847410149774912
# Random Forest validation for article_id 534181008: RMSE=0.20843506847774265, MAE=0.18874199884285708
# Random Forest validation for article_id 729928001: RMSE=0.08796613115757014, MAE=0.07555091013400006
# Random Forest validation for article_id 253448003: RMSE=0.06754101725173359, MAE=0.05398163522285713
# Random Forest validation for article_id 762846006: RMSE=0.5751313312636052, MAE=0.5293825943901984
# Random Forest validation for article_id 652924004: RMSE=0.22051001052374505, MAE=0.18704845600971226
# Random Forest validation for article_id 636505001: RMSE=0.661740411617205, MAE=0.6279084619519443
# Random Forest validation for article_id 688105002: RMSE=0.11155975995761555, MAE=0.09602104744357196
# Random Forest validation for article_id 781613002: RMSE=0.0861598638144733, MAE=0.06079764403637756
# Random Forest validation for article_id 757303012: RMSE=0.301165154927035, MAE=0.2676295464300595
# Random Forest validation for article_id 729860002: RMSE=0.14853107402253857, MAE=0.12076294207857134
# Random Forest validation for article_id 677999001: RMSE=0.07004029596668929, MAE=0.04989508013372751
# Random Forest validation for article_id 578478001: RMSE=0.1312939325705967, MAE=0.09859789800902112
# Random Forest validation for article_id 399201025: RMSE=0.20885647646686492, MAE=0.1532097116289728
# Random Forest validation for article_id 719530003: RMSE=0.16111374421894237, MAE=0.14138969789285685
# Random Forest validation for article_id 706016004: RMSE=0.12312098812760962, MAE=0.10627356672221082
# Random Forest validation for article_id 636455005: RMSE=5.374857430350603, MAE=5.3745831767786685
# Random Forest validation for article_id 612481002: RMSE=0.05687183990673666, MAE=0.04248905434884213
# Random Forest validation for article_id 568601023: RMSE=0.25198202077286497, MAE=0.19940172801788192
# Random Forest validation for article_id 755362001: RMSE=0.2676803534636303, MAE=0.24904373755714235
# Random Forest validation for article_id 554598001: RMSE=0.12398098923685187, MAE=0.10933561205567145
# Random Forest validation for article_id 759814009: RMSE=0.2874161898353762, MAE=0.24967814809642816
# Random Forest validation for article_id 773989001: RMSE=0.2712476171023452, MAE=0.2702687895778848
# Random Forest validation for article_id 748355003: RMSE=0.1264461368132879, MAE=0.1059232868771425
# Random Forest validation for article_id 714927002: RMSE=0.276216011378651, MAE=0.24800086453428247
# Random Forest validation for article_id 610776001: RMSE=0.04355776206085823, MAE=0.03475646735004648
# Random Forest validation for article_id 690936001: RMSE=0.35683451434987756, MAE=0.35644921722768447
# Random Forest validation for article_id 600886011: RMSE=0.07922552964822425, MAE=0.06837075607652611
# Random Forest validation for article_id 791587001: RMSE=0.42139672411667356, MAE=0.37528245522828846
# Random Forest validation for article_id 562245062: RMSE=0.21654594301104507, MAE=0.20974094827886353
# Random Forest validation for article_id 680265002: RMSE=0.11188934882624721, MAE=0.1076637645918571
# Random Forest validation for article_id 535035001: RMSE=0.346153720436456, MAE=0.3259641392540515
# Random Forest validation for article_id 760084003: RMSE=0.13045430757983947, MAE=0.10514007323777982
# Random Forest validation for article_id 695545001: RMSE=0.05800745157223306, MAE=0.05543209739914242
# Random Forest validation for article_id 803757001: RMSE=0.1530377957100327, MAE=0.12187685682857079
# Random Forest validation for article_id 611415001: RMSE=0.12383231123862709, MAE=0.1075048095145389
# Random Forest validation for article_id 698276001: RMSE=1.2402692962229886, MAE=1.2340085898932547
# Random Forest validation for article_id 158340001: RMSE=0.14680456590155372, MAE=0.11748083377142858
# Random Forest validation for article_id 758034001: RMSE=0.3453120493227051, MAE=0.32319242674775517
# Random Forest validation for article_id 612935009: RMSE=0.2839617338876908, MAE=0.28314960175006065
# Random Forest validation for article_id 762063001: RMSE=0.10742917228495612, MAE=0.08732030622265825
# Random Forest validation for article_id 534181003: RMSE=0.31663309684659424, MAE=0.3070095542345071
# Random Forest validation for article_id 690936013: RMSE=0.11860302088985998, MAE=0.11788852508577334
# Random Forest validation for article_id 664133001: RMSE=0.13035909603555335, MAE=0.10733606648098307
# Random Forest validation for article_id 640021012: RMSE=0.16863229442923378, MAE=0.1528608620543956
# Random Forest validation for article_id 603584018: RMSE=0.043284228627047255, MAE=0.029295066547078207
# Random Forest validation for article_id 715624010: RMSE=0.2026098669799328, MAE=0.1679154942148588
# Random Forest validation for article_id 160442010: RMSE=0.1253666537025537, MAE=0.11257405291834295
# Random Forest validation for article_id 615141002: RMSE=0.04524551905436457, MAE=0.034417536245714274
# Random Forest validation for article_id 540768002: RMSE=0.06161577635496842, MAE=0.055845145665032854
# Random Forest validation for article_id 684340001: RMSE=0.03346650305537339, MAE=0.024341870368544634
# Random Forest validation for article_id 537688014: RMSE=0.017699487469298808, MAE=0.015484542339714396
# Random Forest validation for article_id 658030016: RMSE=0.1488115370845773, MAE=0.12163843867857152
# Random Forest validation for article_id 740498001: RMSE=0.4647156962946623, MAE=0.45840486848999523
# Random Forest validation for article_id 568601030: RMSE=0.5856128770926432, MAE=0.4245769128513629
# Random Forest validation for article_id 700144001: RMSE=0.2632530769756671, MAE=0.26039773896428664
# Random Forest validation for article_id 589599031: RMSE=0.05177915281181182, MAE=0.03230461351026854
# Random Forest validation for article_id 516903005: RMSE=0.11676997304898708, MAE=0.10473215150392824
# Random Forest validation for article_id 742561001: RMSE=0.5542712712782276, MAE=0.5487775878888511
# Random Forest validation for article_id 554450019: RMSE=0.04697010668355477, MAE=0.032377448488799164
# Random Forest validation for article_id 664074001: RMSE=0.08854722982187671, MAE=0.07603407682142846
# Random Forest validation for article_id 623115001: RMSE=0.38051625617854357, MAE=0.37410343093571485
# Random Forest validation for article_id 790006002: RMSE=0.1885242260266128, MAE=0.12323777289285598
# Random Forest validation for article_id 529953007: RMSE=0.18150068303498418, MAE=0.17230234233108313
# Random Forest validation for article_id 662418001: RMSE=0.10677212585458498, MAE=0.09556663785149389
# Random Forest validation for article_id 702790004: RMSE=0.13665005372286168, MAE=0.13607695789916666
# Random Forest validation for article_id 698776002: RMSE=0.050788569467178434, MAE=0.04551157616999961
# Random Forest validation for article_id 794575001: RMSE=0.15675266728978782, MAE=0.13849460306461933
# Random Forest validation for article_id 506098007: RMSE=0.18127754901883283, MAE=0.1527929375143631
# Random Forest validation for article_id 399201023: RMSE=0.09876779187812809, MAE=0.08961484469714291
# Random Forest validation for article_id 809961002: RMSE=0.6399639159791773, MAE=0.6114547290457174
# Random Forest validation for article_id 714803001: RMSE=0.35118019299205655, MAE=0.3507770819142852
# Random Forest validation for article_id 682550001: RMSE=0.10946983652779384, MAE=0.09429320754621613
# Random Forest validation for article_id 399136033: RMSE=0.05240992734631603, MAE=0.049675246865921015
# Random Forest validation for article_id 728156001: RMSE=0.18644253557330623, MAE=0.17105559819844
# Random Forest validation for article_id 507909003: RMSE=0.08634139709008355, MAE=0.06856979617552501
# Random Forest validation for article_id 699075001: RMSE=0.10110303765021476, MAE=0.10056004473947625
# Random Forest validation for article_id 574109011: RMSE=0.04707941832115566, MAE=0.02973849875
# Random Forest validation for article_id 714824001: RMSE=0.051072555263935906, MAE=0.039294712648503094
# Random Forest validation for article_id 779324004: RMSE=0.18510379993753678, MAE=0.170993117557143
# Random Forest validation for article_id 733267001: RMSE=0.07309491209499197, MAE=0.07082978461142808
# Random Forest validation for article_id 711440001: RMSE=0.10747719331592032, MAE=0.082423288506425
# Random Forest validation for article_id 751471016: RMSE=0.09397945599637693, MAE=0.08905401925040232
# Random Forest validation for article_id 730683019: RMSE=1.0584164249114998, MAE=1.045096247195239
# Random Forest validation for article_id 705786001: RMSE=0.08594332354785618, MAE=0.07187754109714316
# Random Forest validation for article_id 650122001: RMSE=0.1860905123269531, MAE=0.1752801318867822
# Random Forest validation for article_id 652730004: RMSE=0.17657867178152672, MAE=0.1599122932205365
# Random Forest validation for article_id 399087030: RMSE=0.06792345185601371, MAE=0.05432256539589111
# Random Forest validation for article_id 797710001: RMSE=0.2033554872051486, MAE=0.20082677402792387
# Random Forest validation for article_id 179123001: RMSE=0.16590384082146944, MAE=0.16315402037571397
# Random Forest validation for article_id 697054014: RMSE=0.15448669157154335, MAE=0.13705477256072432
# Random Forest validation for article_id 759871002: RMSE=0.061373642167410314, MAE=0.049349978852350304
# Random Forest validation for article_id 689109001: RMSE=0.03125392437375764, MAE=0.030858906273165565
# Random Forest validation for article_id 758064001: RMSE=0.04501934114900187, MAE=0.026803511217857134
# Random Forest validation for article_id 539723003: RMSE=0.014299289719841991, MAE=0.010568895547857117
# Random Forest validation for article_id 658030017: RMSE=0.13687010593828003, MAE=0.10315577243532593
# Random Forest validation for article_id 820873001: RMSE=0.1392111332945797, MAE=0.11397186434142857
# Random Forest validation for article_id 745475001: RMSE=0.16852840312290787, MAE=0.1676531177012302
# Random Forest validation for article_id 663679001: RMSE=0.05490428038020563, MAE=0.05276259056150007
# Random Forest validation for article_id 709138001: RMSE=0.32104309309490237, MAE=0.32016118094851365
# Random Forest validation for article_id 711053003: RMSE=0.08027829886653769, MAE=0.07140843207949409
# Random Forest validation for article_id 698387001: RMSE=0.23233641488045903, MAE=0.18207134603224315
# Random Forest validation for article_id 673677004: RMSE=0.16435355456827763, MAE=0.14759122232674396
# Random Forest validation for article_id 524061003: RMSE=0.04390645817119965, MAE=0.024997403715228343
# Random Forest validation for article_id 714828002: RMSE=0.07817615350787584, MAE=0.07541058357857147
# Random Forest validation for article_id 697091007: RMSE=0.04981607071328038, MAE=0.04289129903346432
# Random Forest validation for article_id 562245093: RMSE=0.08661397815430685, MAE=0.06962505651050287
# Random Forest validation for article_id 688873002: RMSE=0.02056972890024962, MAE=0.012419734239285718
# Random Forest validation for article_id 744786001: RMSE=0.024599023420529737, MAE=0.01960361328004621
# Random Forest validation for article_id 573716053: RMSE=0.031467980834742254, MAE=0.029657416834840272
# Random Forest validation for article_id 569562005: RMSE=0.43128469049333573, MAE=0.22190585872571425
# Random Forest validation for article_id 706016007: RMSE=0.7520143504497707, MAE=0.5963552864285714
# Random Forest validation for article_id 714807003: RMSE=0.1415730734548005, MAE=0.11569272395977429
# Random Forest validation for article_id 824185001: RMSE=0.36990817678170174, MAE=0.3502043450000002
# Random Forest validation for article_id 752814004: RMSE=0.08865944942384492, MAE=0.07948528094428543
# Random Forest validation for article_id 783384008: RMSE=0.22559916522228515, MAE=0.1841813001014286
# Random Forest validation for article_id 787946002: RMSE=0.0966850533817845, MAE=0.0826566528088524
# Random Forest validation for article_id 399087010: RMSE=0.10424239351006309, MAE=0.09086111625082553
# Random Forest validation for article_id 400285006: RMSE=0.1727326419121275, MAE=0.15749350855401914
# Random Forest validation for article_id 721268001: RMSE=0.09121874864084985, MAE=0.06753232603571423
# Random Forest validation for article_id 658030005: RMSE=0.027261293067984377, MAE=0.01905414358857171
# Random Forest validation for article_id 720504001: RMSE=0.10132918289194635, MAE=0.08392550357381025
# Random Forest validation for article_id 637283006: RMSE=0.1270415265168648, MAE=0.12547352281560084
# Random Forest validation for article_id 634426008: RMSE=0.06483867077758136, MAE=0.05343186681621833
# Random Forest validation for article_id 704756001: RMSE=0.0729592584105506, MAE=0.057901689889285866
# Random Forest validation for article_id 685813001: RMSE=0.10598960519160942, MAE=0.08344067049999968
# Random Forest validation for article_id 111586001: RMSE=0.1901788220280692, MAE=0.16865856793704986
# Random Forest validation for article_id 547058001: RMSE=0.41172339749365106, MAE=0.4107068709549996
# Random Forest validation for article_id 456163060: RMSE=0.5631663350929856, MAE=0.5130684210714261
# Random Forest validation for article_id 788846004: RMSE=0.34040745454299737, MAE=0.31247003737142937
# Random Forest validation for article_id 599580020: RMSE=0.02237006682426195, MAE=0.012409582889000017
# Random Forest validation for article_id 749615001: RMSE=0.08041190452501425, MAE=0.06013881371142858
# Random Forest validation for article_id 743616001: RMSE=0.1799032451992491, MAE=0.16211286987857138
# Random Forest validation for article_id 539723006: RMSE=0.027961979328713697, MAE=0.011855289754285717
# Random Forest validation for article_id 111593001: RMSE=0.08412692768668668, MAE=0.06852610455034698
# Random Forest validation for article_id 524825011: RMSE=0.024182306271561652, MAE=0.020473516308928692
# Random Forest validation for article_id 399223035: RMSE=0.16061338723760393, MAE=0.1559366902356711
# Random Forest validation for article_id 611415005: RMSE=0.2755120864401033, MAE=0.2537771553445079
# Random Forest validation for article_id 684824003: RMSE=0.4408599416993488, MAE=0.43942504583642983
# Random Forest validation for article_id 768912001: RMSE=0.14030467810156214, MAE=0.11891621784999355
# Random Forest validation for article_id 622955001: RMSE=0.34811094879198284, MAE=0.3438876926999993
# Random Forest validation for article_id 599502001: RMSE=0.07727176894554194, MAE=0.07194261328970215
# Random Forest validation for article_id 743594003: RMSE=0.07970933735247886, MAE=0.06034351324857147
# Random Forest validation for article_id 253448001: RMSE=0.14044191507682652, MAE=0.11177482295366023
# Random Forest validation for article_id 775825001: RMSE=1.3654561417600835, MAE=1.3605322428057103
# Random Forest validation for article_id 712587004: RMSE=0.025666710718248182, MAE=0.019661579881108
# Random Forest validation for article_id 745475002: RMSE=0.3716586317600492, MAE=0.3704881773107195
# Random Forest validation for article_id 571706001: RMSE=0.054370326442757445, MAE=0.04282673508192176
# Random Forest validation for article_id 590928011: RMSE=0.014719168272037822, MAE=0.010910259512111121
# Random Forest validation for article_id 748269003: RMSE=0.11340075184074547, MAE=0.10386718724398795
# Random Forest validation for article_id 697031001: RMSE=0.03781302935443761, MAE=0.033996876313095274
# Random Forest validation for article_id 772832001: RMSE=0.28848865978661153, MAE=0.24955268063409977
# Random Forest validation for article_id 557994003: RMSE=0.050397502167025716, MAE=0.03345823259714286
# Random Forest validation for article_id 455832001: RMSE=0.06196192664830607, MAE=0.05298372527853584
# Random Forest validation for article_id 771829005: RMSE=0.12444378188157042, MAE=0.10960435475000001
# Random Forest validation for article_id 639151001: RMSE=0.0941802106475504, MAE=0.08909043017321391
# Random Forest validation for article_id 812207002: RMSE=0.5785597096871659, MAE=0.5510401551976188
# Random Forest validation for article_id 675068002: RMSE=0.0715630436950991, MAE=0.06169010692857164
# Random Forest validation for article_id 730863005: RMSE=0.20281485960218554, MAE=0.13016063468840403
# Random Forest validation for article_id 399223034: RMSE=0.6257664556728665, MAE=0.6182011947006278
# Random Forest validation for article_id 399201026: RMSE=0.052885743923702065, MAE=0.048431716628956116
# Random Forest validation for article_id 429313006: RMSE=0.09557850643611032, MAE=0.07861699294637635
# Random Forest validation for article_id 736870001: RMSE=0.1151737450367416, MAE=0.09518386844214284
# Random Forest validation for article_id 624486001: RMSE=0.06265069976115543, MAE=0.049878869287689795
# Random Forest validation for article_id 685814033: RMSE=0.2588545680907131, MAE=0.21381701125476532
# Random Forest validation for article_id 537346026: RMSE=0.0984320603967101, MAE=0.09742865115149532
# Random Forest validation for article_id 688105003: RMSE=0.08758006466073437, MAE=0.0748245690190392
# Random Forest validation for article_id 664319021: RMSE=0.025185785234654597, MAE=0.023674114938571595
# Random Forest validation for article_id 803468002: RMSE=0.16693963708621493, MAE=0.13715377776716514
# Random Forest validation for article_id 589599047: RMSE=0.02385378703892767, MAE=0.019559171602131876
# Random Forest validation for article_id 781613001: RMSE=0.18800920237062899, MAE=0.1850434517999998
# Random Forest validation for article_id 719957006: RMSE=0.19673111238051547, MAE=0.1699027640442845
# Random Forest validation for article_id 692632001: RMSE=0.2625277522829222, MAE=0.2590496896214289
# Random Forest validation for article_id 469137001: RMSE=0.35230664248705973, MAE=0.3517382260769926
# Random Forest validation for article_id 806388002: RMSE=0.04951009887171426, MAE=0.03847042982742853
# Random Forest validation for article_id 708311001: RMSE=0.1719797081923918, MAE=0.12061974364383074
# Random Forest validation for article_id 680264001: RMSE=0.05094048683449175, MAE=0.045206251831736446
# Random Forest validation for article_id 562245004: RMSE=0.0781318230871282, MAE=0.07505325462949008
# Random Forest validation for article_id 698276004: RMSE=0.2885811018088364, MAE=0.24711760048855222
# Random Forest validation for article_id 812167002: RMSE=0.4412389070910713, MAE=0.438309294242857
# Random Forest validation for article_id 762846007: RMSE=0.3160075761127564, MAE=0.21823823748371413
# Random Forest validation for article_id 772829001: RMSE=1.8083709870874982, MAE=1.7813189621889725
# Random Forest validation for article_id 811777001: RMSE=0.3553336123727357, MAE=0.29987613927143036
# Random Forest validation for article_id 698718002: RMSE=0.06741602227801934, MAE=0.04219619718906038
# Random Forest validation for article_id 771829002: RMSE=0.6754639894475338, MAE=0.6684914193999995
# Random Forest validation for article_id 399087021: RMSE=0.07182791878313757, MAE=0.05460393743513673
# Random Forest validation for article_id 572998002: RMSE=0.0684094836928915, MAE=0.06322911942857161
# Random Forest validation for article_id 806388001: RMSE=0.1113171103595329, MAE=0.08520566379142865
# Random Forest validation for article_id 573716050: RMSE=0.06815223246879144, MAE=0.06471422562348868
# Random Forest validation for article_id 537688010: RMSE=1.7429769319853325, MAE=1.7419708516382018
# Random Forest validation for article_id 673799001: RMSE=0.01963110558066502, MAE=0.01720392338928569
# Random Forest validation for article_id 756322001: RMSE=0.06423951514870356, MAE=0.05390035903177561
# Random Forest validation for article_id 716672003: RMSE=0.1171896789387338, MAE=0.1166949200653187
# Random Forest validation for article_id 687704039: RMSE=0.2503490463808427, MAE=0.20250665250000002
# Random Forest validation for article_id 827637001: RMSE=1.8659521067543707, MAE=1.843873912143814
# Random Forest validation for article_id 723469002: RMSE=0.10909771750392999, MAE=0.08746070094428614
# Random Forest validation for article_id 563519008: RMSE=0.19640430064579906, MAE=0.19490205192844678
# Random Forest validation for article_id 662948003: RMSE=0.393611454854352, MAE=0.39325012372175616
# Random Forest validation for article_id 660599016: RMSE=0.1643606168405712, MAE=0.15622087935430137
# Random Forest validation for article_id 591334003: RMSE=0.03046305422915247, MAE=0.023905337549119027
# Random Forest validation for article_id 688432001: RMSE=0.0257968103921785, MAE=0.020121806331785723
# Random Forest validation for article_id 700701001: RMSE=0.08360097899923241, MAE=0.05944020940824425
# Random Forest validation for article_id 736489003: RMSE=0.06167541868153387, MAE=0.0504424194703222
# Random Forest validation for article_id 640542002: RMSE=0.06823782972898262, MAE=0.056008970549193626
# Random Forest validation for article_id 660599001: RMSE=0.04968862004989189, MAE=0.037003631892857144
# Random Forest validation for article_id 519583008: RMSE=0.09198167224302588, MAE=0.08427165238480941
# Random Forest validation for article_id 552716001: RMSE=0.13795907151353382, MAE=0.11680872779394569
# Random Forest validation for article_id 780297001: RMSE=0.05402906046348166, MAE=0.05226641081643623
# Random Forest validation for article_id 750330002: RMSE=0.05209107247785838, MAE=0.03871268950765023
# Random Forest validation for article_id 692930001: RMSE=0.048866260034842686, MAE=0.0460321096384027
# Random Forest validation for article_id 534164001: RMSE=0.12449462460883978, MAE=0.11042135071474558
# Random Forest validation for article_id 687704028: RMSE=0.8126119376456652, MAE=0.8025729494278225
# Random Forest validation for article_id 688873001: RMSE=0.028870607716130803, MAE=0.027688738863928593
# Random Forest validation for article_id 572797001: RMSE=0.07166610169526137, MAE=0.0529362488051112
# Random Forest validation for article_id 590928022: RMSE=0.25475457628643206, MAE=0.2049911620228571
# Random Forest validation for article_id 811198002: RMSE=0.08505701523931267, MAE=0.07951417611250004
# Random Forest validation for article_id 751664001: RMSE=0.3620219909287082, MAE=0.34358883172100013
# Random Forest validation for article_id 656719005: RMSE=0.02189601609955842, MAE=0.015638611922571682
# Random Forest validation for article_id 547780003: RMSE=0.11680456992346185, MAE=0.10143855941250832
# Random Forest validation for article_id 801512004: RMSE=0.3668212956010351, MAE=0.33415593545204997
# Random Forest validation for article_id 796210010: RMSE=0.3178175972118223, MAE=0.2751451883385087
# Random Forest validation for article_id 670655001: RMSE=0.3072559474385396, MAE=0.3061882213788191
# Random Forest validation for article_id 564786001: RMSE=0.06043464312055184, MAE=0.04695406749928568
# Random Forest validation for article_id 772822001: RMSE=1.0297401457933426, MAE=1.0260013702999962
# Random Forest validation for article_id 738943005: RMSE=0.2408489769180196, MAE=0.23874720132857144
# Random Forest validation for article_id 754238001: RMSE=0.20824298200032676, MAE=0.1801309938295997
# Random Forest validation for article_id 156231001: RMSE=0.1057980237161881, MAE=0.087948581182143
# Random Forest validation for article_id 301656026: RMSE=0.12192215906063136, MAE=0.10313459396837198
# Random Forest validation for article_id 624257003: RMSE=0.17561971334494866, MAE=0.15735392723836727
# Random Forest validation for article_id 559634009: RMSE=0.17319271557471422, MAE=0.17276886166484534
# Random Forest validation for article_id 821031002: RMSE=0.6601420449410531, MAE=0.6533662025285703
# Random Forest validation for article_id 751941002: RMSE=0.020953829621201906, MAE=0.01988242121571429
# Random Forest validation for article_id 704668001: RMSE=0.3850970753207021, MAE=0.38335495195861097
# Random Forest validation for article_id 573085033: RMSE=0.37530768603519943, MAE=0.3720176238685749
# Random Forest validation for article_id 689109003: RMSE=0.013348455970574232, MAE=0.008352710615857144
# Random Forest validation for article_id 837941001: RMSE=0.24829839371597565, MAE=0.20673182971527157
# Random Forest validation for article_id 735583001: RMSE=0.029430877132193105, MAE=0.019551420411257847
# Random Forest validation for article_id 470789001: RMSE=0.044818432738319175, MAE=0.03812163515770928
# Random Forest validation for article_id 534357002: RMSE=0.041074596631826804, MAE=0.03189309747142859
# Random Forest validation for article_id 684341001: RMSE=0.017641869752850006, MAE=0.012227239509427815
# Random Forest validation for article_id 688558001: RMSE=0.04303427458706374, MAE=0.03437624204628558
# Random Forest validation for article_id 622958003: RMSE=0.0888312074570685, MAE=0.07158859461979454
# Random Forest validation for article_id 750422018: RMSE=0.20380651646762593, MAE=0.15140419928185642
# Random Forest validation for article_id 755362003: RMSE=1.7887484730676515, MAE=1.785550149317667
# Random Forest validation for article_id 787148001: RMSE=0.3913569041899739, MAE=0.3337414879789726
# Random Forest validation for article_id 744180001: RMSE=0.06990363676034028, MAE=0.0654324056607144
# Random Forest validation for article_id 559633008: RMSE=0.22830520360287646, MAE=0.19538038485563233
# Random Forest validation for article_id 801309002: RMSE=0.26584791909263394, MAE=0.2560369411599974
# Random Forest validation for article_id 678686001: RMSE=0.0765684156213618, MAE=0.07376156709605687
# Random Forest validation for article_id 717727002: RMSE=0.2096371627786728, MAE=0.20898396473571407
# Random Forest validation for article_id 559616013: RMSE=0.2856537930938689, MAE=0.28557509607500026
# Random Forest validation for article_id 661794006: RMSE=0.1165225007024243, MAE=0.10339183085714287
# Random Forest validation for article_id 799742003: RMSE=1.0418688264293912, MAE=1.0370230418047657
# Random Forest validation for article_id 727029001: RMSE=0.03819448512311567, MAE=0.02992731372339285
# Random Forest validation for article_id 719530004: RMSE=0.36159838660552607, MAE=0.28615640217051735
# Random Forest validation for article_id 707269003: RMSE=0.2742683666143068, MAE=0.26489513620714294
# Random Forest validation for article_id 786752001: RMSE=0.3371727112803879, MAE=0.3247198756185031
# Random Forest validation for article_id 656719015: RMSE=0.049525649072339896, MAE=0.043123462757142884
# Random Forest validation for article_id 714807004: RMSE=0.13822460573279918, MAE=0.11720405285644843
# Random Forest validation for article_id 787049001: RMSE=1.011169247567586, MAE=1.007708737235716
# Random Forest validation for article_id 554450005: RMSE=0.04518364827409838, MAE=0.03496913198364695
# Random Forest validation for article_id 739144004: RMSE=0.027878486221395618, MAE=0.016693123500571463
# Random Forest validation for article_id 534181010: RMSE=4.588388231217467, MAE=4.5864220906482105
# Random Forest validation for article_id 779842001: RMSE=0.21679999936091135, MAE=0.19564367300357116
# Random Forest validation for article_id 697091002: RMSE=0.03014169940115309, MAE=0.025533291785714285
# Random Forest validation for article_id 649437002: RMSE=0.03655504194115538, MAE=0.019918776907071407
# Random Forest validation for article_id 756633001: RMSE=0.042336171488613926, MAE=0.029667941881428576
# Random Forest validation for article_id 668537002: RMSE=0.5874932083019789, MAE=0.586661770906419
# Random Forest validation for article_id 673901001: RMSE=0.06998188213677822, MAE=0.0690907138142858
# Random Forest validation for article_id 785018003: RMSE=0.2156384131337298, MAE=0.18724339752857166
# Random Forest validation for article_id 708705004: RMSE=0.4613325262836104, MAE=0.449543913244043
# Random Forest validation for article_id 700701002: RMSE=0.08467126694539205, MAE=0.06962671714281211
# Random Forest validation for article_id 537346013: RMSE=0.25793171073151233, MAE=0.2567441272253732
# Random Forest validation for article_id 827635002: RMSE=0.20095522906467303, MAE=0.16522530542735384
# Random Forest validation for article_id 738943003: RMSE=0.12136863285225688, MAE=0.11712061634999979
# Random Forest validation for article_id 671852003: RMSE=0.040159728100914276, MAE=0.03129024672519183
# Random Forest validation for article_id 720125004: RMSE=0.09882031007399754, MAE=0.09576040391828654
# Random Forest validation for article_id 607154001: RMSE=0.023832724344990938, MAE=0.018684026539704773
# Random Forest validation for article_id 684340002: RMSE=0.03649540492033077, MAE=0.025389823745809507
# Random Forest validation for article_id 621381016: RMSE=0.1558364906138021, MAE=0.14194750568622258
# Random Forest validation for article_id 189616006: RMSE=0.17340426872619147, MAE=0.16732869450432403
# Random Forest validation for article_id 680262010: RMSE=0.043722462507273026, MAE=0.043025206212724744
# Random Forest validation for article_id 457892003: RMSE=0.1532166442511633, MAE=0.14264308747979834
# Random Forest validation for article_id 562245064: RMSE=0.01765246445418663, MAE=0.013194915
# Random Forest validation for article_id 662948012: RMSE=0.053587783151210405, MAE=0.048938651287143274
# Random Forest validation for article_id 748355002: RMSE=1.6604708576326024, MAE=1.657348705853433
# Random Forest validation for article_id 806388003: RMSE=0.05245412394622692, MAE=0.037290331625483675
# Random Forest validation for article_id 684080001: RMSE=0.960697565447734, MAE=0.9600547370107128
# Random Forest validation for article_id 731644001: RMSE=0.32154421948822587, MAE=0.32104454941733057
# Random Forest validation for article_id 448515001: RMSE=0.1167245731813035, MAE=0.09304492876926591
# Random Forest validation for article_id 732842004: RMSE=0.06059878853979001, MAE=0.045386575340194746
# Random Forest validation for article_id 733123004: RMSE=0.2717532044558111, MAE=0.2710662922014266
# Random Forest validation for article_id 700851001: RMSE=0.153102913821523, MAE=0.152253926851404
# Random Forest validation for article_id 702790003: RMSE=0.07553012918637764, MAE=0.07473798950508341
# Random Forest validation for article_id 678965001: RMSE=0.08079896735550011, MAE=0.07755008229890002
# Random Forest validation for article_id 758049001: RMSE=0.042105840914318, MAE=0.03769054621999989
# ...
# Random Forest validation for article_id 793856005: RMSE=0.386933161761102, MAE=0.38272132453571445
# Random Forest validation for article_id 669682006: RMSE=0.09484790664879394, MAE=0.09254222004464355
# Random Forest validation for article_id 816933001: RMSE=0.20772128728248634, MAE=0.17569039173775505
# Random Forest validation for article_id 524529010: RMSE=0.7307705785114539, MAE=0.7304943283917578
# Random Forest validation for article_id 789301001: RMSE=0.2615106841402065, MAE=0.26024602008809533
# Random Forest validation for article_id 755738001: RMSE=0.06379702260552265, MAE=0.060984777192106106
# Random Forest validation for article_id 718086003: RMSE=0.07317293830909509, MAE=0.05025241273272403
# Random Forest validation for article_id 665481013: RMSE=0.307371269740575, MAE=0.25373016315795927
# Random Forest validation for article_id 684824001: RMSE=0.02572497701969277, MAE=0.017723951222142997
# Random Forest validation for article_id 712924008: RMSE=0.009830292762426173, MAE=0.008271424327285755
# Random Forest validation for article_id 698387003: RMSE=0.08975584564362438, MAE=0.08439153215214108
# Random Forest validation for article_id 701046001: RMSE=0.02674520679876539, MAE=0.023234888703021893
# Random Forest validation for article_id 598859009: RMSE=0.1429406920739992, MAE=0.13704807195535687
# Random Forest validation for article_id 637566007: RMSE=0.03967114114536563, MAE=0.029718620285714266
# Random Forest validation for article_id 669715001: RMSE=0.34098854804621187, MAE=0.339893179426192
# Random Forest validation for article_id 790791002: RMSE=0.0436354839541949, MAE=0.03164543643214261
# Random Forest validation for article_id 722437003: RMSE=0.02313987764630605, MAE=0.02232099478964277
# Random Forest validation for article_id 788324008: RMSE=0.23946282052371456, MAE=0.23883830551883362
# Random Forest validation for article_id 775996015: RMSE=0.12267300314585902, MAE=0.1207258878899995
# Random Forest validation for article_id 824999001: RMSE=0.18880755520900333, MAE=0.15843163924553388
# Random Forest validation for article_id 706016028: RMSE=0.09981998121047969, MAE=0.0941828756996906
# Random Forest validation for article_id 761406001: RMSE=0.3662324403303079, MAE=0.36489157453285825
# Random Forest validation for article_id 794779001: RMSE=0.17707972930026478, MAE=0.17207258100219894
# Random Forest validation for article_id 705974001: RMSE=0.06927918895396372, MAE=0.06378454858571468
# Random Forest validation for article_id 772149001: RMSE=0.01993489056484994, MAE=0.01825636993227242
# Random Forest validation for article_id 676539001: RMSE=0.035689460309607256, MAE=0.02270798452447758
# Random Forest validation for article_id 685150002: RMSE=0.08051122877831957, MAE=0.07866579984387803
# Random Forest validation for article_id 787147002: RMSE=1.2733876944378113, MAE=1.270768530353105
# Random Forest validation for article_id 763037001: RMSE=0.04481677695511827, MAE=0.035321530094540456
# Random Forest validation for article_id 556260001: RMSE=0.06504605837524294, MAE=0.04611104273592518
# Random Forest validation for article_id 606395006: RMSE=0.060370994105316364, MAE=0.051825953384455836
# Random Forest validation for article_id 456163048: RMSE=0.6987346639204703, MAE=0.698408946807142
# Random Forest validation for article_id 783444001: RMSE=0.17663411866412257, MAE=0.17573056739571302
# Random Forest validation for article_id 395127011: RMSE=0.03283605647024501, MAE=0.026278322503595214
# Random Forest validation for article_id 639258002: RMSE=0.044926624977730416, MAE=0.02925529222857152
# Random Forest validation for article_id 687704027: RMSE=0.19991688635432556, MAE=0.1543331856785431
# Random Forest validation for article_id 706016011: RMSE=0.03541077141114871, MAE=0.027555926545398585
# Random Forest validation for article_id 676990001: RMSE=0.17416866212116497, MAE=0.17289377249904733
# Random Forest validation for article_id 784926001: RMSE=0.060692907468191816, MAE=0.052698147291428646
# Random Forest validation for article_id 670752002: RMSE=0.09584078864853142, MAE=0.09128331633093467
# Random Forest validation for article_id 794395001: RMSE=0.23867532967782912, MAE=0.2378811376285718
# Random Forest validation for article_id 781608001: RMSE=0.3280402937739208, MAE=0.32029481878428623
# Random Forest validation for article_id 770857003: RMSE=0.25787307434677736, MAE=0.2523541744071424
# Random Forest validation for article_id 756132001: RMSE=0.038058550815911245, MAE=0.0357818446381564
# Random Forest validation for article_id 744893006: RMSE=0.2946950333586421, MAE=0.29281947058999924
# Random Forest validation for article_id 501820003: RMSE=0.004734407400548467, MAE=0.0036400785944205663
# Random Forest validation for article_id 787696004: RMSE=0.14121079623993602, MAE=0.13809293146590082
# Random Forest validation for article_id 562245025: RMSE=0.030861048328958415, MAE=0.02468657856912885
# Random Forest validation for article_id 759814010: RMSE=0.13969965917959654, MAE=0.10709044698285726
# Random Forest validation for article_id 714825002: RMSE=0.12510039629747854, MAE=0.1243133039347062
# Random Forest validation for article_id 616708006: RMSE=0.05673858569981766, MAE=0.02891849179469246
# Random Forest validation for article_id 844059001: RMSE=0.12426875285227153, MAE=0.11229806203000006
# Random Forest validation for article_id 696209004: RMSE=0.013771118792032688, MAE=0.011559156913857166
# Random Forest validation for article_id 675070002: RMSE=0.011123465580391142, MAE=0.009817844891000014
# Random Forest validation for article_id 776237003: RMSE=0.020509649226268904, MAE=0.016893262443928577
# Random Forest validation for article_id 791571003: RMSE=0.5407638339921707, MAE=0.5330578529921663
# Random Forest validation for article_id 694182004: RMSE=0.08390073833882647, MAE=0.0764481046799628
# Random Forest validation for article_id 577648001: RMSE=0.06281099789416428, MAE=0.06260361829285771
# Random Forest validation for article_id 797065001: RMSE=0.23508265745879248, MAE=0.22621006525599482
# Random Forest validation for article_id 708379004: RMSE=0.3074737751946113, MAE=0.3071538949700657
# Random Forest validation for article_id 734435002: RMSE=0.1823364070540991, MAE=0.18081686855739165
# Random Forest validation for article_id 569984001: RMSE=0.02985958842648422, MAE=0.023454893102381327
# Random Forest validation for article_id 807329002: RMSE=0.1465912665150883, MAE=0.1354966014945128
# Random Forest validation for article_id 732511002: RMSE=0.10992791411782855, MAE=0.10277921040544832
# Random Forest validation for article_id 637667002: RMSE=0.16782723421771154, MAE=0.16656988835290437
# Random Forest validation for article_id 748566004: RMSE=0.03050805371623649, MAE=0.016704799832857165
# Random Forest validation for article_id 661435002: RMSE=0.318066732818421, MAE=0.316683396521428
# Random Forest validation for article_id 733101002: RMSE=0.26172899079422657, MAE=0.26069177887283057
# Random Forest validation for article_id 637566006: RMSE=0.26202134566638474, MAE=0.26164404813571457
# Random Forest validation for article_id 695545008: RMSE=0.9838784813881656, MAE=0.9338562689642849
# Random Forest validation for article_id 706371001: RMSE=0.056079399304011374, MAE=0.05296049682612249
# Random Forest validation for article_id 837325001: RMSE=1.5355301182736434, MAE=1.5341254311940478
# Random Forest validation for article_id 781608002: RMSE=0.2979657262224903, MAE=0.2809052786777909
# Random Forest validation for article_id 697054002: RMSE=0.02515341318792199, MAE=0.02392825254887754
# Random Forest validation for article_id 668004001: RMSE=2.054118327589272, MAE=2.049109628534723
# Random Forest validation for article_id 767869001: RMSE=0.07832501935390478, MAE=0.07119470288571297
# Random Forest validation for article_id 762286001: RMSE=0.19678514288063895, MAE=0.1931305138170438
# Random Forest validation for article_id 768419001: RMSE=0.5843675852783373, MAE=0.5834607024694065
# Random Forest validation for article_id 744072002: RMSE=0.08456455599716942, MAE=0.05967163871971414
# Random Forest validation for article_id 737852001: RMSE=0.3216856999888254, MAE=0.3215109602214286
# Random Forest validation for article_id 687948001: RMSE=0.11358282446060479, MAE=0.09723797121446634
# Random Forest validation for article_id 695632007: RMSE=0.07422669735683571, MAE=0.07101599826535694
# Random Forest validation for article_id 844915003: RMSE=0.27665259338122955, MAE=0.25040291848571405
# Random Forest validation for article_id 794575003: RMSE=0.07629978159556855, MAE=0.047716761816764916
# Random Forest validation for article_id 571092001: RMSE=0.017183912267498304, MAE=0.013259325109020554
# Random Forest validation for article_id 662888005: RMSE=1.173245441731503, MAE=1.1724770608372135
# Random Forest validation for article_id 775996012: RMSE=0.03942967785624989, MAE=0.03403247499250002
# Random Forest validation for article_id 809961001: RMSE=0.14339313482839647, MAE=0.12368674641856994
# Random Forest validation for article_id 637549005: RMSE=0.31075159747787745, MAE=0.3073888973928564
# Random Forest validation for article_id 778534001: RMSE=0.3921268889812951, MAE=0.39153419725523786
# Random Forest validation for article_id 733027005: RMSE=0.017168692175710976, MAE=0.015703534320510748
# Random Forest validation for article_id 399223068: RMSE=0.2424972362683424, MAE=0.22312685768571477
# Random Forest validation for article_id 351933051: RMSE=0.043459256591282316, MAE=0.034031452243494915
# Random Forest validation for article_id 399223059: RMSE=0.07224007295741086, MAE=0.06707611806753337
# Random Forest validation for article_id 717816001: RMSE=0.07105221948749416, MAE=0.055526803082857144
# Random Forest validation for article_id 669605003: RMSE=0.022402170411776, MAE=0.02165253796011653
# Random Forest validation for article_id 717664001: RMSE=0.046093655324825275, MAE=0.044283011880634895
# Random Forest validation for article_id 618287006: RMSE=0.24194268572041247, MAE=0.22841174104006035
# Random Forest validation for article_id 714750001: RMSE=0.04655501176810516, MAE=0.045432282415377
# Random Forest validation for article_id 624486005: RMSE=0.012227475888438076, MAE=0.009167804570630387
# Random Forest validation for article_id 767438002: RMSE=0.03485068234254955, MAE=0.034033713225865674
# Random Forest validation for article_id 788107006: RMSE=0.45298131629566063, MAE=0.37766127077510714
# Random Forest validation for article_id 636323005: RMSE=0.01782369388543071, MAE=0.015750079881244182
# Random Forest validation for article_id 637283007: RMSE=0.15840969296463314, MAE=0.15161505365142852
# Random Forest validation for article_id 495685003: RMSE=0.4222650173169485, MAE=0.41987487043571026
# Random Forest validation for article_id 718582002: RMSE=0.20373697327591922, MAE=0.1886944849657148
# Random Forest validation for article_id 750398005: RMSE=0.03357503526766413, MAE=0.030162876267999957
# Random Forest validation for article_id 744862004: RMSE=0.030316806352049266, MAE=0.029169342665143278
# Random Forest validation for article_id 760449001: RMSE=0.35939688038507434, MAE=0.31496229612857096
# Random Forest validation for article_id 695318002: RMSE=0.1319215215858052, MAE=0.13141253919164173
# Random Forest validation for article_id 540768012: RMSE=0.019100974121413764, MAE=0.013794067248898301
# Random Forest validation for article_id 696733001: RMSE=0.06196756795505592, MAE=0.05797328102198292
# Random Forest validation for article_id 689005002: RMSE=0.04281177125989325, MAE=0.0260229760176743
# Random Forest validation for article_id 661806003: RMSE=0.06449465477173545, MAE=0.059699924864384184
# Random Forest validation for article_id 666382014: RMSE=0.5184281864032031, MAE=0.5173693661524118
# Random Forest validation for article_id 820563001: RMSE=0.419385351803811, MAE=0.4187185520931568
# Random Forest validation for article_id 569929001: RMSE=0.84302607221633, MAE=0.8421565018354727
# Random Forest validation for article_id 700515002: RMSE=0.225966447736875, MAE=0.2223336860249836
# Random Forest validation for article_id 831218001: RMSE=0.3409165895982212, MAE=0.335477355455957
# Random Forest validation for article_id 650122004: RMSE=0.05110533483335933, MAE=0.04615816587581629
# Random Forest validation for article_id 399201031: RMSE=0.16365124863906405, MAE=0.15715905320278376
# Random Forest validation for article_id 599580049: RMSE=0.13856875307394595, MAE=0.11554140781930748
# Random Forest validation for article_id 788651001: RMSE=0.18970762823802895, MAE=0.1872463115531746
# Random Forest validation for article_id 662868002: RMSE=0.1470715325537391, MAE=0.14317745010999997
# Random Forest validation for article_id 724905008: RMSE=0.11226393389712767, MAE=0.0797321816142857
# Random Forest validation for article_id 704630003: RMSE=0.04671694213857396, MAE=0.04354975470319268
# Random Forest validation for article_id 784143001: RMSE=0.09575625718962533, MAE=0.07537685270870731
# Random Forest validation for article_id 694127001: RMSE=0.21035444691063562, MAE=0.20983448570507274
# Random Forest validation for article_id 712711001: RMSE=0.06057616002481537, MAE=0.05740372821158255
# Random Forest validation for article_id 779889001: RMSE=0.11164107012087633, MAE=0.10892239850171358
# Random Forest validation for article_id 610776028: RMSE=0.03716185085421266, MAE=0.028836912797857005
# Random Forest validation for article_id 693479002: RMSE=0.0339550781947024, MAE=0.031467801953999876
# Random Forest validation for article_id 436083001: RMSE=0.10301808884922248, MAE=0.10180936189464307
# Random Forest validation for article_id 707699001: RMSE=0.03242095697488977, MAE=0.030283695296504244
# Random Forest validation for article_id 456163009: RMSE=0.03969132222099566, MAE=0.03438652896037414
# Random Forest validation for article_id 660599003: RMSE=0.14199413367334396, MAE=0.1350527210785712
# Random Forest validation for article_id 704126003: RMSE=0.016985900200845477, MAE=0.015487215730285428
# Random Forest validation for article_id 758642001: RMSE=0.4200050580388308, MAE=0.4194471853000003
# Random Forest validation for article_id 794793001: RMSE=0.1750471291062155, MAE=0.17123342960505905
# Random Forest validation for article_id 697060014: RMSE=0.015768483514663593, MAE=0.013383414382142857
# Random Forest validation for article_id 754323004: RMSE=0.35858413166450454, MAE=0.35723038324285705
# Random Forest validation for article_id 619884007: RMSE=0.02187255458957681, MAE=0.019979007444285702
# Random Forest validation for article_id 746888001: RMSE=0.16925519938852263, MAE=0.16731913857275074
# Random Forest validation for article_id 741478003: RMSE=0.15329977802938125, MAE=0.15224108220714258
# Random Forest validation for article_id 779656002: RMSE=0.6308459450405118, MAE=0.6303171731033982
# Random Forest validation for article_id 685848008: RMSE=0.14597185560466017, MAE=0.14570946108871932
# Random Forest validation for article_id 828991001: RMSE=0.08607510567508264, MAE=0.06376796491428573
# Random Forest validation for article_id 689572001: RMSE=0.047826164559255716, MAE=0.03668945402789552
# Random Forest validation for article_id 684686001: RMSE=0.0633404254175703, MAE=0.05941847911988204
# Random Forest validation for article_id 772927001: RMSE=0.16347180674778608, MAE=0.1622249816085713
# Random Forest validation for article_id 768440001: RMSE=0.015614398711759537, MAE=0.011377243455273644
# Random Forest validation for article_id 796239001: RMSE=0.09137061546381851, MAE=0.08706353352142858
# Random Forest validation for article_id 710708005: RMSE=0.03634112439372069, MAE=0.03302205710714308
# Random Forest validation for article_id 312878010: RMSE=0.13970286554780606, MAE=0.1260132626758644
# Random Forest validation for article_id 682520002: RMSE=0.15889006585357796, MAE=0.15810473550000048
# Random Forest validation for article_id 554450035: RMSE=0.04096966386898115, MAE=0.03529444774580946
# Random Forest validation for article_id 660712014: RMSE=0.016711384874353218, MAE=0.016134688304585778
# Random Forest predictions and validation tables with time information created successfully!

# %%
#RANDOMFOREST 7 DAYS 30% ITEMS, supreme Mighty Best Params Set

import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import warnings

warnings.filterwarnings("ignore")  # Suppress non-critical warnings

# Ensure `sale_date` is in datetime format
seasonal_data['sale_date'] = pd.to_datetime(seasonal_data['sale_date'])
seasonal_data = seasonal_data[seasonal_data['sale_date'] <= '2020-02-29']


# List of top 3ß% selling article IDs
top_30_percent = int(len(total_sales_id_sorted) * 0.3)
top_sample_article_ids = total_sales_id_sorted.head(top_30_percent)['article_id'].values

# Step 1: Filter `top_sample_article_ids` to include only those present in `item_params_final`
filtered_sample_ids = [article_id for article_id in top_sample_article_ids if article_id in item_params_final['article_id'].values]

# Step 2: Filter `seasonal_data` to include only items in the filtered sample
sampled_data = seasonal_data[seasonal_data['article_id'].isin(filtered_sample_ids)]

# Initialize dictionaries to store predictions and validation metrics
predictions_7_days = {}
validation_results = []

# Set default parameters for items without specific tuning information (if applicable)
default_params = {
    'max_depth': 10,
    'min_samples_split': 2,
    'n_estimators': 100
}

# Loop through each article in the filtered sampled set and apply Random Forest with validation
for article_id in filtered_sample_ids:
    # Filter data for the current article_id
    article_data = sampled_data[sampled_data['article_id'] == article_id]
    
    # Sort data by `sale_date`, set it as index
    article_data = article_data.set_index('sale_date').sort_index()
    article_data['total_sales'] = article_data['total_sales'].fillna(0)
    
    # Extract the time series for training
    ts_data = article_data['total_sales']
    
    # Check for sufficient data points
    if len(ts_data) < 60:  # Ensure at least 60 days of data for model stability
        continue
    
    # Fetch parameters for the current article_id from `item_params_final`
    params = item_params_final[item_params_final['article_id'] == article_id].iloc[0]

    # Use specific parameters if they exist, otherwise default to common ones
    if len(params) > 0:  # Check if params is not empty
        max_depth = int(params['max_depth'])
        min_samples_split = int(params['min_samples_split'])
        n_estimators = int(params['n_estimators'])

    else:
        max_depth = 10  # Default to the most common value
        min_samples_split = 2  # Default to the most common value
        n_estimators = 100  # Default to the most common value
    
    # Define the RandomForest model with the selected parameters
    rf_model = RandomForestRegressor(
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        n_estimators=n_estimators,
        random_state=42
    )
    
    # Split the data for validation: last 8 weeks (56 days)
    train_data = ts_data[:-56]  # All data except the last 8 weeks
    validation_data = ts_data[-56:]  # Last 8 weeks
    
    # Further split the last 8 weeks into 4-week training and 4-week validation sets
    rf_train = validation_data[:-28].values.reshape(-1, 1)  # First 4 weeks of the last 8 weeks
    rf_validation = validation_data[-28:].values  # Last 4 weeks of the last 8 weeks
    validation_dates = validation_data[-28:].index  # Dates for the validation period
    
    # Prepare target data for training
    y_train = train_data.values.reshape(-1, 1)
    
    # Fit the model on training data
    rf_model.fit(np.arange(len(y_train)).reshape(-1, 1), y_train.ravel())
    
    # Predict the next 7 days for forecasting using the trained model
    future_days = np.arange(len(y_train), len(y_train) + 7).reshape(-1, 1)
    forecast_7_days = rf_model.predict(future_days)
    predictions_7_days[article_id] = forecast_7_days
    
    # Validate the model on the 4-week validation period
    validation_days = np.arange(len(y_train), len(y_train) + 28).reshape(-1, 1)
    rf_validation_pred = rf_model.predict(validation_days)
    
    # Calculate RMSE and MAE on validation set
    rmse = np.sqrt(mean_squared_error(rf_validation, rf_validation_pred))
    mae = mean_absolute_error(rf_validation, rf_validation_pred)
    
    # Store each validation point with actual and predicted values, along with date
    for date, actual, predicted in zip(validation_dates, rf_validation, rf_validation_pred):
        validation_results.append({
            'article_id': article_id,
            'date': date,
            'total_sales': actual,
            'total_sales_predicted': predicted,
            'rmse': rmse,
            'mae': mae
        })

    print(f"Random Forest validation for article_id {article_id}: RMSE={rmse}, MAE={mae}")

# Convert predictions and validation results to DataFrames
forecast_df = pd.DataFrame(predictions_7_days).T  # Transpose so each article_id is a row
forecast_df.columns = [f"day_{i+1}" for i in range(7)]  # Rename columns for each forecasted day

validation_df = pd.DataFrame(validation_results)

# Save the results to CSV
forecast_df.to_csv("covid_30_rf_7_day_forecasts.csv", index=True)
validation_df.to_csv("covid_30_rf_7_day_validation_results_with_dates.csv", index=False)

print("Random Forest predictions and validation tables with time information created successfully!")
# Out:
# Random Forest validation for article_id 706016002: RMSE=0.549808418080242, MAE=0.3862977507619038
# Random Forest validation for article_id 568601006: RMSE=0.38776462276093465, MAE=0.32003002935911057
# Random Forest validation for article_id 448509014: RMSE=1.028374212113053, MAE=0.8776318890539858
# Random Forest validation for article_id 720125001: RMSE=1.1723946052733083, MAE=1.0341467297999989
# Random Forest validation for article_id 399223001: RMSE=0.36394992445390006, MAE=0.31856117152246605
# Random Forest validation for article_id 706016003: RMSE=1.246453165835904, MAE=1.1560983521278203
# Random Forest validation for article_id 562245046: RMSE=0.31784391253613603, MAE=0.27608948279999945
# Random Forest validation for article_id 751471001: RMSE=1.0201915122973442, MAE=0.9483195091285718
# Random Forest validation for article_id 661794001: RMSE=1.5301947365688624, MAE=1.5091359147857162
# Random Forest validation for article_id 706016015: RMSE=0.2582770120799426, MAE=0.2025072741428571
# Random Forest validation for article_id 562245001: RMSE=0.4216610564096799, MAE=0.40036453377857073
# Random Forest validation for article_id 554450001: RMSE=0.17983064149085012, MAE=0.15565170547845925
# Random Forest validation for article_id 399201002: RMSE=0.8922515717681178, MAE=0.8237308391501211
# Random Forest validation for article_id 687704001: RMSE=0.3707257823703122, MAE=0.28218054571428575
# Random Forest validation for article_id 399136009: RMSE=0.054981669722809996, MAE=0.04529074478928575
# Random Forest validation for article_id 741356002: RMSE=0.1619173220952705, MAE=0.1417064291357051
# Random Forest validation for article_id 673677002: RMSE=1.0530206972940568, MAE=1.022663104285714
# Random Forest validation for article_id 590928001: RMSE=0.9890199172237886, MAE=0.9610614329228572
# Random Forest validation for article_id 372860001: RMSE=0.23556987643331118, MAE=0.16777909842001618
# Random Forest validation for article_id 706016006: RMSE=0.4396174979971173, MAE=0.41539071704571784
# Random Forest validation for article_id 568597006: RMSE=0.11660657708370482, MAE=0.09195732807857157
# Random Forest validation for article_id 730683001: RMSE=0.45358290547601193, MAE=0.3921290270000009
# Random Forest validation for article_id 448509001: RMSE=0.34557990148526835, MAE=0.28761003303372673
# Random Forest validation for article_id 562245018: RMSE=0.13861735342505513, MAE=0.1235060693785718
# Random Forest validation for article_id 568601007: RMSE=0.36001228420553827, MAE=0.29500069840801313
# Random Forest validation for article_id 464297007: RMSE=0.4877383412422612, MAE=0.45645731472986534
# Random Forest validation for article_id 399201022: RMSE=0.10149657627419476, MAE=0.06735203455794288
# Random Forest validation for article_id 661794002: RMSE=0.31074524203299014, MAE=0.26804060026160753
# Random Forest validation for article_id 351484002: RMSE=0.198527136284462, MAE=0.17550047842857078
# Random Forest validation for article_id 573716012: RMSE=0.17356330443205414, MAE=0.1682290513168236
# Random Forest validation for article_id 714790020: RMSE=0.2544690638617172, MAE=0.20512636848571456
# Random Forest validation for article_id 753737001: RMSE=0.46018650505105485, MAE=0.32209462601041977
# Random Forest validation for article_id 695632002: RMSE=0.1923144820598533, MAE=0.15781720256232457
# Random Forest validation for article_id 399201005: RMSE=0.05486910884805074, MAE=0.040640520430059515
# Random Forest validation for article_id 685814001: RMSE=0.26853494283120427, MAE=0.23339198384406337
# Random Forest validation for article_id 799365002: RMSE=0.4571015061428434, MAE=0.403217230789611
# Random Forest validation for article_id 484398001: RMSE=0.16076932876742456, MAE=0.14694515567857153
# Random Forest validation for article_id 732842001: RMSE=0.2749316155173941, MAE=0.2178236988820297
# Random Forest validation for article_id 732842002: RMSE=0.15240136048757558, MAE=0.12788922392857144
# Random Forest validation for article_id 714790003: RMSE=0.4230507998114608, MAE=0.3689037543267237
# Random Forest validation for article_id 695632001: RMSE=0.17911256105544146, MAE=0.14527542499999999
# Random Forest validation for article_id 534181002: RMSE=0.739791630731637, MAE=0.6943339865256458
# Random Forest validation for article_id 684209004: RMSE=0.2067766808914657, MAE=0.14375059653571426
# Random Forest validation for article_id 578476001: RMSE=0.23182430033511484, MAE=0.19676851074935517
# Random Forest validation for article_id 658030011: RMSE=0.17599051536539284, MAE=0.14186109945571437
# Random Forest validation for article_id 399061008: RMSE=0.17180160934244912, MAE=0.12145834799750004
# Random Forest validation for article_id 507909001: RMSE=0.11308768237301715, MAE=0.08738126026571377
# Random Forest validation for article_id 640021005: RMSE=0.12886493830755144, MAE=0.1163231336506423
# Random Forest validation for article_id 399201042: RMSE=0.4962929552822149, MAE=0.4006868271192873
# Random Forest validation for article_id 783346001: RMSE=0.4075049455962655, MAE=0.3674912940999149
# Random Forest validation for article_id 399256001: RMSE=0.16022863572377552, MAE=0.12465352685677512
# Random Forest validation for article_id 573085028: RMSE=0.6878047713247272, MAE=0.6457346474706835
# Random Forest validation for article_id 399136004: RMSE=0.0950155272886189, MAE=0.07606615002141673
# Random Forest validation for article_id 749699002: RMSE=0.16853610144299552, MAE=0.1549305647847497
# Random Forest validation for article_id 572998001: RMSE=0.9334309581299717, MAE=0.8927237515649555
# Random Forest validation for article_id 714790008: RMSE=0.2602669615144003, MAE=0.19260394351273447
# Random Forest validation for article_id 399223029: RMSE=0.37032627916468336, MAE=0.3611003730778403
# Random Forest validation for article_id 372860002: RMSE=0.1186697643601674, MAE=0.09145057743253161
# Random Forest validation for article_id 640021011: RMSE=0.1039957511100209, MAE=0.08297422675142856
# Random Forest validation for article_id 790006001: RMSE=0.4897040809414873, MAE=0.45748142682143067
# Random Forest validation for article_id 579302001: RMSE=0.1738896341633653, MAE=0.14200302714285715
# Random Forest validation for article_id 658030001: RMSE=0.2809249749485651, MAE=0.25653978027220165
# Random Forest validation for article_id 708705001: RMSE=0.20035334781585742, MAE=0.16465309656842844
# Random Forest validation for article_id 699080001: RMSE=0.20775453438330774, MAE=0.17369170303516998
# Random Forest validation for article_id 731160005: RMSE=0.3133869876991996, MAE=0.2743280204028905
# Random Forest validation for article_id 749699001: RMSE=0.10121022638198639, MAE=0.0743386068964285
# Random Forest validation for article_id 687704002: RMSE=0.38415120324178126, MAE=0.35186609367720745
# Random Forest validation for article_id 534181011: RMSE=0.23768667616256767, MAE=0.21315975502142842
# Random Forest validation for article_id 685814003: RMSE=0.3098770988461046, MAE=0.1992978232142857
# Random Forest validation for article_id 731160004: RMSE=0.11286749141722292, MAE=0.09794014399751753
# Random Forest validation for article_id 534181005: RMSE=0.07397312515748275, MAE=0.039323610592857126
# Random Forest validation for article_id 636455003: RMSE=0.0788375221920798, MAE=0.07046861858748986
# Random Forest validation for article_id 740519002: RMSE=0.24736419585535094, MAE=0.22042278445311939
# Random Forest validation for article_id 666006004: RMSE=0.934130910647532, MAE=0.9331921383185707
# Random Forest validation for article_id 562245050: RMSE=0.11213177268189142, MAE=0.08835677928000016
# Random Forest validation for article_id 554450027: RMSE=0.2559932330010665, MAE=0.24015303400458168
# Random Forest validation for article_id 539723005: RMSE=0.018901039485987748, MAE=0.015678873823214333
# Random Forest validation for article_id 781613006: RMSE=0.20601178060900702, MAE=0.19799879989285715
# Random Forest validation for article_id 312878001: RMSE=0.1284274729111875, MAE=0.10736098642142933
# Random Forest validation for article_id 724906006: RMSE=0.3993752258932535, MAE=0.347097822600623
# Random Forest validation for article_id 600886001: RMSE=0.48829200798948047, MAE=0.4658502131017143
# Random Forest validation for article_id 723469001: RMSE=0.19247222380338722, MAE=0.17011746230065564
# Random Forest validation for article_id 666006006: RMSE=0.24503410350636334, MAE=0.24316791875997817
# Random Forest validation for article_id 554450004: RMSE=0.196488735427866, MAE=0.17967609132315612
# Random Forest validation for article_id 688537004: RMSE=0.1904381363082422, MAE=0.16847603752080823
# Random Forest validation for article_id 658030020: RMSE=0.22598369714164532, MAE=0.18719257231714184
# Random Forest validation for article_id 673396002: RMSE=0.07485108424681174, MAE=0.06026750100000013
# Random Forest validation for article_id 579541001: RMSE=0.07727850250729194, MAE=0.06284883534644561
# Random Forest validation for article_id 618800001: RMSE=0.5014536073564605, MAE=0.49749264037571467
# Random Forest validation for article_id 568597007: RMSE=0.2341946484287837, MAE=0.18821238774913399
# Random Forest validation for article_id 684209013: RMSE=0.27702916438981245, MAE=0.2738081132857146
# Random Forest validation for article_id 399223033: RMSE=0.5157837522021039, MAE=0.4977529500222218
# Random Forest validation for article_id 573085004: RMSE=0.052967471479572356, MAE=0.041368479191861256
# Random Forest validation for article_id 448509018: RMSE=0.565240890729914, MAE=0.5052350769096903
# Random Forest validation for article_id 399136061: RMSE=0.7389205425853502, MAE=0.7246062351485671
# Random Forest validation for article_id 554479001: RMSE=0.11061067712227167, MAE=0.0894483204074714
# Random Forest validation for article_id 399136011: RMSE=0.11030217617118401, MAE=0.10173964216736335
# Random Forest validation for article_id 539723001: RMSE=0.05263270595051456, MAE=0.052008311489092275
# Random Forest validation for article_id 655784001: RMSE=0.14050364719639244, MAE=0.12174517856788837
# Random Forest validation for article_id 743616009: RMSE=0.4980555932517582, MAE=0.4606293974588011
# Random Forest validation for article_id 712587003: RMSE=0.023083756844420995, MAE=0.021075951571428612
# Random Forest validation for article_id 805000001: RMSE=0.2903870004046156, MAE=0.2426634976714265
# Random Forest validation for article_id 769748002: RMSE=0.6413879370266973, MAE=0.5271051774571506
# Random Forest validation for article_id 772774001: RMSE=2.3308716580131352, MAE=2.319428060544768
# Random Forest validation for article_id 507910001: RMSE=0.02142322054029471, MAE=0.01908373847579221
# Random Forest validation for article_id 720125007: RMSE=0.4634111995381792, MAE=0.42581619287404776
# Random Forest validation for article_id 554450036: RMSE=0.09787522811596305, MAE=0.08594149324819048
# Random Forest validation for article_id 756318001: RMSE=0.2813400329738131, MAE=0.22258720487394137
# Random Forest validation for article_id 762846001: RMSE=0.5667499922125393, MAE=0.5360598740149711
# Random Forest validation for article_id 573937001: RMSE=0.09625490449124675, MAE=0.08351170061071436
# Random Forest validation for article_id 399201020: RMSE=0.06076286199713902, MAE=0.05569240458889964
# Random Forest validation for article_id 487722001: RMSE=0.11407516624436488, MAE=0.09139761581080771
# Random Forest validation for article_id 719655001: RMSE=0.20112194011051251, MAE=0.18012743281655555
# Random Forest validation for article_id 608776002: RMSE=0.29916508094944577, MAE=0.26852570021058747
# Random Forest validation for article_id 736530007: RMSE=0.23664869363358873, MAE=0.18293368162280088
# Random Forest validation for article_id 599580017: RMSE=0.18972918599172006, MAE=0.16447071211057143
# Random Forest validation for article_id 827635001: RMSE=0.301450848650959, MAE=0.2448623850051554
# Random Forest validation for article_id 752814003: RMSE=0.6940069724078872, MAE=0.6500802826798309
# Random Forest validation for article_id 188183001: RMSE=0.24681066257669904, MAE=0.2448865861502126
# Random Forest validation for article_id 610776002: RMSE=0.13869293646935296, MAE=0.12841245127351297
# Random Forest validation for article_id 762846008: RMSE=0.6417725575830989, MAE=0.5796515067460868
# Random Forest validation for article_id 772829002: RMSE=1.1832219677981723, MAE=1.17035025014286
# Random Forest validation for article_id 716672001: RMSE=0.0974885182108107, MAE=0.09578794993206449
# Random Forest validation for article_id 573085043: RMSE=0.4626194828660476, MAE=0.4095474320685719
# Random Forest validation for article_id 179950001: RMSE=0.10883451236008597, MAE=0.08540608552657779
# Random Forest validation for article_id 680262001: RMSE=0.02704104976185145, MAE=0.01649091340464286
# Random Forest validation for article_id 658030006: RMSE=0.09938713753867942, MAE=0.07875938427490932
# Random Forest validation for article_id 554479005: RMSE=0.026402743638147267, MAE=0.01971755319168424
# Random Forest validation for article_id 723529001: RMSE=0.19657924130201337, MAE=0.17729731589285716
# Random Forest validation for article_id 715343003: RMSE=0.14571706549222163, MAE=0.11582022392857146
# Random Forest validation for article_id 399061028: RMSE=0.37024326689424336, MAE=0.32171105140111916
# Random Forest validation for article_id 715624001: RMSE=0.5262284983856618, MAE=0.49747334514116176
# Random Forest validation for article_id 399201024: RMSE=0.1094151295821654, MAE=0.10696908006172152
# Random Forest validation for article_id 598859001: RMSE=0.1966422665901424, MAE=0.19261211996692781
# Random Forest validation for article_id 668537001: RMSE=0.07865951017998922, MAE=0.07543035337142898
# Random Forest validation for article_id 678942001: RMSE=0.3143606267179448, MAE=0.2852549113185712
# Random Forest validation for article_id 656763001: RMSE=0.03868606654220415, MAE=0.028079102097133688
# Random Forest validation for article_id 621381001: RMSE=0.10422221505610682, MAE=0.0927852649568818
# Random Forest validation for article_id 636323001: RMSE=0.1334222181340785, MAE=0.11419211900285728
# Random Forest validation for article_id 621381012: RMSE=0.11040604484582617, MAE=0.09103862815215728
# Random Forest validation for article_id 658298001: RMSE=0.5633236713400998, MAE=0.555585082842858
# Random Forest validation for article_id 639192002: RMSE=1.1748525409231014, MAE=1.174123773558353
# Random Forest validation for article_id 624257001: RMSE=0.22194931285552305, MAE=0.17777859700214343
# Random Forest validation for article_id 484205004: RMSE=0.0765690308930962, MAE=0.07298905500475904
# Random Forest validation for article_id 728156006: RMSE=0.257345650242736, MAE=0.2047937473891696
# Random Forest validation for article_id 764155001: RMSE=0.09548426588104382, MAE=0.06490382432142858
# Random Forest validation for article_id 714790017: RMSE=0.20489453219718892, MAE=0.16343854670044622
# Random Forest validation for article_id 559633001: RMSE=0.023953427867040633, MAE=0.019569998878499337
# Random Forest validation for article_id 730683041: RMSE=0.9916409459543454, MAE=0.9197150437142865
# Random Forest validation for article_id 758084002: RMSE=0.07976118249183338, MAE=0.07276388921342938
# Random Forest validation for article_id 687704012: RMSE=0.95050645475247, MAE=0.9424816517006464
# Random Forest validation for article_id 690936003: RMSE=0.07430768690044366, MAE=0.06929757708356284
# Random Forest validation for article_id 502224001: RMSE=0.11766761395880919, MAE=0.11293149451170635
# Random Forest validation for article_id 722169001: RMSE=0.18575717737581143, MAE=0.16964290233857277
# Random Forest validation for article_id 639448001: RMSE=0.3712057620289554, MAE=0.3602385316146755
# Random Forest validation for article_id 399087014: RMSE=0.18886112966483545, MAE=0.17658009843249484
# Random Forest validation for article_id 578487002: RMSE=0.07107198170949253, MAE=0.06239346239642849
# Random Forest validation for article_id 568808001: RMSE=0.0902002941247838, MAE=0.07892258488600648
# Random Forest validation for article_id 690936006: RMSE=0.4701374760561928, MAE=0.46975238562399463
# Random Forest validation for article_id 278811006: RMSE=0.10962839394468094, MAE=0.08758033909285753
# Random Forest validation for article_id 708138002: RMSE=0.31982465690207296, MAE=0.256504114751818
# Random Forest validation for article_id 699081001: RMSE=0.10413506138769348, MAE=0.07560003978262506
# Random Forest validation for article_id 815851001: RMSE=0.6399858618543537, MAE=0.6165418959589958
# Random Forest validation for article_id 688537011: RMSE=0.03278863990167592, MAE=0.024209408515714254
# Random Forest validation for article_id 547780001: RMSE=0.5365258879249228, MAE=0.5154888292277129
# Random Forest validation for article_id 741040001: RMSE=0.2116133840619777, MAE=0.18030856434285722
# Random Forest validation for article_id 160442007: RMSE=0.05202620180799714, MAE=0.04515280607285711
# Random Forest validation for article_id 697031002: RMSE=0.11781159136595751, MAE=0.09255936472859323
# Random Forest validation for article_id 684209001: RMSE=0.09718884412419364, MAE=0.09480168266757073
# Random Forest validation for article_id 690936002: RMSE=0.04493601364287722, MAE=0.04126884100518368
# Random Forest validation for article_id 658298007: RMSE=0.10201411411336077, MAE=0.08676400793297613
# Random Forest validation for article_id 399136027: RMSE=0.09242543507646012, MAE=0.08462604702698359
# Random Forest validation for article_id 305931001: RMSE=0.13689347681023853, MAE=0.11769563357411618
# Random Forest validation for article_id 790006003: RMSE=1.7857008235471028, MAE=1.7806052883996035
# Random Forest validation for article_id 706016019: RMSE=0.1553159300495176, MAE=0.12729558045000014
# Random Forest validation for article_id 795440001: RMSE=0.1622387857946826, MAE=0.12312615389642843
# Random Forest validation for article_id 401044004: RMSE=0.06964789171358128, MAE=0.06436737873391858
# Random Forest validation for article_id 399256005: RMSE=0.16256454307890147, MAE=0.14593322760501912
# Random Forest validation for article_id 796210001: RMSE=0.17287571943405577, MAE=0.14575143142857153
# Random Forest validation for article_id 660599002: RMSE=0.061434947520744534, MAE=0.0556510488910717
# Random Forest validation for article_id 537116001: RMSE=0.24146363634014265, MAE=0.18897069253886192
# Random Forest validation for article_id 680263003: RMSE=0.1057913505900148, MAE=0.10476365688928554
# Random Forest validation for article_id 536139006: RMSE=0.09191428672086623, MAE=0.07847410149774912
# Random Forest validation for article_id 534181008: RMSE=0.20843506847774265, MAE=0.18874199884285708
# Random Forest validation for article_id 729928001: RMSE=0.08796613115757014, MAE=0.07555091013400006
# Random Forest validation for article_id 253448003: RMSE=0.06754101725173359, MAE=0.05398163522285713
# Random Forest validation for article_id 762846006: RMSE=0.5751313312636052, MAE=0.5293825943901984
# Random Forest validation for article_id 652924004: RMSE=0.22051001052374505, MAE=0.18704845600971226
# Random Forest validation for article_id 636505001: RMSE=0.661740411617205, MAE=0.6279084619519443
# Random Forest validation for article_id 688105002: RMSE=0.11155975995761555, MAE=0.09602104744357196
# Random Forest validation for article_id 781613002: RMSE=0.0861598638144733, MAE=0.06079764403637756
# Random Forest validation for article_id 757303012: RMSE=0.301165154927035, MAE=0.2676295464300595
# Random Forest validation for article_id 729860002: RMSE=0.14853107402253857, MAE=0.12076294207857134
# Random Forest validation for article_id 677999001: RMSE=0.07004029596668929, MAE=0.04989508013372751
# Random Forest validation for article_id 578478001: RMSE=0.1312939325705967, MAE=0.09859789800902112
# Random Forest validation for article_id 399201025: RMSE=0.20885647646686492, MAE=0.1532097116289728
# Random Forest validation for article_id 719530003: RMSE=0.16111374421894237, MAE=0.14138969789285685
# Random Forest validation for article_id 706016004: RMSE=0.12312098812760962, MAE=0.10627356672221082
# Random Forest validation for article_id 636455005: RMSE=5.374857430350603, MAE=5.3745831767786685
# Random Forest validation for article_id 612481002: RMSE=0.05687183990673666, MAE=0.04248905434884213
# Random Forest validation for article_id 568601023: RMSE=0.25198202077286497, MAE=0.19940172801788192
# Random Forest validation for article_id 755362001: RMSE=0.2676803534636303, MAE=0.24904373755714235
# Random Forest validation for article_id 554598001: RMSE=0.12398098923685187, MAE=0.10933561205567145
# Random Forest validation for article_id 759814009: RMSE=0.2874161898353762, MAE=0.24967814809642816
# Random Forest validation for article_id 773989001: RMSE=0.2712476171023452, MAE=0.2702687895778848
# Random Forest validation for article_id 748355003: RMSE=0.1264461368132879, MAE=0.1059232868771425
# Random Forest validation for article_id 714927002: RMSE=0.276216011378651, MAE=0.24800086453428247
# Random Forest validation for article_id 610776001: RMSE=0.04355776206085823, MAE=0.03475646735004648
# Random Forest validation for article_id 690936001: RMSE=0.35683451434987756, MAE=0.35644921722768447
# Random Forest validation for article_id 600886011: RMSE=0.07922552964822425, MAE=0.06837075607652611
# Random Forest validation for article_id 791587001: RMSE=0.42139672411667356, MAE=0.37528245522828846
# Random Forest validation for article_id 562245062: RMSE=0.21654594301104507, MAE=0.20974094827886353
# Random Forest validation for article_id 680265002: RMSE=0.11188934882624721, MAE=0.1076637645918571
# Random Forest validation for article_id 535035001: RMSE=0.346153720436456, MAE=0.3259641392540515
# Random Forest validation for article_id 760084003: RMSE=0.13045430757983947, MAE=0.10514007323777982
# Random Forest validation for article_id 695545001: RMSE=0.05800745157223306, MAE=0.05543209739914242
# Random Forest validation for article_id 803757001: RMSE=0.1530377957100327, MAE=0.12187685682857079
# Random Forest validation for article_id 611415001: RMSE=0.12383231123862709, MAE=0.1075048095145389
# Random Forest validation for article_id 698276001: RMSE=1.2402692962229886, MAE=1.2340085898932547
# Random Forest validation for article_id 158340001: RMSE=0.14680456590155372, MAE=0.11748083377142858
# Random Forest validation for article_id 758034001: RMSE=0.3453120493227051, MAE=0.32319242674775517
# Random Forest validation for article_id 612935009: RMSE=0.2839617338876908, MAE=0.28314960175006065
# Random Forest validation for article_id 762063001: RMSE=0.10742917228495612, MAE=0.08732030622265825
# Random Forest validation for article_id 534181003: RMSE=0.31663309684659424, MAE=0.3070095542345071
# Random Forest validation for article_id 690936013: RMSE=0.11860302088985998, MAE=0.11788852508577334
# Random Forest validation for article_id 664133001: RMSE=0.13035909603555335, MAE=0.10733606648098307
# Random Forest validation for article_id 640021012: RMSE=0.16863229442923378, MAE=0.1528608620543956
# Random Forest validation for article_id 603584018: RMSE=0.043284228627047255, MAE=0.029295066547078207
# Random Forest validation for article_id 715624010: RMSE=0.2026098669799328, MAE=0.1679154942148588
# Random Forest validation for article_id 160442010: RMSE=0.1253666537025537, MAE=0.11257405291834295
# Random Forest validation for article_id 615141002: RMSE=0.04524551905436457, MAE=0.034417536245714274
# Random Forest validation for article_id 540768002: RMSE=0.06161577635496842, MAE=0.055845145665032854
# Random Forest validation for article_id 684340001: RMSE=0.03346650305537339, MAE=0.024341870368544634
# Random Forest validation for article_id 537688014: RMSE=0.017699487469298808, MAE=0.015484542339714396
# Random Forest validation for article_id 658030016: RMSE=0.1488115370845773, MAE=0.12163843867857152
# Random Forest validation for article_id 740498001: RMSE=0.4647156962946623, MAE=0.45840486848999523
# Random Forest validation for article_id 568601030: RMSE=0.5856128770926432, MAE=0.4245769128513629
# Random Forest validation for article_id 700144001: RMSE=0.2632530769756671, MAE=0.26039773896428664
# Random Forest validation for article_id 589599031: RMSE=0.05177915281181182, MAE=0.03230461351026854
# Random Forest validation for article_id 516903005: RMSE=0.11676997304898708, MAE=0.10473215150392824
# Random Forest validation for article_id 742561001: RMSE=0.5542712712782276, MAE=0.5487775878888511
# Random Forest validation for article_id 554450019: RMSE=0.04697010668355477, MAE=0.032377448488799164
# Random Forest validation for article_id 664074001: RMSE=0.08854722982187671, MAE=0.07603407682142846
# Random Forest validation for article_id 623115001: RMSE=0.38051625617854357, MAE=0.37410343093571485
# Random Forest validation for article_id 790006002: RMSE=0.1885242260266128, MAE=0.12323777289285598
# Random Forest validation for article_id 529953007: RMSE=0.18150068303498418, MAE=0.17230234233108313
# Random Forest validation for article_id 662418001: RMSE=0.10677212585458498, MAE=0.09556663785149389
# Random Forest validation for article_id 702790004: RMSE=0.13665005372286168, MAE=0.13607695789916666
# Random Forest validation for article_id 698776002: RMSE=0.050788569467178434, MAE=0.04551157616999961
# Random Forest validation for article_id 794575001: RMSE=0.15675266728978782, MAE=0.13849460306461933
# Random Forest validation for article_id 506098007: RMSE=0.18127754901883283, MAE=0.1527929375143631
# Random Forest validation for article_id 399201023: RMSE=0.09876779187812809, MAE=0.08961484469714291
# Random Forest validation for article_id 809961002: RMSE=0.6399639159791773, MAE=0.6114547290457174
# Random Forest validation for article_id 714803001: RMSE=0.35118019299205655, MAE=0.3507770819142852
# Random Forest validation for article_id 682550001: RMSE=0.10946983652779384, MAE=0.09429320754621613
# Random Forest validation for article_id 399136033: RMSE=0.05240992734631603, MAE=0.049675246865921015
# Random Forest validation for article_id 728156001: RMSE=0.18644253557330623, MAE=0.17105559819844
# Random Forest validation for article_id 507909003: RMSE=0.08634139709008355, MAE=0.06856979617552501
# Random Forest validation for article_id 699075001: RMSE=0.10110303765021476, MAE=0.10056004473947625
# Random Forest validation for article_id 574109011: RMSE=0.04707941832115566, MAE=0.02973849875
# Random Forest validation for article_id 714824001: RMSE=0.051072555263935906, MAE=0.039294712648503094
# Random Forest validation for article_id 779324004: RMSE=0.18510379993753678, MAE=0.170993117557143
# Random Forest validation for article_id 733267001: RMSE=0.07309491209499197, MAE=0.07082978461142808
# Random Forest validation for article_id 711440001: RMSE=0.10747719331592032, MAE=0.082423288506425
# Random Forest validation for article_id 751471016: RMSE=0.09397945599637693, MAE=0.08905401925040232
# Random Forest validation for article_id 730683019: RMSE=1.0584164249114998, MAE=1.045096247195239
# Random Forest validation for article_id 705786001: RMSE=0.08594332354785618, MAE=0.07187754109714316
# Random Forest validation for article_id 650122001: RMSE=0.1860905123269531, MAE=0.1752801318867822
# Random Forest validation for article_id 652730004: RMSE=0.17657867178152672, MAE=0.1599122932205365
# Random Forest validation for article_id 399087030: RMSE=0.06792345185601371, MAE=0.05432256539589111
# Random Forest validation for article_id 797710001: RMSE=0.2033554872051486, MAE=0.20082677402792387
# Random Forest validation for article_id 179123001: RMSE=0.16590384082146944, MAE=0.16315402037571397
# Random Forest validation for article_id 697054014: RMSE=0.15448669157154335, MAE=0.13705477256072432
# Random Forest validation for article_id 759871002: RMSE=0.061373642167410314, MAE=0.049349978852350304
# Random Forest validation for article_id 689109001: RMSE=0.03125392437375764, MAE=0.030858906273165565
# Random Forest validation for article_id 758064001: RMSE=0.04501934114900187, MAE=0.026803511217857134
# Random Forest validation for article_id 539723003: RMSE=0.014299289719841991, MAE=0.010568895547857117
# Random Forest validation for article_id 658030017: RMSE=0.13687010593828003, MAE=0.10315577243532593
# Random Forest validation for article_id 820873001: RMSE=0.1392111332945797, MAE=0.11397186434142857
# Random Forest validation for article_id 745475001: RMSE=0.16852840312290787, MAE=0.1676531177012302
# Random Forest validation for article_id 663679001: RMSE=0.05490428038020563, MAE=0.05276259056150007
# Random Forest validation for article_id 709138001: RMSE=0.32104309309490237, MAE=0.32016118094851365
# Random Forest validation for article_id 711053003: RMSE=0.08027829886653769, MAE=0.07140843207949409
# Random Forest validation for article_id 698387001: RMSE=0.23233641488045903, MAE=0.18207134603224315
# Random Forest validation for article_id 673677004: RMSE=0.16435355456827763, MAE=0.14759122232674396
# Random Forest validation for article_id 524061003: RMSE=0.04390645817119965, MAE=0.024997403715228343
# Random Forest validation for article_id 714828002: RMSE=0.07817615350787584, MAE=0.07541058357857147
# Random Forest validation for article_id 697091007: RMSE=0.04981607071328038, MAE=0.04289129903346432
# Random Forest validation for article_id 562245093: RMSE=0.08661397815430685, MAE=0.06962505651050287
# Random Forest validation for article_id 688873002: RMSE=0.02056972890024962, MAE=0.012419734239285718
# Random Forest validation for article_id 744786001: RMSE=0.024599023420529737, MAE=0.01960361328004621
# Random Forest validation for article_id 573716053: RMSE=0.031467980834742254, MAE=0.029657416834840272
# Random Forest validation for article_id 569562005: RMSE=0.43128469049333573, MAE=0.22190585872571425
# Random Forest validation for article_id 706016007: RMSE=0.7520143504497707, MAE=0.5963552864285714
# Random Forest validation for article_id 714807003: RMSE=0.1415730734548005, MAE=0.11569272395977429
# Random Forest validation for article_id 824185001: RMSE=0.36990817678170174, MAE=0.3502043450000002
# Random Forest validation for article_id 752814004: RMSE=0.08865944942384492, MAE=0.07948528094428543
# Random Forest validation for article_id 783384008: RMSE=0.22559916522228515, MAE=0.1841813001014286
# Random Forest validation for article_id 787946002: RMSE=0.0966850533817845, MAE=0.0826566528088524
# Random Forest validation for article_id 399087010: RMSE=0.10424239351006309, MAE=0.09086111625082553
# Random Forest validation for article_id 400285006: RMSE=0.1727326419121275, MAE=0.15749350855401914
# Random Forest validation for article_id 721268001: RMSE=0.09121874864084985, MAE=0.06753232603571423
# Random Forest validation for article_id 658030005: RMSE=0.027261293067984377, MAE=0.01905414358857171
# Random Forest validation for article_id 720504001: RMSE=0.10132918289194635, MAE=0.08392550357381025
# Random Forest validation for article_id 637283006: RMSE=0.1270415265168648, MAE=0.12547352281560084
# Random Forest validation for article_id 634426008: RMSE=0.06483867077758136, MAE=0.05343186681621833
# Random Forest validation for article_id 704756001: RMSE=0.0729592584105506, MAE=0.057901689889285866
# Random Forest validation for article_id 685813001: RMSE=0.10598960519160942, MAE=0.08344067049999968
# Random Forest validation for article_id 111586001: RMSE=0.1901788220280692, MAE=0.16865856793704986
# Random Forest validation for article_id 547058001: RMSE=0.41172339749365106, MAE=0.4107068709549996
# Random Forest validation for article_id 456163060: RMSE=0.5631663350929856, MAE=0.5130684210714261
# Random Forest validation for article_id 788846004: RMSE=0.34040745454299737, MAE=0.31247003737142937
# Random Forest validation for article_id 599580020: RMSE=0.02237006682426195, MAE=0.012409582889000017
# Random Forest validation for article_id 749615001: RMSE=0.08041190452501425, MAE=0.06013881371142858
# Random Forest validation for article_id 743616001: RMSE=0.1799032451992491, MAE=0.16211286987857138
# Random Forest validation for article_id 539723006: RMSE=0.027961979328713697, MAE=0.011855289754285717
# Random Forest validation for article_id 111593001: RMSE=0.08412692768668668, MAE=0.06852610455034698
# Random Forest validation for article_id 524825011: RMSE=0.024182306271561652, MAE=0.020473516308928692
# Random Forest validation for article_id 399223035: RMSE=0.16061338723760393, MAE=0.1559366902356711
# Random Forest validation for article_id 611415005: RMSE=0.2755120864401033, MAE=0.2537771553445079
# Random Forest validation for article_id 684824003: RMSE=0.4408599416993488, MAE=0.43942504583642983
# Random Forest validation for article_id 768912001: RMSE=0.14030467810156214, MAE=0.11891621784999355
# Random Forest validation for article_id 622955001: RMSE=0.34811094879198284, MAE=0.3438876926999993
# Random Forest validation for article_id 599502001: RMSE=0.07727176894554194, MAE=0.07194261328970215
# Random Forest validation for article_id 743594003: RMSE=0.07970933735247886, MAE=0.06034351324857147
# Random Forest validation for article_id 253448001: RMSE=0.14044191507682652, MAE=0.11177482295366023
# Random Forest validation for article_id 775825001: RMSE=1.3654561417600835, MAE=1.3605322428057103
# Random Forest validation for article_id 712587004: RMSE=0.025666710718248182, MAE=0.019661579881108
# Random Forest validation for article_id 745475002: RMSE=0.3716586317600492, MAE=0.3704881773107195
# Random Forest validation for article_id 571706001: RMSE=0.054370326442757445, MAE=0.04282673508192176
# Random Forest validation for article_id 590928011: RMSE=0.014719168272037822, MAE=0.010910259512111121
# Random Forest validation for article_id 748269003: RMSE=0.11340075184074547, MAE=0.10386718724398795
# Random Forest validation for article_id 697031001: RMSE=0.03781302935443761, MAE=0.033996876313095274
# Random Forest validation for article_id 772832001: RMSE=0.28848865978661153, MAE=0.24955268063409977
# Random Forest validation for article_id 557994003: RMSE=0.050397502167025716, MAE=0.03345823259714286
# Random Forest validation for article_id 455832001: RMSE=0.06196192664830607, MAE=0.05298372527853584
# Random Forest validation for article_id 771829005: RMSE=0.12444378188157042, MAE=0.10960435475000001
# Random Forest validation for article_id 639151001: RMSE=0.0941802106475504, MAE=0.08909043017321391
# Random Forest validation for article_id 812207002: RMSE=0.5785597096871659, MAE=0.5510401551976188
# Random Forest validation for article_id 675068002: RMSE=0.0715630436950991, MAE=0.06169010692857164
# Random Forest validation for article_id 730863005: RMSE=0.20281485960218554, MAE=0.13016063468840403
# Random Forest validation for article_id 399223034: RMSE=0.6257664556728665, MAE=0.6182011947006278
# Random Forest validation for article_id 399201026: RMSE=0.052885743923702065, MAE=0.048431716628956116
# Random Forest validation for article_id 429313006: RMSE=0.09557850643611032, MAE=0.07861699294637635
# Random Forest validation for article_id 736870001: RMSE=0.1151737450367416, MAE=0.09518386844214284
# Random Forest validation for article_id 624486001: RMSE=0.06265069976115543, MAE=0.049878869287689795
# Random Forest validation for article_id 685814033: RMSE=0.2588545680907131, MAE=0.21381701125476532
# Random Forest validation for article_id 537346026: RMSE=0.0984320603967101, MAE=0.09742865115149532
# Random Forest validation for article_id 688105003: RMSE=0.08758006466073437, MAE=0.0748245690190392
# Random Forest validation for article_id 664319021: RMSE=0.025185785234654597, MAE=0.023674114938571595
# Random Forest validation for article_id 803468002: RMSE=0.16693963708621493, MAE=0.13715377776716514
# Random Forest validation for article_id 589599047: RMSE=0.02385378703892767, MAE=0.019559171602131876
# Random Forest validation for article_id 781613001: RMSE=0.18800920237062899, MAE=0.1850434517999998
# Random Forest validation for article_id 719957006: RMSE=0.19673111238051547, MAE=0.1699027640442845
# Random Forest validation for article_id 692632001: RMSE=0.2625277522829222, MAE=0.2590496896214289
# Random Forest validation for article_id 469137001: RMSE=0.35230664248705973, MAE=0.3517382260769926
# Random Forest validation for article_id 806388002: RMSE=0.04951009887171426, MAE=0.03847042982742853
# Random Forest validation for article_id 708311001: RMSE=0.1719797081923918, MAE=0.12061974364383074
# Random Forest validation for article_id 680264001: RMSE=0.05094048683449175, MAE=0.045206251831736446
# Random Forest validation for article_id 562245004: RMSE=0.0781318230871282, MAE=0.07505325462949008
# Random Forest validation for article_id 698276004: RMSE=0.2885811018088364, MAE=0.24711760048855222
# Random Forest validation for article_id 812167002: RMSE=0.4412389070910713, MAE=0.438309294242857
# Random Forest validation for article_id 762846007: RMSE=0.3160075761127564, MAE=0.21823823748371413
# Random Forest validation for article_id 772829001: RMSE=1.8083709870874982, MAE=1.7813189621889725
# Random Forest validation for article_id 811777001: RMSE=0.3553336123727357, MAE=0.29987613927143036
# Random Forest validation for article_id 698718002: RMSE=0.06741602227801934, MAE=0.04219619718906038
# Random Forest validation for article_id 771829002: RMSE=0.6754639894475338, MAE=0.6684914193999995
# Random Forest validation for article_id 399087021: RMSE=0.07182791878313757, MAE=0.05460393743513673
# Random Forest validation for article_id 572998002: RMSE=0.0684094836928915, MAE=0.06322911942857161
# Random Forest validation for article_id 806388001: RMSE=0.1113171103595329, MAE=0.08520566379142865
# Random Forest validation for article_id 573716050: RMSE=0.06815223246879144, MAE=0.06471422562348868
# Random Forest validation for article_id 537688010: RMSE=1.7429769319853325, MAE=1.7419708516382018
# Random Forest validation for article_id 673799001: RMSE=0.01963110558066502, MAE=0.01720392338928569
# Random Forest validation for article_id 756322001: RMSE=0.06423951514870356, MAE=0.05390035903177561
# Random Forest validation for article_id 716672003: RMSE=0.1171896789387338, MAE=0.1166949200653187
# Random Forest validation for article_id 687704039: RMSE=0.2503490463808427, MAE=0.20250665250000002
# Random Forest validation for article_id 827637001: RMSE=1.8659521067543707, MAE=1.843873912143814
# Random Forest validation for article_id 723469002: RMSE=0.10909771750392999, MAE=0.08746070094428614
# Random Forest validation for article_id 563519008: RMSE=0.19640430064579906, MAE=0.19490205192844678
# Random Forest validation for article_id 662948003: RMSE=0.393611454854352, MAE=0.39325012372175616
# Random Forest validation for article_id 660599016: RMSE=0.1643606168405712, MAE=0.15622087935430137
# Random Forest validation for article_id 591334003: RMSE=0.03046305422915247, MAE=0.023905337549119027
# Random Forest validation for article_id 688432001: RMSE=0.0257968103921785, MAE=0.020121806331785723
# Random Forest validation for article_id 700701001: RMSE=0.08360097899923241, MAE=0.05944020940824425
# Random Forest validation for article_id 736489003: RMSE=0.06167541868153387, MAE=0.0504424194703222
# Random Forest validation for article_id 640542002: RMSE=0.06823782972898262, MAE=0.056008970549193626
# Random Forest validation for article_id 660599001: RMSE=0.04968862004989189, MAE=0.037003631892857144
# Random Forest validation for article_id 519583008: RMSE=0.09198167224302588, MAE=0.08427165238480941
# Random Forest validation for article_id 552716001: RMSE=0.13795907151353382, MAE=0.11680872779394569
# Random Forest validation for article_id 780297001: RMSE=0.05402906046348166, MAE=0.05226641081643623
# Random Forest validation for article_id 750330002: RMSE=0.05209107247785838, MAE=0.03871268950765023
# Random Forest validation for article_id 692930001: RMSE=0.048866260034842686, MAE=0.0460321096384027
# Random Forest validation for article_id 534164001: RMSE=0.12449462460883978, MAE=0.11042135071474558
# Random Forest validation for article_id 687704028: RMSE=0.8126119376456652, MAE=0.8025729494278225
# Random Forest validation for article_id 688873001: RMSE=0.028870607716130803, MAE=0.027688738863928593
# Random Forest validation for article_id 572797001: RMSE=0.07166610169526137, MAE=0.0529362488051112
# Random Forest validation for article_id 590928022: RMSE=0.25475457628643206, MAE=0.2049911620228571
# Random Forest validation for article_id 811198002: RMSE=0.08505701523931267, MAE=0.07951417611250004
# Random Forest validation for article_id 751664001: RMSE=0.3620219909287082, MAE=0.34358883172100013
# Random Forest validation for article_id 656719005: RMSE=0.02189601609955842, MAE=0.015638611922571682
# Random Forest validation for article_id 547780003: RMSE=0.11680456992346185, MAE=0.10143855941250832
# Random Forest validation for article_id 801512004: RMSE=0.3668212956010351, MAE=0.33415593545204997
# Random Forest validation for article_id 796210010: RMSE=0.3178175972118223, MAE=0.2751451883385087
# Random Forest validation for article_id 670655001: RMSE=0.3072559474385396, MAE=0.3061882213788191
# Random Forest validation for article_id 564786001: RMSE=0.06043464312055184, MAE=0.04695406749928568
# Random Forest validation for article_id 772822001: RMSE=1.0297401457933426, MAE=1.0260013702999962
# Random Forest validation for article_id 738943005: RMSE=0.2408489769180196, MAE=0.23874720132857144
# Random Forest validation for article_id 754238001: RMSE=0.20824298200032676, MAE=0.1801309938295997
# Random Forest validation for article_id 156231001: RMSE=0.1057980237161881, MAE=0.087948581182143
# Random Forest validation for article_id 301656026: RMSE=0.12192215906063136, MAE=0.10313459396837198
# Random Forest validation for article_id 624257003: RMSE=0.17561971334494866, MAE=0.15735392723836727
# Random Forest validation for article_id 559634009: RMSE=0.17319271557471422, MAE=0.17276886166484534
# Random Forest validation for article_id 821031002: RMSE=0.6601420449410531, MAE=0.6533662025285703
# Random Forest validation for article_id 751941002: RMSE=0.020953829621201906, MAE=0.01988242121571429
# Random Forest validation for article_id 704668001: RMSE=0.3850970753207021, MAE=0.38335495195861097
# Random Forest validation for article_id 573085033: RMSE=0.37530768603519943, MAE=0.3720176238685749
# Random Forest validation for article_id 689109003: RMSE=0.013348455970574232, MAE=0.008352710615857144
# Random Forest validation for article_id 837941001: RMSE=0.24829839371597565, MAE=0.20673182971527157
# Random Forest validation for article_id 735583001: RMSE=0.029430877132193105, MAE=0.019551420411257847
# Random Forest validation for article_id 470789001: RMSE=0.044818432738319175, MAE=0.03812163515770928
# Random Forest validation for article_id 534357002: RMSE=0.041074596631826804, MAE=0.03189309747142859
# Random Forest validation for article_id 684341001: RMSE=0.017641869752850006, MAE=0.012227239509427815
# Random Forest validation for article_id 688558001: RMSE=0.04303427458706374, MAE=0.03437624204628558
# Random Forest validation for article_id 622958003: RMSE=0.0888312074570685, MAE=0.07158859461979454
# Random Forest validation for article_id 750422018: RMSE=0.20380651646762593, MAE=0.15140419928185642
# Random Forest validation for article_id 755362003: RMSE=1.7887484730676515, MAE=1.785550149317667
# Random Forest validation for article_id 787148001: RMSE=0.3913569041899739, MAE=0.3337414879789726
# Random Forest validation for article_id 744180001: RMSE=0.06990363676034028, MAE=0.0654324056607144
# Random Forest validation for article_id 559633008: RMSE=0.22830520360287646, MAE=0.19538038485563233
# Random Forest validation for article_id 801309002: RMSE=0.26584791909263394, MAE=0.2560369411599974
# Random Forest validation for article_id 678686001: RMSE=0.0765684156213618, MAE=0.07376156709605687
# Random Forest validation for article_id 717727002: RMSE=0.2096371627786728, MAE=0.20898396473571407
# Random Forest validation for article_id 559616013: RMSE=0.2856537930938689, MAE=0.28557509607500026
# Random Forest validation for article_id 661794006: RMSE=0.1165225007024243, MAE=0.10339183085714287
# Random Forest validation for article_id 799742003: RMSE=1.0418688264293912, MAE=1.0370230418047657
# Random Forest validation for article_id 727029001: RMSE=0.03819448512311567, MAE=0.02992731372339285
# Random Forest validation for article_id 719530004: RMSE=0.36159838660552607, MAE=0.28615640217051735
# Random Forest validation for article_id 707269003: RMSE=0.2742683666143068, MAE=0.26489513620714294
# Random Forest validation for article_id 786752001: RMSE=0.3371727112803879, MAE=0.3247198756185031
# Random Forest validation for article_id 656719015: RMSE=0.049525649072339896, MAE=0.043123462757142884
# Random Forest validation for article_id 714807004: RMSE=0.13822460573279918, MAE=0.11720405285644843
# Random Forest validation for article_id 787049001: RMSE=1.011169247567586, MAE=1.007708737235716
# Random Forest validation for article_id 554450005: RMSE=0.04518364827409838, MAE=0.03496913198364695
# Random Forest validation for article_id 739144004: RMSE=0.027878486221395618, MAE=0.016693123500571463
# Random Forest validation for article_id 534181010: RMSE=4.588388231217467, MAE=4.5864220906482105
# Random Forest validation for article_id 779842001: RMSE=0.21679999936091135, MAE=0.19564367300357116
# Random Forest validation for article_id 697091002: RMSE=0.03014169940115309, MAE=0.025533291785714285
# Random Forest validation for article_id 649437002: RMSE=0.03655504194115538, MAE=0.019918776907071407
# Random Forest validation for article_id 756633001: RMSE=0.042336171488613926, MAE=0.029667941881428576
# Random Forest validation for article_id 668537002: RMSE=0.5874932083019789, MAE=0.586661770906419
# Random Forest validation for article_id 673901001: RMSE=0.06998188213677822, MAE=0.0690907138142858
# Random Forest validation for article_id 785018003: RMSE=0.2156384131337298, MAE=0.18724339752857166
# Random Forest validation for article_id 708705004: RMSE=0.4613325262836104, MAE=0.449543913244043
# Random Forest validation for article_id 700701002: RMSE=0.08467126694539205, MAE=0.06962671714281211
# Random Forest validation for article_id 537346013: RMSE=0.25793171073151233, MAE=0.2567441272253732
# Random Forest validation for article_id 827635002: RMSE=0.20095522906467303, MAE=0.16522530542735384
# Random Forest validation for article_id 738943003: RMSE=0.12136863285225688, MAE=0.11712061634999979
# Random Forest validation for article_id 671852003: RMSE=0.040159728100914276, MAE=0.03129024672519183
# Random Forest validation for article_id 720125004: RMSE=0.09882031007399754, MAE=0.09576040391828654
# Random Forest validation for article_id 607154001: RMSE=0.023832724344990938, MAE=0.018684026539704773
# Random Forest validation for article_id 684340002: RMSE=0.03649540492033077, MAE=0.025389823745809507
# Random Forest validation for article_id 621381016: RMSE=0.1558364906138021, MAE=0.14194750568622258
# Random Forest validation for article_id 189616006: RMSE=0.17340426872619147, MAE=0.16732869450432403
# Random Forest validation for article_id 680262010: RMSE=0.043722462507273026, MAE=0.043025206212724744
# Random Forest validation for article_id 457892003: RMSE=0.1532166442511633, MAE=0.14264308747979834
# Random Forest validation for article_id 562245064: RMSE=0.01765246445418663, MAE=0.013194915
# Random Forest validation for article_id 662948012: RMSE=0.053587783151210405, MAE=0.048938651287143274
# Random Forest validation for article_id 748355002: RMSE=1.6604708576326024, MAE=1.657348705853433
# Random Forest validation for article_id 806388003: RMSE=0.05245412394622692, MAE=0.037290331625483675
# Random Forest validation for article_id 684080001: RMSE=0.960697565447734, MAE=0.9600547370107128
# Random Forest validation for article_id 731644001: RMSE=0.32154421948822587, MAE=0.32104454941733057
# Random Forest validation for article_id 448515001: RMSE=0.1167245731813035, MAE=0.09304492876926591
# Random Forest validation for article_id 732842004: RMSE=0.06059878853979001, MAE=0.045386575340194746
# Random Forest validation for article_id 733123004: RMSE=0.2717532044558111, MAE=0.2710662922014266
# Random Forest validation for article_id 700851001: RMSE=0.153102913821523, MAE=0.152253926851404
# Random Forest validation for article_id 702790003: RMSE=0.07553012918637764, MAE=0.07473798950508341
# Random Forest validation for article_id 678965001: RMSE=0.08079896735550011, MAE=0.07755008229890002
# Random Forest validation for article_id 758049001: RMSE=0.042105840914318, MAE=0.03769054621999989
# ...
# Random Forest validation for article_id 793856005: RMSE=0.386933161761102, MAE=0.38272132453571445
# Random Forest validation for article_id 669682006: RMSE=0.09484790664879394, MAE=0.09254222004464355
# Random Forest validation for article_id 816933001: RMSE=0.20772128728248634, MAE=0.17569039173775505
# Random Forest validation for article_id 524529010: RMSE=0.7307705785114539, MAE=0.7304943283917578
# Random Forest validation for article_id 789301001: RMSE=0.2615106841402065, MAE=0.26024602008809533
# Random Forest validation for article_id 755738001: RMSE=0.06379702260552265, MAE=0.060984777192106106
# Random Forest validation for article_id 718086003: RMSE=0.07317293830909509, MAE=0.05025241273272403
# Random Forest validation for article_id 665481013: RMSE=0.307371269740575, MAE=0.25373016315795927
# Random Forest validation for article_id 684824001: RMSE=0.02572497701969277, MAE=0.017723951222142997
# Random Forest validation for article_id 712924008: RMSE=0.009830292762426173, MAE=0.008271424327285755
# Random Forest validation for article_id 698387003: RMSE=0.08975584564362438, MAE=0.08439153215214108
# Random Forest validation for article_id 701046001: RMSE=0.02674520679876539, MAE=0.023234888703021893
# Random Forest validation for article_id 598859009: RMSE=0.1429406920739992, MAE=0.13704807195535687
# Random Forest validation for article_id 637566007: RMSE=0.03967114114536563, MAE=0.029718620285714266
# Random Forest validation for article_id 669715001: RMSE=0.34098854804621187, MAE=0.339893179426192
# Random Forest validation for article_id 790791002: RMSE=0.0436354839541949, MAE=0.03164543643214261
# Random Forest validation for article_id 722437003: RMSE=0.02313987764630605, MAE=0.02232099478964277
# Random Forest validation for article_id 788324008: RMSE=0.23946282052371456, MAE=0.23883830551883362
# Random Forest validation for article_id 775996015: RMSE=0.12267300314585902, MAE=0.1207258878899995
# Random Forest validation for article_id 824999001: RMSE=0.18880755520900333, MAE=0.15843163924553388
# Random Forest validation for article_id 706016028: RMSE=0.09981998121047969, MAE=0.0941828756996906
# Random Forest validation for article_id 761406001: RMSE=0.3662324403303079, MAE=0.36489157453285825
# Random Forest validation for article_id 794779001: RMSE=0.17707972930026478, MAE=0.17207258100219894
# Random Forest validation for article_id 705974001: RMSE=0.06927918895396372, MAE=0.06378454858571468
# Random Forest validation for article_id 772149001: RMSE=0.01993489056484994, MAE=0.01825636993227242
# Random Forest validation for article_id 676539001: RMSE=0.035689460309607256, MAE=0.02270798452447758
# Random Forest validation for article_id 685150002: RMSE=0.08051122877831957, MAE=0.07866579984387803
# Random Forest validation for article_id 787147002: RMSE=1.2733876944378113, MAE=1.270768530353105
# Random Forest validation for article_id 763037001: RMSE=0.04481677695511827, MAE=0.035321530094540456
# Random Forest validation for article_id 556260001: RMSE=0.06504605837524294, MAE=0.04611104273592518
# Random Forest validation for article_id 606395006: RMSE=0.060370994105316364, MAE=0.051825953384455836
# Random Forest validation for article_id 456163048: RMSE=0.6987346639204703, MAE=0.698408946807142
# Random Forest validation for article_id 783444001: RMSE=0.17663411866412257, MAE=0.17573056739571302
# Random Forest validation for article_id 395127011: RMSE=0.03283605647024501, MAE=0.026278322503595214
# Random Forest validation for article_id 639258002: RMSE=0.044926624977730416, MAE=0.02925529222857152
# Random Forest validation for article_id 687704027: RMSE=0.19991688635432556, MAE=0.1543331856785431
# Random Forest validation for article_id 706016011: RMSE=0.03541077141114871, MAE=0.027555926545398585
# Random Forest validation for article_id 676990001: RMSE=0.17416866212116497, MAE=0.17289377249904733
# Random Forest validation for article_id 784926001: RMSE=0.060692907468191816, MAE=0.052698147291428646
# Random Forest validation for article_id 670752002: RMSE=0.09584078864853142, MAE=0.09128331633093467
# Random Forest validation for article_id 794395001: RMSE=0.23867532967782912, MAE=0.2378811376285718
# Random Forest validation for article_id 781608001: RMSE=0.3280402937739208, MAE=0.32029481878428623
# Random Forest validation for article_id 770857003: RMSE=0.25787307434677736, MAE=0.2523541744071424
# Random Forest validation for article_id 756132001: RMSE=0.038058550815911245, MAE=0.0357818446381564
# Random Forest validation for article_id 744893006: RMSE=0.2946950333586421, MAE=0.29281947058999924
# Random Forest validation for article_id 501820003: RMSE=0.004734407400548467, MAE=0.0036400785944205663
# Random Forest validation for article_id 787696004: RMSE=0.14121079623993602, MAE=0.13809293146590082
# Random Forest validation for article_id 562245025: RMSE=0.030861048328958415, MAE=0.02468657856912885
# Random Forest validation for article_id 759814010: RMSE=0.13969965917959654, MAE=0.10709044698285726
# Random Forest validation for article_id 714825002: RMSE=0.12510039629747854, MAE=0.1243133039347062
# Random Forest validation for article_id 616708006: RMSE=0.05673858569981766, MAE=0.02891849179469246
# Random Forest validation for article_id 844059001: RMSE=0.12426875285227153, MAE=0.11229806203000006
# Random Forest validation for article_id 696209004: RMSE=0.013771118792032688, MAE=0.011559156913857166
# Random Forest validation for article_id 675070002: RMSE=0.011123465580391142, MAE=0.009817844891000014
# Random Forest validation for article_id 776237003: RMSE=0.020509649226268904, MAE=0.016893262443928577
# Random Forest validation for article_id 791571003: RMSE=0.5407638339921707, MAE=0.5330578529921663
# Random Forest validation for article_id 694182004: RMSE=0.08390073833882647, MAE=0.0764481046799628
# Random Forest validation for article_id 577648001: RMSE=0.06281099789416428, MAE=0.06260361829285771
# Random Forest validation for article_id 797065001: RMSE=0.23508265745879248, MAE=0.22621006525599482
# Random Forest validation for article_id 708379004: RMSE=0.3074737751946113, MAE=0.3071538949700657
# Random Forest validation for article_id 734435002: RMSE=0.1823364070540991, MAE=0.18081686855739165
# Random Forest validation for article_id 569984001: RMSE=0.02985958842648422, MAE=0.023454893102381327
# Random Forest validation for article_id 807329002: RMSE=0.1465912665150883, MAE=0.1354966014945128
# Random Forest validation for article_id 732511002: RMSE=0.10992791411782855, MAE=0.10277921040544832
# Random Forest validation for article_id 637667002: RMSE=0.16782723421771154, MAE=0.16656988835290437
# Random Forest validation for article_id 748566004: RMSE=0.03050805371623649, MAE=0.016704799832857165
# Random Forest validation for article_id 661435002: RMSE=0.318066732818421, MAE=0.316683396521428
# Random Forest validation for article_id 733101002: RMSE=0.26172899079422657, MAE=0.26069177887283057
# Random Forest validation for article_id 637566006: RMSE=0.26202134566638474, MAE=0.26164404813571457
# Random Forest validation for article_id 695545008: RMSE=0.9838784813881656, MAE=0.9338562689642849
# Random Forest validation for article_id 706371001: RMSE=0.056079399304011374, MAE=0.05296049682612249
# Random Forest validation for article_id 837325001: RMSE=1.5355301182736434, MAE=1.5341254311940478
# Random Forest validation for article_id 781608002: RMSE=0.2979657262224903, MAE=0.2809052786777909
# Random Forest validation for article_id 697054002: RMSE=0.02515341318792199, MAE=0.02392825254887754
# Random Forest validation for article_id 668004001: RMSE=2.054118327589272, MAE=2.049109628534723
# Random Forest validation for article_id 767869001: RMSE=0.07832501935390478, MAE=0.07119470288571297
# Random Forest validation for article_id 762286001: RMSE=0.19678514288063895, MAE=0.1931305138170438
# Random Forest validation for article_id 768419001: RMSE=0.5843675852783373, MAE=0.5834607024694065
# Random Forest validation for article_id 744072002: RMSE=0.08456455599716942, MAE=0.05967163871971414
# Random Forest validation for article_id 737852001: RMSE=0.3216856999888254, MAE=0.3215109602214286
# Random Forest validation for article_id 687948001: RMSE=0.11358282446060479, MAE=0.09723797121446634
# Random Forest validation for article_id 695632007: RMSE=0.07422669735683571, MAE=0.07101599826535694
# Random Forest validation for article_id 844915003: RMSE=0.27665259338122955, MAE=0.25040291848571405
# Random Forest validation for article_id 794575003: RMSE=0.07629978159556855, MAE=0.047716761816764916
# Random Forest validation for article_id 571092001: RMSE=0.017183912267498304, MAE=0.013259325109020554
# Random Forest validation for article_id 662888005: RMSE=1.173245441731503, MAE=1.1724770608372135
# Random Forest validation for article_id 775996012: RMSE=0.03942967785624989, MAE=0.03403247499250002
# Random Forest validation for article_id 809961001: RMSE=0.14339313482839647, MAE=0.12368674641856994
# Random Forest validation for article_id 637549005: RMSE=0.31075159747787745, MAE=0.3073888973928564
# Random Forest validation for article_id 778534001: RMSE=0.3921268889812951, MAE=0.39153419725523786
# Random Forest validation for article_id 733027005: RMSE=0.017168692175710976, MAE=0.015703534320510748
# Random Forest validation for article_id 399223068: RMSE=0.2424972362683424, MAE=0.22312685768571477
# Random Forest validation for article_id 351933051: RMSE=0.043459256591282316, MAE=0.034031452243494915
# Random Forest validation for article_id 399223059: RMSE=0.07224007295741086, MAE=0.06707611806753337
# Random Forest validation for article_id 717816001: RMSE=0.07105221948749416, MAE=0.055526803082857144
# Random Forest validation for article_id 669605003: RMSE=0.022402170411776, MAE=0.02165253796011653
# Random Forest validation for article_id 717664001: RMSE=0.046093655324825275, MAE=0.044283011880634895
# Random Forest validation for article_id 618287006: RMSE=0.24194268572041247, MAE=0.22841174104006035
# Random Forest validation for article_id 714750001: RMSE=0.04655501176810516, MAE=0.045432282415377
# Random Forest validation for article_id 624486005: RMSE=0.012227475888438076, MAE=0.009167804570630387
# Random Forest validation for article_id 767438002: RMSE=0.03485068234254955, MAE=0.034033713225865674
# Random Forest validation for article_id 788107006: RMSE=0.45298131629566063, MAE=0.37766127077510714
# Random Forest validation for article_id 636323005: RMSE=0.01782369388543071, MAE=0.015750079881244182
# Random Forest validation for article_id 637283007: RMSE=0.15840969296463314, MAE=0.15161505365142852
# Random Forest validation for article_id 495685003: RMSE=0.4222650173169485, MAE=0.41987487043571026
# Random Forest validation for article_id 718582002: RMSE=0.20373697327591922, MAE=0.1886944849657148
# Random Forest validation for article_id 750398005: RMSE=0.03357503526766413, MAE=0.030162876267999957
# Random Forest validation for article_id 744862004: RMSE=0.030316806352049266, MAE=0.029169342665143278
# Random Forest validation for article_id 760449001: RMSE=0.35939688038507434, MAE=0.31496229612857096
# Random Forest validation for article_id 695318002: RMSE=0.1319215215858052, MAE=0.13141253919164173
# Random Forest validation for article_id 540768012: RMSE=0.019100974121413764, MAE=0.013794067248898301
# Random Forest validation for article_id 696733001: RMSE=0.06196756795505592, MAE=0.05797328102198292
# Random Forest validation for article_id 689005002: RMSE=0.04281177125989325, MAE=0.0260229760176743
# Random Forest validation for article_id 661806003: RMSE=0.06449465477173545, MAE=0.059699924864384184
# Random Forest validation for article_id 666382014: RMSE=0.5184281864032031, MAE=0.5173693661524118
# Random Forest validation for article_id 820563001: RMSE=0.419385351803811, MAE=0.4187185520931568
# Random Forest validation for article_id 569929001: RMSE=0.84302607221633, MAE=0.8421565018354727
# Random Forest validation for article_id 700515002: RMSE=0.225966447736875, MAE=0.2223336860249836
# Random Forest validation for article_id 831218001: RMSE=0.3409165895982212, MAE=0.335477355455957
# Random Forest validation for article_id 650122004: RMSE=0.05110533483335933, MAE=0.04615816587581629
# Random Forest validation for article_id 399201031: RMSE=0.16365124863906405, MAE=0.15715905320278376
# Random Forest validation for article_id 599580049: RMSE=0.13856875307394595, MAE=0.11554140781930748
# Random Forest validation for article_id 788651001: RMSE=0.18970762823802895, MAE=0.1872463115531746
# Random Forest validation for article_id 662868002: RMSE=0.1470715325537391, MAE=0.14317745010999997
# Random Forest validation for article_id 724905008: RMSE=0.11226393389712767, MAE=0.0797321816142857
# Random Forest validation for article_id 704630003: RMSE=0.04671694213857396, MAE=0.04354975470319268
# Random Forest validation for article_id 784143001: RMSE=0.09575625718962533, MAE=0.07537685270870731
# Random Forest validation for article_id 694127001: RMSE=0.21035444691063562, MAE=0.20983448570507274
# Random Forest validation for article_id 712711001: RMSE=0.06057616002481537, MAE=0.05740372821158255
# Random Forest validation for article_id 779889001: RMSE=0.11164107012087633, MAE=0.10892239850171358
# Random Forest validation for article_id 610776028: RMSE=0.03716185085421266, MAE=0.028836912797857005
# Random Forest validation for article_id 693479002: RMSE=0.0339550781947024, MAE=0.031467801953999876
# Random Forest validation for article_id 436083001: RMSE=0.10301808884922248, MAE=0.10180936189464307
# Random Forest validation for article_id 707699001: RMSE=0.03242095697488977, MAE=0.030283695296504244
# Random Forest validation for article_id 456163009: RMSE=0.03969132222099566, MAE=0.03438652896037414
# Random Forest validation for article_id 660599003: RMSE=0.14199413367334396, MAE=0.1350527210785712
# Random Forest validation for article_id 704126003: RMSE=0.016985900200845477, MAE=0.015487215730285428
# Random Forest validation for article_id 758642001: RMSE=0.4200050580388308, MAE=0.4194471853000003
# Random Forest validation for article_id 794793001: RMSE=0.1750471291062155, MAE=0.17123342960505905
# Random Forest validation for article_id 697060014: RMSE=0.015768483514663593, MAE=0.013383414382142857
# Random Forest validation for article_id 754323004: RMSE=0.35858413166450454, MAE=0.35723038324285705
# Random Forest validation for article_id 619884007: RMSE=0.02187255458957681, MAE=0.019979007444285702
# Random Forest validation for article_id 746888001: RMSE=0.16925519938852263, MAE=0.16731913857275074
# Random Forest validation for article_id 741478003: RMSE=0.15329977802938125, MAE=0.15224108220714258
# Random Forest validation for article_id 779656002: RMSE=0.6308459450405118, MAE=0.6303171731033982
# Random Forest validation for article_id 685848008: RMSE=0.14597185560466017, MAE=0.14570946108871932
# Random Forest validation for article_id 828991001: RMSE=0.08607510567508264, MAE=0.06376796491428573
# Random Forest validation for article_id 689572001: RMSE=0.047826164559255716, MAE=0.03668945402789552
# Random Forest validation for article_id 684686001: RMSE=0.0633404254175703, MAE=0.05941847911988204
# Random Forest validation for article_id 772927001: RMSE=0.16347180674778608, MAE=0.1622249816085713
# Random Forest validation for article_id 768440001: RMSE=0.015614398711759537, MAE=0.011377243455273644
# Random Forest validation for article_id 796239001: RMSE=0.09137061546381851, MAE=0.08706353352142858
# Random Forest validation for article_id 710708005: RMSE=0.03634112439372069, MAE=0.03302205710714308
# Random Forest validation for article_id 312878010: RMSE=0.13970286554780606, MAE=0.1260132626758644
# Random Forest validation for article_id 682520002: RMSE=0.15889006585357796, MAE=0.15810473550000048
# Random Forest validation for article_id 554450035: RMSE=0.04096966386898115, MAE=0.03529444774580946
# Random Forest validation for article_id 660712014: RMSE=0.016711384874353218, MAE=0.016134688304585778
# Random Forest predictions and validation tables with time information created successfully!
